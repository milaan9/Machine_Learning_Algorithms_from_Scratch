# %% [markdown]
# <a href="https://github.com/milaan9/Machine_Learning_Algorithms_from_Scratch"><img src="https://img.shields.io/badge/All the IPython Notebooks in Machine_Learning_Algorithms_from_Scratch lecture series by Dr. Milaan Parmar are available ➔ -GitHub-blueviolet.svg" alt="logo"/></a>

# %%
import math
"""
Program fits the training data to a gaussian model
"""

class Gaussian:
	def __init__(self, train_file, test_file):
		self.classifier_dic = {}
		self.mean_dic = {}
		self.variance_dic = {}
		self.normal_dic = []
		self.unique_labels = []
		self.probability_dic = {}
		self.train_file = train_file
		self.test_file = test_file

	def train(self):
		""" Trains the gaussian naive bayes classifier """

		train_file_path = self.train_file
		data_dic, self.unique_labels, total_number_of_rows, data_list = load_data_set(train_file_path)
		self.unique_labels = list(map(int, self.unique_labels))
		self.unique_labels = sorted(self.unique_labels)
		for label in self.unique_labels:
			for dimension in range(0, len(data_dic[label][0])):
				gaussian_training = GaussianTraining(data_dic[label], dimension)
				mean = gaussian_training.calculate_mean()
				variance = gaussian_training.calculate_variacne()
				if variance < 0.0001:
					variance = 0.0001
				if label in self.mean_dic:
					self.mean_dic[label].append(mean)
					self.variance_dic[label].append(variance)
				else:
					self.mean_dic[label] = [mean]
					self.variance_dic[label] = [variance]
				print("Class %d, dimension %d, mean = %.2f, std = %.2f" % (
				label, dimension + 1, mean, math.sqrt(variance)))
		self.probability_dic = GaussianTraining.probability_of_classifiers(self.unique_labels, total_number_of_rows, data_dic)

	def test(self):
		""" performs testing on test data """

		test_file_path = self.test_file
		number_of_test_rows, test_data = load_test_set(test_file_path)
		classification = GaussianClassification(self.unique_labels, self.mean_dic, self.variance_dic, self.probability_dic)
		for row in test_data:
			classification.classify(row)

		classification.display_accuracy(number_of_test_rows)


class GaussianTraining:
	def __init__(self, data, y):
		self.data_list = data
		self.column_number = y
		self.mean = 0
		self.sigma = 0
		self.variance = 0

	def calculate_mean(self):
		""" Calculates mean of the given dimension

        	Returns
        	-------
        	self.mean : float
                	    mean over the given dimension
       		"""

		summation = 0
		for elements in self.data_list:
			summation += elements[self.column_number]
		self.mean = summation / len(self.data_list)
		return self.mean

	def calculate_variacne(self):
		""" Calculates variance of the given dimension

		Returns
		----------------------------------------------------------------
		self.variance : float
				variance over the given dimension
        	"""
		
		if len(self.data_list) == 0:
			return 0
		summation = 0
		for elements in self.data_list:
			summation += ((elements[self.column_number] - self.mean) * (elements[self.column_number] - self.mean))
		self.sigma = math.sqrt(summation / (len(self.data_list) - 1))
		self.variance = math.pow(self.sigma, 2)
		return self.variance

	def calculate_normal_distribution(self, label):
		"""Calculates normal distribution

		Parameters
		----------------------------------------------------------
		label : int
			Class label.
	
		Returns
		----------------------------------------------------------		
		normal : float
			 normal distribution over a dimension for a class label.
		"""
		
		if self.variance == 0:
			return 0
		denominator = self.sigma * (math.sqrt(2 * math.pi))
		power = ((-1) * math.pow((label - self.mean), 2)) / (2 * self.variance)
		numerator = math.pow(math.e, power)
		normal = numerator / denominator
		return normal

	@staticmethod
	def probability_of_classifiers(unique_labels, total_number_of_rows, data_dic):
		"""Calculates probability of class labels

		Parameters
		----------
		unique_labels        :    list
					  contains list of unique class labels.
		total_number_of_rows :    int
					  number of samples in the training data
		data_dic	     :    dictionary
				
		Returns
		-------
		probability_dic      : dictionary
				       class labels are key and their probabilities are dictionary
		"""
		
		probability_dic = {}
		for labels in unique_labels:
			probability = len(data_dic[labels]) / float(total_number_of_rows)
			probability_dic[labels] = probability
		return probability_dic


class GaussianClassification:
	def __init__(self, unique_labels, mean, variance, probability_dic):
		self.unique_labels = unique_labels
		self.mean_dic = mean
		self.variance_dic = variance
		self.normal_dic = {}
		self.probability_dic = probability_dic
		self.correctly_classifed = 0
		self.total_probability = {}

	def classify(self, data_row):
		"""classifies a new data

		Parameters
		-----------------------------------------------------------------
		data_row        :    list
				     contains unknown data to be classified
		"""
		self.normal_dic = {}
		for label in self.unique_labels:
			for column in range(0, len(data_row) - 2):
				normal_result = self.calculate_normal_distribution(data_row[column], self.mean_dic[label][column], self.variance_dic[label][column])
				if label in self.normal_dic:
					self.normal_dic[label] *= normal_result
				else:
					self.normal_dic[label] = normal_result
		maximum = -1
		for label in self.normal_dic:
			self.normal_dic[label] = (self.normal_dic[label] * self.probability_dic[label])
		denominator = sum(self.normal_dic.values())
		for label in self.normal_dic:
			self.normal_dic[label] /= (float(denominator))
			if maximum < self.normal_dic[label]:
				maximum = self.normal_dic[label]
				classified_as = label

		accuracy = 0
		if classified_as == data_row[-2]:
			self.correctly_classifed += 1
			accuracy = 1
		print("ID = %5d, predicted = %3d, probability = %.4f, true=%3d, accuracy=%4.2f" % (
		data_row[-1], classified_as, maximum, data_row[-2], accuracy))

	def display_accuracy(self, number_of_test_rows):
		print("classification accuracy=%6.4lf " % (self.correctly_classifed / float(number_of_test_rows)))

	@staticmethod
	def calculate_normal_distribution(value, mean, variance):
		"""Calculates normal distribution

				Parameters
				-------------------------------------------------------
				value   :   float
					    value of x in f(x)
				mean    :   float
					    mean of the dimension
				variance :  float
				            variance of the dimension

				Returns
				-------------------------------------------------------
				normal : float
					 normal distribution over a dimension.
		"""
		if variance < 0.0001:
			variance = 0.0001
		denominator = math.sqrt(variance * 2 * math.pi)

		power = ((-1) * math.pow((value - mean), 2)) / float((2 * variance))
		numerator = math.pow(math.e, power)
		normal = numerator / float(denominator)

		return normal


def load_data_set(filename):
	"""Loads the training data from a file to the dictionary

		Parameters
		----------------------------------------------------
		filename   :   string
			       file path of training data
							       
		Returns
		----------------------------------------------------
		dictionary    : dictionary
				class label as key : list of rows as value
		unique_labels : list
		 		list of unique labels in the training data
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
	"""
	data_list = []
	input_file = open(filename, "r")
	print("⤵\n")    
	unique_labels = []
	dictionary = {}
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list)
		if row_list[-1] in dictionary:
			dictionary[row_list[-1]].append(row_list[0:-1])
		else:
			unique_labels.append(row_list[-1])
			dictionary[row_list[-1]] = [row_list[0:-1]]
		loop_count += 1
	return dictionary, unique_labels, loop_count, data_list


def load_test_set(filename):
	"""Loads the testing data from a file to the dictionary

		Parameters
		----------------------------------------------------
		filename   :   string
			       file path of training data
							       
		Returns
		----------------------------------------------------
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
	"""
	data_list = []
	input_file = open(filename, "r")
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list + [loop_count])
		loop_count += 1
	return loop_count, data_list


def main():
	
	input_line = input()	    # Taking file path from user as input
	input_list = input_line.split()  		    # converting  the input to a list

	gaussian = Gaussian(input_list[1], input_list[2])   # making object of Gaussian
	gaussian.train()
	gaussian.test()
	

main()


# ▶ Run and Enter ➜ naive_bayes data/yeast_training.txt data/yeast_test.txt gaussians
# or
# ▶ Run and Enter ➜ naive_bayes data/satellite_training.txt data/satellite_test.txt gaussians
# or
# ▶ Run and Enter ➜ naive_bayes data/pendigits_training.txt data/pendigits_test.txt gaussians
# Out:
# naive_bayes data/yeast_training.txt data/yeast_test.txt gaussians
# ⤵
#
# Class 1, dimension 1, mean = 0.52, std = 0.10
# Class 1, dimension 2, mean = 0.54, std = 0.10
# Class 1, dimension 3, mean = 0.52, std = 0.07
# Class 1, dimension 4, mean = 0.41, std = 0.17
# Class 1, dimension 5, mean = 0.50, std = 0.01
# Class 1, dimension 6, mean = 0.00, std = 0.01
# Class 1, dimension 7, mean = 0.50, std = 0.05
# Class 1, dimension 8, mean = 0.24, std = 0.05
# Class 2, dimension 1, mean = 0.45, std = 0.11
# Class 2, dimension 2, mean = 0.45, std = 0.10
# Class 2, dimension 3, mean = 0.53, std = 0.06
# Class 2, dimension 4, mean = 0.23, std = 0.11
# Class 2, dimension 5, mean = 0.50, std = 0.04
# Class 2, dimension 6, mean = 0.00, std = 0.01
# Class 2, dimension 7, mean = 0.49, std = 0.06
# Class 2, dimension 8, mean = 0.33, std = 0.14
# Class 3, dimension 1, mean = 0.43, std = 0.10
# Class 3, dimension 2, mean = 0.48, std = 0.11
# Class 3, dimension 3, mean = 0.36, std = 0.06
# Class 3, dimension 4, mean = 0.22, std = 0.08
# Class 3, dimension 5, mean = 0.51, std = 0.05
# Class 3, dimension 6, mean = 0.00, std = 0.01
# Class 3, dimension 7, mean = 0.51, std = 0.04
# Class 3, dimension 8, mean = 0.27, std = 0.09
# Class 4, dimension 1, mean = 0.79, std = 0.07
# Class 4, dimension 2, mean = 0.76, std = 0.07
# Class 4, dimension 3, mean = 0.38, std = 0.06
# Class 4, dimension 4, mean = 0.32, std = 0.11
# Class 4, dimension 5, mean = 0.50, std = 0.01
# Class 4, dimension 6, mean = 0.00, std = 0.01
# Class 4, dimension 7, mean = 0.51, std = 0.07
# Class 4, dimension 8, mean = 0.27, std = 0.09
# Class 5, dimension 1, mean = 0.74, std = 0.16
# Class 5, dimension 2, mean = 0.62, std = 0.13
# Class 5, dimension 3, mean = 0.42, std = 0.08
# Class 5, dimension 4, mean = 0.30, std = 0.12
# Class 5, dimension 5, mean = 0.50, std = 0.01
# Class 5, dimension 6, mean = 0.00, std = 0.01
# Class 5, dimension 7, mean = 0.51, std = 0.06
# Class 5, dimension 8, mean = 0.24, std = 0.04
# Class 6, dimension 1, mean = 0.54, std = 0.14
# Class 6, dimension 2, mean = 0.50, std = 0.12
# Class 6, dimension 3, mean = 0.51, std = 0.05
# Class 6, dimension 4, mean = 0.24, std = 0.10
# Class 6, dimension 5, mean = 0.50, std = 0.01
# Class 6, dimension 6, mean = 0.49, std = 0.39
# Class 6, dimension 7, mean = 0.51, std = 0.03
# Class 6, dimension 8, mean = 0.24, std = 0.05
# Class 7, dimension 1, mean = 0.48, std = 0.11
# Class 7, dimension 2, mean = 0.47, std = 0.09
# Class 7, dimension 3, mean = 0.54, std = 0.06
# Class 7, dimension 4, mean = 0.22, std = 0.12
# Class 7, dimension 5, mean = 0.50, std = 0.04
# Class 7, dimension 6, mean = 0.00, std = 0.03
# Class 7, dimension 7, mean = 0.50, std = 0.06
# Class 7, dimension 8, mean = 0.26, std = 0.09
# Class 8, dimension 1, mean = 0.74, std = 0.11
# Class 8, dimension 2, mean = 0.73, std = 0.11
# Class 8, dimension 3, mean = 0.49, std = 0.05
# Class 8, dimension 4, mean = 0.29, std = 0.07
# Class 8, dimension 5, mean = 0.50, std = 0.01
# Class 8, dimension 6, mean = 0.00, std = 0.01
# Class 8, dimension 7, mean = 0.46, std = 0.08
# Class 8, dimension 8, mean = 0.23, std = 0.02
# Class 9, dimension 1, mean = 0.55, std = 0.14
# Class 9, dimension 2, mean = 0.56, std = 0.16
# Class 9, dimension 3, mean = 0.51, std = 0.07
# Class 9, dimension 4, mean = 0.20, std = 0.07
# Class 9, dimension 5, mean = 0.50, std = 0.01
# Class 9, dimension 6, mean = 0.00, std = 0.01
# Class 9, dimension 7, mean = 0.53, std = 0.05
# Class 9, dimension 8, mean = 0.24, std = 0.05
# Class 10, dimension 1, mean = 0.78, std = 0.06
# Class 10, dimension 2, mean = 0.73, std = 0.12
# Class 10, dimension 3, mean = 0.48, std = 0.11
# Class 10, dimension 4, mean = 0.33, std = 0.07
# Class 10, dimension 5, mean = 1.00, std = 0.01
# Class 10, dimension 6, mean = 0.00, std = 0.01
# Class 10, dimension 7, mean = 0.55, std = 0.02
# Class 10, dimension 8, mean = 0.23, std = 0.01
# ID =     0, predicted =   3, probability = 0.7938, true=  3, accuracy=1.00
# ID =     1, predicted =   1, probability = 0.4629, true=  7, accuracy=0.00
# ID =     2, predicted =   1, probability = 0.3624, true=  7, accuracy=0.00
# ID =     3, predicted =   2, probability = 0.3239, true=  2, accuracy=1.00
# ID =     4, predicted =   2, probability = 0.7119, true=  2, accuracy=1.00
# ID =     5, predicted =   2, probability = 0.9952, true=  2, accuracy=1.00
# ID =     6, predicted =   1, probability = 0.6079, true=  7, accuracy=0.00
# ID =     7, predicted =   1, probability = 0.9230, true=  1, accuracy=1.00
# ID =     8, predicted =   1, probability = 0.3988, true=  7, accuracy=0.00
# ID =     9, predicted =   7, probability = 0.3530, true=  7, accuracy=1.00
# ID =    10, predicted =   3, probability = 0.7469, true=  3, accuracy=1.00
# ID =    11, predicted =   1, probability = 0.6686, true=  6, accuracy=0.00
# ID =    12, predicted =   1, probability = 0.8505, true=  2, accuracy=0.00
# ID =    13, predicted =   2, probability = 0.4730, true=  5, accuracy=0.00
# ID =    14, predicted =   5, probability = 0.8713, true=  5, accuracy=1.00
# ID =    15, predicted =   1, probability = 0.3799, true=  7, accuracy=0.00
# ID =    16, predicted =   1, probability = 0.4115, true=  3, accuracy=0.00
# ID =    17, predicted =   2, probability = 0.8200, true=  2, accuracy=1.00
# ID =    18, predicted =   2, probability = 0.9985, true=  3, accuracy=0.00
# ID =    19, predicted =   1, probability = 0.5075, true=  2, accuracy=0.00
# ID =    20, predicted =   2, probability = 0.6128, true=  2, accuracy=1.00
# ID =    21, predicted =   3, probability = 0.5484, true=  3, accuracy=1.00
# ID =    22, predicted =   2, probability = 0.4455, true=  2, accuracy=1.00
# ID =    23, predicted =   5, probability = 0.5965, true=  5, accuracy=1.00
# ID =    24, predicted =   2, probability = 0.9521, true=  3, accuracy=0.00
# ID =    25, predicted =   2, probability = 0.9742, true=  2, accuracy=1.00
# ID =    26, predicted =   2, probability = 0.5981, true=  2, accuracy=1.00
# ID =    27, predicted =   1, probability = 0.5413, true=  7, accuracy=0.00
# ID =    28, predicted =   1, probability = 0.3429, true=  3, accuracy=0.00
# ID =    29, predicted =   4, probability = 0.9264, true=  9, accuracy=0.00
# ID =    30, predicted =   1, probability = 0.7563, true=  7, accuracy=0.00
# ID =    31, predicted =   1, probability = 0.9133, true=  7, accuracy=0.00
# ID =    32, predicted =   1, probability = 0.5235, true=  7, accuracy=0.00
# ID =    33, predicted =   1, probability = 0.9681, true=  1, accuracy=1.00
# ID =    34, predicted =   9, probability = 0.4248, true=  7, accuracy=0.00
# ID =    35, predicted =   3, probability = 0.9086, true=  3, accuracy=1.00
# ID =    36, predicted =   3, probability = 0.8069, true=  3, accuracy=1.00
# ID =    37, predicted =   1, probability = 0.3497, true=  2, accuracy=0.00
# ID =    38, predicted =   2, probability = 0.7396, true=  7, accuracy=0.00
# ID =    39, predicted =   2, probability = 0.3533, true=  7, accuracy=0.00
# ID =    40, predicted =   1, probability = 0.4795, true=  3, accuracy=0.00
# ID =    41, predicted =   5, probability = 0.8289, true=  9, accuracy=0.00
# ID =    42, predicted =   5, probability = 0.4630, true=  1, accuracy=0.00
# ID =    43, predicted =   2, probability = 0.6989, true=  2, accuracy=1.00
# ID =    44, predicted =   2, probability = 0.9312, true=  2, accuracy=1.00
# ID =    45, predicted =   1, probability = 0.5007, true=  2, accuracy=0.00
# ID =    46, predicted =   1, probability = 0.3192, true=  7, accuracy=0.00
# ID =    47, predicted =   1, probability = 0.9505, true=  1, accuracy=1.00
# ID =    48, predicted =   1, probability = 0.8438, true=  1, accuracy=1.00
# ID =    49, predicted =   1, probability = 0.7714, true=  1, accuracy=1.00
# ID =    50, predicted =   2, probability = 0.9912, true=  7, accuracy=0.00
# ID =    51, predicted =   1, probability = 0.5219, true=  7, accuracy=0.00
# ID =    52, predicted =   2, probability = 0.3106, true=  2, accuracy=1.00
# ID =    53, predicted =   2, probability = 0.6690, true=  2, accuracy=1.00
# ID =    54, predicted =   2, probability = 0.5999, true=  7, accuracy=0.00
# ID =    55, predicted =   1, probability = 0.4811, true=  2, accuracy=0.00
# ID =    56, predicted =   1, probability = 0.8519, true=  2, accuracy=0.00
# ID =    57, predicted =   7, probability = 0.8934, true=  2, accuracy=0.00
# ID =    58, predicted =   1, probability = 0.6050, true=  3, accuracy=0.00
# ID =    59, predicted =   2, probability = 0.3341, true=  3, accuracy=0.00
# ID =    60, predicted =   1, probability = 0.3976, true=  2, accuracy=0.00
# ID =    61, predicted =   2, probability = 0.7544, true=  2, accuracy=1.00
# ID =    62, predicted =   1, probability = 0.8295, true=  1, accuracy=1.00
# ID =    63, predicted =   8, probability = 0.8927, true=  8, accuracy=1.00
# ID =    64, predicted =   3, probability = 0.6285, true=  3, accuracy=1.00
# ID =    65, predicted =   8, probability = 0.5460, true=  9, accuracy=0.00
# ID =    66, predicted =   7, probability = 0.9161, true=  2, accuracy=0.00
# ID =    67, predicted =   8, probability = 0.8960, true=  8, accuracy=1.00
# ID =    68, predicted =   2, probability = 0.4415, true=  7, accuracy=0.00
# ID =    69, predicted =   1, probability = 0.5673, true=  2, accuracy=0.00
# ID =    70, predicted =   3, probability = 0.6188, true=  9, accuracy=0.00
# ID =    71, predicted =   2, probability = 0.3884, true=  2, accuracy=1.00
# ID =    72, predicted =   3, probability = 0.9958, true=  3, accuracy=1.00
# ID =    73, predicted =   1, probability = 0.4629, true=  7, accuracy=0.00
# ID =    74, predicted =   1, probability = 0.4245, true=  7, accuracy=0.00
# ID =    75, predicted =   1, probability = 0.4107, true=  9, accuracy=0.00
# ID =    76, predicted =   5, probability = 0.4438, true=  3, accuracy=0.00
# ID =    77, predicted =   1, probability = 0.5372, true=  7, accuracy=0.00
# ID =    78, predicted =   8, probability = 0.7186, true=  8, accuracy=1.00
# ID =    79, predicted =   1, probability = 0.4277, true=  7, accuracy=0.00
# ID =    80, predicted =   1, probability = 0.4198, true=  7, accuracy=0.00
# ID =    81, predicted =   5, probability = 0.4501, true=  5, accuracy=1.00
# ID =    82, predicted =   1, probability = 0.3375, true=  5, accuracy=0.00
# ID =    83, predicted =   2, probability = 0.8983, true=  7, accuracy=0.00
# ID =    84, predicted =   1, probability = 0.5523, true=  1, accuracy=1.00
# ID =    85, predicted =   4, probability = 0.8206, true=  4, accuracy=1.00
# ID =    86, predicted =   1, probability = 0.5854, true=  7, accuracy=0.00
# ID =    87, predicted =   3, probability = 0.9150, true=  3, accuracy=1.00
# ID =    88, predicted =   2, probability = 0.6826, true=  2, accuracy=1.00
# ID =    89, predicted =   2, probability = 0.8376, true=  7, accuracy=0.00
# ID =    90, predicted =   2, probability = 0.4091, true=  7, accuracy=0.00
# ID =    91, predicted =   1, probability = 0.5358, true=  7, accuracy=0.00
# ID =    92, predicted =   1, probability = 0.7095, true=  7, accuracy=0.00
# ID =    93, predicted =   1, probability = 0.9759, true=  1, accuracy=1.00
# ID =    94, predicted =   2, probability = 0.7187, true=  2, accuracy=1.00
# ID =    95, predicted =   2, probability = 0.3619, true=  2, accuracy=1.00
# ID =    96, predicted =   1, probability = 0.9762, true=  1, accuracy=1.00
# ID =    97, predicted =   1, probability = 0.4777, true=  2, accuracy=0.00
# ID =    98, predicted =   1, probability = 0.5319, true=  7, accuracy=0.00
# ID =    99, predicted =   2, probability = 0.9964, true=  2, accuracy=1.00
# ID =   100, predicted =   1, probability = 0.3880, true=  3, accuracy=0.00
# ID =   101, predicted =   3, probability = 0.7177, true=  3, accuracy=1.00
# ID =   102, predicted =   1, probability = 0.4537, true=  2, accuracy=0.00
# ID =   103, predicted =   1, probability = 0.9193, true=  7, accuracy=0.00
# ID =   104, predicted =   4, probability = 0.9087, true=  3, accuracy=0.00
# ID =   105, predicted =   3, probability = 0.9791, true=  9, accuracy=0.00
# ID =   106, predicted =   1, probability = 0.6695, true=  6, accuracy=0.00
# ID =   107, predicted =   1, probability = 0.5765, true=  7, accuracy=0.00
# ID =   108, predicted =   2, probability = 0.4869, true=  7, accuracy=0.00
# ID =   109, predicted =   2, probability = 0.3327, true=  1, accuracy=0.00
# ID =   110, predicted =   1, probability = 0.9943, true=  2, accuracy=0.00
# ID =   111, predicted =   1, probability = 0.6059, true=  2, accuracy=0.00
# ID =   112, predicted =   1, probability = 0.5442, true=  7, accuracy=0.00
# ID =   113, predicted =   1, probability = 0.9695, true=  1, accuracy=1.00
# ID =   114, predicted =   1, probability = 0.4663, true=  7, accuracy=0.00
# ID =   115, predicted =   3, probability = 0.4391, true=  2, accuracy=0.00
# ID =   116, predicted =   1, probability = 0.4508, true=  2, accuracy=0.00
# ID =   117, predicted =   8, probability = 0.9949, true=  8, accuracy=1.00
# ID =   118, predicted =   2, probability = 0.8883, true=  5, accuracy=0.00
# ID =   119, predicted =   2, probability = 0.4648, true=  2, accuracy=1.00
# ID =   120, predicted =   9, probability = 0.3052, true=  7, accuracy=0.00
# ID =   121, predicted =   1, probability = 0.6840, true=  2, accuracy=0.00
# ID =   122, predicted =   4, probability = 0.6494, true=  4, accuracy=1.00
# ID =   123, predicted =   1, probability = 0.3409, true=  7, accuracy=0.00
# ID =   124, predicted =   1, probability = 0.9995, true=  1, accuracy=1.00
# ID =   125, predicted =   1, probability = 0.4939, true=  7, accuracy=0.00
# ID =   126, predicted =   2, probability = 0.5016, true=  7, accuracy=0.00
# ID =   127, predicted =   9, probability = 0.3504, true=  7, accuracy=0.00
# ID =   128, predicted =   2, probability = 0.9398, true=  7, accuracy=0.00
# ID =   129, predicted =   2, probability = 0.8731, true=  2, accuracy=1.00
# ID =   130, predicted =   2, probability = 0.9985, true=  7, accuracy=0.00
# ID =   131, predicted =   9, probability = 0.5197, true=  2, accuracy=0.00
# ID =   132, predicted =   1, probability = 0.4090, true=  2, accuracy=0.00
# ID =   133, predicted =   1, probability = 0.4732, true=  2, accuracy=0.00
# ID =   134, predicted =   1, probability = 0.9387, true=  1, accuracy=1.00
# ID =   135, predicted =   7, probability = 0.3716, true=  7, accuracy=1.00
# ID =   136, predicted =   8, probability = 0.6489, true=  8, accuracy=1.00
# ID =   137, predicted =   3, probability = 0.9540, true=  3, accuracy=1.00
# ID =   138, predicted =   2, probability = 0.5667, true=  2, accuracy=1.00
# ID =   139, predicted =   5, probability = 0.4381, true=  2, accuracy=0.00
# ID =   140, predicted =   2, probability = 0.7012, true=  7, accuracy=0.00
# ID =   141, predicted =   7, probability = 0.5138, true=  2, accuracy=0.00
# ID =   142, predicted =   3, probability = 0.8952, true=  3, accuracy=1.00
# ID =   143, predicted =   1, probability = 0.9791, true=  1, accuracy=1.00
# ID =   144, predicted =   1, probability = 0.6478, true=  7, accuracy=0.00
# ID =   145, predicted =   3, probability = 0.7709, true=  2, accuracy=0.00
# ID =   146, predicted =   2, probability = 0.5744, true=  2, accuracy=1.00
# ID =   147, predicted =   6, probability = 1.0000, true=  1, accuracy=0.00
# ID =   148, predicted =   1, probability = 0.6881, true=  2, accuracy=0.00
# ID =   149, predicted =   2, probability = 0.9966, true=  2, accuracy=1.00
# ID =   150, predicted =   2, probability = 0.6698, true=  7, accuracy=0.00
# ID =   151, predicted =   2, probability = 0.5926, true=  2, accuracy=1.00
# ID =   152, predicted =   2, probability = 0.9844, true=  2, accuracy=1.00
# ID =   153, predicted =   1, probability = 0.5717, true=  1, accuracy=1.00
# ID =   154, predicted =   5, probability = 0.6787, true=  5, accuracy=1.00
# ID =   155, predicted =   2, probability = 0.7503, true=  2, accuracy=1.00
# ID =   156, predicted =   2, probability = 0.7175, true=  7, accuracy=0.00
# ID =   157, predicted =   1, probability = 0.8959, true=  7, accuracy=0.00
# ID =   158, predicted =   2, probability = 0.6781, true=  7, accuracy=0.00
# ID =   159, predicted =   1, probability = 0.5779, true=  2, accuracy=0.00
# ID =   160, predicted =   7, probability = 0.6128, true=  7, accuracy=1.00
# ID =   161, predicted =   1, probability = 0.8360, true=  1, accuracy=1.00
# ID =   162, predicted =   1, probability = 0.7249, true=  2, accuracy=0.00
# ID =   163, predicted =   1, probability = 0.9548, true=  1, accuracy=1.00
# ID =   164, predicted =   4, probability = 0.5108, true=  4, accuracy=1.00
# ID =   165, predicted =   2, probability = 1.0000, true=  7, accuracy=0.00
# ID =   166, predicted =   1, probability = 0.4614, true=  7, accuracy=0.00
# ID =   167, predicted =   2, probability = 0.7420, true=  2, accuracy=1.00
# ID =   168, predicted =   1, probability = 0.6173, true=  2, accuracy=0.00
# ID =   169, predicted =   1, probability = 0.7447, true=  1, accuracy=1.00
# ID =   170, predicted =   1, probability = 0.9345, true=  1, accuracy=1.00
# ID =   171, predicted =   4, probability = 0.7313, true=  4, accuracy=1.00
# ID =   172, predicted =   5, probability = 0.7846, true=  1, accuracy=0.00
# ID =   173, predicted =   1, probability = 0.6310, true=  7, accuracy=0.00
# ID =   174, predicted =   2, probability = 0.6771, true=  2, accuracy=1.00
# ID =   175, predicted =   1, probability = 0.5227, true=  7, accuracy=0.00
# ID =   176, predicted =   2, probability = 0.9692, true=  2, accuracy=1.00
# ID =   177, predicted =   1, probability = 0.9907, true=  1, accuracy=1.00
# ID =   178, predicted =   1, probability = 0.6533, true=  7, accuracy=0.00
# ID =   179, predicted =   7, probability = 0.4061, true=  7, accuracy=1.00
# ID =   180, predicted =   4, probability = 0.5406, true=  4, accuracy=1.00
# ID =   181, predicted =   3, probability = 0.9582, true=  3, accuracy=1.00
# ID =   182, predicted =   3, probability = 0.9842, true=  3, accuracy=1.00
# ID =   183, predicted =   2, probability = 0.6389, true=  2, accuracy=1.00
# ID =   184, predicted =   2, probability = 0.5758, true=  2, accuracy=1.00
# ID =   185, predicted =   1, probability = 0.3337, true=  7, accuracy=0.00
# ID =   186, predicted =   1, probability = 0.5354, true=  3, accuracy=0.00
# ID =   187, predicted =   1, probability = 0.5193, true=  7, accuracy=0.00
# ID =   188, predicted =   3, probability = 1.0000, true=  2, accuracy=0.00
# ID =   189, predicted =   1, probability = 0.9498, true=  1, accuracy=1.00
# ID =   190, predicted =   9, probability = 0.2772, true=  7, accuracy=0.00
# ID =   191, predicted =   1, probability = 0.4623, true=  7, accuracy=0.00
# ID =   192, predicted =   1, probability = 0.7086, true=  7, accuracy=0.00
# ID =   193, predicted =   1, probability = 0.9626, true=  9, accuracy=0.00
# ID =   194, predicted =   1, probability = 0.4370, true=  1, accuracy=1.00
# ID =   195, predicted =   1, probability = 0.5446, true=  2, accuracy=0.00
# ID =   196, predicted =   2, probability = 0.4092, true=  2, accuracy=1.00
# ID =   197, predicted =   3, probability = 0.7457, true=  3, accuracy=1.00
# ID =   198, predicted =   1, probability = 0.5127, true=  7, accuracy=0.00
# ID =   199, predicted =   1, probability = 0.3335, true=  7, accuracy=0.00
# ID =   200, predicted =   1, probability = 0.4739, true=  1, accuracy=1.00
# ID =   201, predicted =   3, probability = 0.6167, true=  3, accuracy=1.00
# ID =   202, predicted =   2, probability = 0.5817, true=  2, accuracy=1.00
# ID =   203, predicted =   2, probability = 0.4765, true=  7, accuracy=0.00
# ID =   204, predicted =   3, probability = 0.9790, true=  3, accuracy=1.00
# ID =   205, predicted =   3, probability = 0.9982, true=  3, accuracy=1.00
# ID =   206, predicted =   2, probability = 0.8669, true=  7, accuracy=0.00
# ID =   207, predicted =   1, probability = 0.3698, true=  1, accuracy=1.00
# ID =   208, predicted =   3, probability = 0.9226, true=  3, accuracy=1.00
# ID =   209, predicted =   1, probability = 0.4239, true=  2, accuracy=0.00
# ID =   210, predicted =   1, probability = 0.5469, true=  3, accuracy=0.00
# ID =   211, predicted =   1, probability = 0.5497, true=  2, accuracy=0.00
# ID =   212, predicted =   1, probability = 0.7219, true=  1, accuracy=1.00
# ID =   213, predicted =   7, probability = 0.3739, true=  1, accuracy=0.00
# ID =   214, predicted =   2, probability = 0.6494, true=  7, accuracy=0.00
# ID =   215, predicted =   2, probability = 0.9991, true=  2, accuracy=1.00
# ID =   216, predicted =   1, probability = 0.9832, true=  1, accuracy=1.00
# ID =   217, predicted =   1, probability = 0.4420, true=  3, accuracy=0.00
# ID =   218, predicted =   1, probability = 0.9928, true=  1, accuracy=1.00
# ID =   219, predicted =   1, probability = 0.9968, true=  1, accuracy=1.00
# ID =   220, predicted =   2, probability = 0.4767, true=  2, accuracy=1.00
# ID =   221, predicted =   1, probability = 0.4517, true=  7, accuracy=0.00
# ID =   222, predicted =   3, probability = 0.4685, true=  3, accuracy=1.00
# ID =   223, predicted =   1, probability = 0.9434, true=  1, accuracy=1.00
# ID =   224, predicted =   8, probability = 0.7959, true=  8, accuracy=1.00
# ID =   225, predicted =   2, probability = 0.9887, true=  7, accuracy=0.00
# ID =   226, predicted =   1, probability = 0.9879, true=  1, accuracy=1.00
# ID =   227, predicted =   1, probability = 0.8451, true=  7, accuracy=0.00
# ID =   228, predicted =   1, probability = 0.4737, true=  9, accuracy=0.00
# ID =   229, predicted =   1, probability = 0.5751, true=  1, accuracy=1.00
# ID =   230, predicted =   2, probability = 0.4163, true=  1, accuracy=0.00
# ID =   231, predicted =   7, probability = 0.9782, true=  7, accuracy=1.00
# ID =   232, predicted =   1, probability = 0.3428, true=  3, accuracy=0.00
# ID =   233, predicted =   1, probability = 0.4546, true=  7, accuracy=0.00
# ID =   234, predicted =   5, probability = 0.7237, true=  1, accuracy=0.00
# ID =   235, predicted =   2, probability = 0.9964, true=  2, accuracy=1.00
# ID =   236, predicted =   3, probability = 1.0000, true=  7, accuracy=0.00
# ID =   237, predicted =   2, probability = 0.4399, true=  1, accuracy=0.00
# ID =   238, predicted =   4, probability = 0.5892, true=  4, accuracy=1.00
# ID =   239, predicted =   5, probability = 0.5303, true=  3, accuracy=0.00
# ID =   240, predicted =   1, probability = 0.4206, true=  7, accuracy=0.00
# ID =   241, predicted =   1, probability = 0.4727, true=  7, accuracy=0.00
# ID =   242, predicted =   1, probability = 0.9308, true=  3, accuracy=0.00
# ID =   243, predicted =   8, probability = 0.8990, true=  8, accuracy=1.00
# ID =   244, predicted =   2, probability = 0.6588, true=  2, accuracy=1.00
# ID =   245, predicted =   2, probability = 0.9649, true=  7, accuracy=0.00
# ID =   246, predicted =   2, probability = 0.9658, true=  2, accuracy=1.00
# ID =   247, predicted =   2, probability = 0.9987, true=  1, accuracy=0.00
# ID =   248, predicted =   1, probability = 0.4675, true=  7, accuracy=0.00
# ID =   249, predicted =   1, probability = 0.9942, true=  1, accuracy=1.00
# ID =   250, predicted =   1, probability = 0.3339, true=  9, accuracy=0.00
# ID =   251, predicted =   3, probability = 0.4779, true=  3, accuracy=1.00
# ID =   252, predicted =   2, probability = 0.7135, true=  1, accuracy=0.00
# ID =   253, predicted =   1, probability = 0.6482, true=  7, accuracy=0.00
# ID =   254, predicted =   1, probability = 0.9607, true=  1, accuracy=1.00
# ID =   255, predicted =   8, probability = 0.7178, true=  4, accuracy=0.00
# ID =   256, predicted =   1, probability = 0.3950, true=  3, accuracy=0.00
# ID =   257, predicted =   2, probability = 0.9998, true=  2, accuracy=1.00
# ID =   258, predicted =   1, probability = 0.4503, true=  1, accuracy=1.00
# ID =   259, predicted =   2, probability = 0.6342, true=  3, accuracy=0.00
# ID =   260, predicted =   2, probability = 0.3541, true=  2, accuracy=1.00
# ID =   261, predicted =   2, probability = 0.7231, true=  2, accuracy=1.00
# ID =   262, predicted =   8, probability = 0.6455, true=  4, accuracy=0.00
# ID =   263, predicted =   9, probability = 0.3051, true=  9, accuracy=1.00
# ID =   264, predicted =   1, probability = 0.5866, true=  2, accuracy=0.00
# ID =   265, predicted =   1, probability = 0.6958, true=  2, accuracy=0.00
# ID =   266, predicted =   4, probability = 0.9606, true=  4, accuracy=1.00
# ID =   267, predicted =   1, probability = 0.5842, true=  7, accuracy=0.00
# ID =   268, predicted =   1, probability = 0.9239, true=  7, accuracy=0.00
# ID =   269, predicted =   1, probability = 0.4650, true=  7, accuracy=0.00
# ID =   270, predicted =   1, probability = 0.3923, true=  7, accuracy=0.00
# ID =   271, predicted =   1, probability = 0.4745, true=  7, accuracy=0.00
# ID =   272, predicted =   4, probability = 0.7132, true=  8, accuracy=0.00
# ID =   273, predicted =   2, probability = 0.9489, true=  2, accuracy=1.00
# ID =   274, predicted =   1, probability = 0.6013, true=  2, accuracy=0.00
# ID =   275, predicted =   1, probability = 0.4151, true=  7, accuracy=0.00
# ID =   276, predicted =   3, probability = 0.8281, true=  3, accuracy=1.00
# ID =   277, predicted =   3, probability = 0.3732, true=  2, accuracy=0.00
# ID =   278, predicted =   1, probability = 0.4130, true=  1, accuracy=1.00
# ID =   279, predicted =   2, probability = 0.5778, true=  2, accuracy=1.00
# ID =   280, predicted =   1, probability = 0.5492, true=  7, accuracy=0.00
# ID =   281, predicted =   8, probability = 0.5115, true=  7, accuracy=0.00
# ID =   282, predicted =   2, probability = 0.8821, true=  2, accuracy=1.00
# ID =   283, predicted =   1, probability = 0.9522, true=  7, accuracy=0.00
# ID =   284, predicted =   2, probability = 0.3901, true=  2, accuracy=1.00
# ID =   285, predicted =   2, probability = 0.3908, true=  7, accuracy=0.00
# ID =   286, predicted =   8, probability = 0.7427, true=  2, accuracy=0.00
# ID =   287, predicted =   1, probability = 0.3457, true=  7, accuracy=0.00
# ID =   288, predicted =   3, probability = 0.3899, true=  3, accuracy=1.00
# ID =   289, predicted =   3, probability = 0.2912, true=  2, accuracy=0.00
# ID =   290, predicted =   1, probability = 0.3605, true=  3, accuracy=0.00
# ID =   291, predicted =   5, probability = 0.6419, true=  5, accuracy=1.00
# ID =   292, predicted =   2, probability = 0.3469, true=  2, accuracy=1.00
# ID =   293, predicted =   1, probability = 0.4346, true=  7, accuracy=0.00
# ID =   294, predicted =   7, probability = 0.3629, true=  8, accuracy=0.00
# ID =   295, predicted =   2, probability = 0.4446, true=  1, accuracy=0.00
# ID =   296, predicted =   3, probability = 0.5085, true=  3, accuracy=1.00
# ID =   297, predicted =   2, probability = 0.9730, true=  2, accuracy=1.00
# ID =   298, predicted =   1, probability = 0.5557, true=  7, accuracy=0.00
# ID =   299, predicted =   6, probability = 1.0000, true=  1, accuracy=0.00
# ID =   300, predicted =   8, probability = 0.6563, true=  7, accuracy=0.00
# ID =   301, predicted =   1, probability = 0.8850, true=  1, accuracy=1.00
# ID =   302, predicted =   1, probability = 0.5800, true=  1, accuracy=1.00
# ID =   303, predicted =   2, probability = 0.9956, true=  3, accuracy=0.00
# ID =   304, predicted =   2, probability = 0.5670, true=  2, accuracy=1.00
# ID =   305, predicted =   2, probability = 0.6958, true=  2, accuracy=1.00
# ID =   306, predicted =   9, probability = 0.4982, true=  7, accuracy=0.00
# ID =   307, predicted =   1, probability = 0.6100, true=  8, accuracy=0.00
# ID =   308, predicted =   1, probability = 0.3493, true=  7, accuracy=0.00
# ID =   309, predicted =   1, probability = 0.9832, true=  1, accuracy=1.00
# ID =   310, predicted =   3, probability = 0.7089, true=  3, accuracy=1.00
# ID =   311, predicted =   2, probability = 0.7483, true=  7, accuracy=0.00
# ID =   312, predicted =   1, probability = 0.7679, true=  1, accuracy=1.00
# ID =   313, predicted =   1, probability = 0.3345, true=  7, accuracy=0.00
# ID =   314, predicted =   1, probability = 0.4103, true=  7, accuracy=0.00
# ID =   315, predicted =   7, probability = 0.2744, true=  7, accuracy=1.00
# ID =   316, predicted =   1, probability = 0.4296, true=  7, accuracy=0.00
# ID =   317, predicted =   2, probability = 0.7316, true=  7, accuracy=0.00
# ID =   318, predicted =   3, probability = 0.9844, true=  3, accuracy=1.00
# ID =   319, predicted =   1, probability = 0.9991, true=  1, accuracy=1.00
# ID =   320, predicted =   3, probability = 0.9757, true=  9, accuracy=0.00
# ID =   321, predicted =   1, probability = 0.3652, true=  7, accuracy=0.00
# ID =   322, predicted =   1, probability = 0.5503, true=  7, accuracy=0.00
# ID =   323, predicted =   3, probability = 0.8063, true=  3, accuracy=1.00
# ID =   324, predicted =   5, probability = 0.8017, true=  5, accuracy=1.00
# ID =   325, predicted =   1, probability = 0.5863, true=  2, accuracy=0.00
# ID =   326, predicted =   1, probability = 0.4420, true=  2, accuracy=0.00
# ID =   327, predicted =   1, probability = 0.4779, true=  7, accuracy=0.00
# ID =   328, predicted =   3, probability = 0.9880, true=  3, accuracy=1.00
# ID =   329, predicted =   1, probability = 0.8777, true=  1, accuracy=1.00
# ID =   330, predicted =   1, probability = 0.5176, true=  7, accuracy=0.00
# ID =   331, predicted =   5, probability = 0.9488, true=  5, accuracy=1.00
# ID =   332, predicted =   2, probability = 0.4862, true=  2, accuracy=1.00
# ID =   333, predicted =   1, probability = 0.8644, true=  7, accuracy=0.00
# ID =   334, predicted =   1, probability = 0.6788, true=  2, accuracy=0.00
# ID =   335, predicted =   6, probability = 1.0000, true=  6, accuracy=1.00
# ID =   336, predicted =   2, probability = 0.6250, true=  2, accuracy=1.00
# ID =   337, predicted =   7, probability = 0.9276, true=  2, accuracy=0.00
# ID =   338, predicted =   1, probability = 0.7537, true=  9, accuracy=0.00
# ID =   339, predicted =   2, probability = 0.9903, true=  7, accuracy=0.00
# ID =   340, predicted =   3, probability = 0.7723, true=  9, accuracy=0.00
# ID =   341, predicted =   3, probability = 0.4316, true=  3, accuracy=1.00
# ID =   342, predicted =   5, probability = 0.5409, true=  5, accuracy=1.00
# ID =   343, predicted =  10, probability = 1.0000, true=  5, accuracy=0.00
# ID =   344, predicted =   2, probability = 0.9154, true=  2, accuracy=1.00
# ID =   345, predicted =   2, probability = 0.9835, true=  2, accuracy=1.00
# ID =   346, predicted =   1, probability = 0.9853, true=  2, accuracy=0.00
# ID =   347, predicted =   1, probability = 0.6544, true=  1, accuracy=1.00
# ID =   348, predicted =   2, probability = 0.7585, true=  2, accuracy=1.00
# ID =   349, predicted =   1, probability = 0.4894, true=  2, accuracy=0.00
# ID =   350, predicted =   1, probability = 0.7483, true=  7, accuracy=0.00
# ID =   351, predicted =   1, probability = 0.3582, true=  7, accuracy=0.00
# ID =   352, predicted =  10, probability = 1.0000, true=  7, accuracy=0.00
# ID =   353, predicted =   1, probability = 0.7144, true=  6, accuracy=0.00
# ID =   354, predicted =   1, probability = 0.6684, true=  1, accuracy=1.00
# ID =   355, predicted =   1, probability = 0.7801, true=  1, accuracy=1.00
# ID =   356, predicted =   2, probability = 0.5653, true=  2, accuracy=1.00
# ID =   357, predicted =   2, probability = 0.3061, true=  7, accuracy=0.00
# ID =   358, predicted =   1, probability = 0.4978, true=  7, accuracy=0.00
# ID =   359, predicted =   1, probability = 0.6591, true=  7, accuracy=0.00
# ID =   360, predicted =   3, probability = 0.6014, true=  3, accuracy=1.00
# ID =   361, predicted =   5, probability = 0.4094, true=  7, accuracy=0.00
# ID =   362, predicted =   1, probability = 0.9037, true=  2, accuracy=0.00
# ID =   363, predicted =   1, probability = 0.4020, true=  2, accuracy=0.00
# ID =   364, predicted =   2, probability = 0.7488, true=  7, accuracy=0.00
# ID =   365, predicted =   1, probability = 0.5040, true=  7, accuracy=0.00
# ID =   366, predicted =   1, probability = 0.4629, true=  2, accuracy=0.00
# ID =   367, predicted =   1, probability = 0.5061, true=  6, accuracy=0.00
# ID =   368, predicted =   2, probability = 0.9005, true=  2, accuracy=1.00
# ID =   369, predicted =   6, probability = 1.0000, true=  1, accuracy=0.00
# ID =   370, predicted =   3, probability = 0.4456, true=  3, accuracy=1.00
# ID =   371, predicted =   2, probability = 0.9942, true=  2, accuracy=1.00
# ID =   372, predicted =   2, probability = 0.4067, true=  2, accuracy=1.00
# ID =   373, predicted =   1, probability = 0.4787, true=  7, accuracy=0.00
# ID =   374, predicted =   2, probability = 0.9992, true=  2, accuracy=1.00
# ID =   375, predicted =   1, probability = 0.4403, true=  2, accuracy=0.00
# ID =   376, predicted =   3, probability = 0.6347, true=  3, accuracy=1.00
# ID =   377, predicted =   2, probability = 0.5247, true=  7, accuracy=0.00
# ID =   378, predicted =   1, probability = 0.5561, true=  7, accuracy=0.00
# ID =   379, predicted =   2, probability = 0.3885, true=  2, accuracy=1.00
# ID =   380, predicted =   1, probability = 0.6023, true=  1, accuracy=1.00
# ID =   381, predicted =   2, probability = 0.9751, true=  7, accuracy=0.00
# ID =   382, predicted =   1, probability = 0.4739, true=  1, accuracy=1.00
# ID =   383, predicted =   4, probability = 0.4656, true=  4, accuracy=1.00
# ID =   384, predicted =   1, probability = 0.8624, true=  1, accuracy=1.00
# ID =   385, predicted =   2, probability = 0.5173, true=  7, accuracy=0.00
# ID =   386, predicted =   7, probability = 0.5907, true=  5, accuracy=0.00
# ID =   387, predicted =   2, probability = 0.5393, true=  2, accuracy=1.00
# ID =   388, predicted =   1, probability = 0.7102, true=  7, accuracy=0.00
# ID =   389, predicted =   1, probability = 0.6213, true=  1, accuracy=1.00
# ID =   390, predicted =   1, probability = 0.4859, true=  7, accuracy=0.00
# ID =   391, predicted =   1, probability = 0.4015, true=  7, accuracy=0.00
# ID =   392, predicted =   1, probability = 0.6810, true=  2, accuracy=0.00
# ID =   393, predicted =   1, probability = 0.4139, true=  7, accuracy=0.00
# ID =   394, predicted =   1, probability = 0.6981, true=  7, accuracy=0.00
# ID =   395, predicted =   1, probability = 0.3955, true=  2, accuracy=0.00
# ID =   396, predicted =   3, probability = 0.9918, true=  3, accuracy=1.00
# ID =   397, predicted =   2, probability = 0.5149, true=  7, accuracy=0.00
# ID =   398, predicted =   1, probability = 0.4067, true=  2, accuracy=0.00
# ID =   399, predicted =   2, probability = 0.3201, true=  2, accuracy=1.00
# ID =   400, predicted =   2, probability = 0.5297, true=  7, accuracy=0.00
# ID =   401, predicted =   5, probability = 0.5270, true=  1, accuracy=0.00
# ID =   402, predicted =   2, probability = 1.0000, true=  2, accuracy=1.00
# ID =   403, predicted =   2, probability = 0.4120, true=  7, accuracy=0.00
# ID =   404, predicted =   1, probability = 0.5523, true=  2, accuracy=0.00
# ID =   405, predicted =   5, probability = 0.5756, true=  3, accuracy=0.00
# ID =   406, predicted =  10, probability = 1.0000, true= 10, accuracy=1.00
# ID =   407, predicted =   2, probability = 0.9228, true=  2, accuracy=1.00
# ID =   408, predicted =   3, probability = 0.4093, true=  3, accuracy=1.00
# ID =   409, predicted =   2, probability = 0.7348, true=  2, accuracy=1.00
# ID =   410, predicted =   3, probability = 0.9841, true=  3, accuracy=1.00
# ID =   411, predicted =   3, probability = 0.8085, true=  3, accuracy=1.00
# ID =   412, predicted =   7, probability = 0.4853, true=  7, accuracy=1.00
# ID =   413, predicted =   2, probability = 0.5773, true=  7, accuracy=0.00
# ID =   414, predicted =   4, probability = 0.8423, true=  5, accuracy=0.00
# ID =   415, predicted =   3, probability = 0.9497, true=  3, accuracy=1.00
# ID =   416, predicted =   3, probability = 0.4563, true=  5, accuracy=0.00
# ID =   417, predicted =   1, probability = 0.9479, true=  1, accuracy=1.00
# ID =   418, predicted =   2, probability = 0.5050, true=  2, accuracy=1.00
# ID =   419, predicted =   1, probability = 0.9003, true=  1, accuracy=1.00
# ID =   420, predicted =   1, probability = 0.5248, true=  7, accuracy=0.00
# ID =   421, predicted =   1, probability = 0.4432, true=  2, accuracy=0.00
# ID =   422, predicted =   3, probability = 0.7400, true=  3, accuracy=1.00
# ID =   423, predicted =   2, probability = 0.4313, true=  2, accuracy=1.00
# ID =   424, predicted =   2, probability = 0.3706, true=  7, accuracy=0.00
# ID =   425, predicted =   3, probability = 0.9537, true=  3, accuracy=1.00
# ID =   426, predicted =   2, probability = 0.5149, true=  7, accuracy=0.00
# ID =   427, predicted =   1, probability = 0.5906, true=  7, accuracy=0.00
# ID =   428, predicted =   1, probability = 0.5440, true=  7, accuracy=0.00
# ID =   429, predicted =   1, probability = 0.9058, true=  1, accuracy=1.00
# ID =   430, predicted =   1, probability = 0.9998, true=  1, accuracy=1.00
# ID =   431, predicted =   1, probability = 0.5102, true=  7, accuracy=0.00
# ID =   432, predicted =   1, probability = 0.5967, true=  2, accuracy=0.00
# ID =   433, predicted =   1, probability = 0.4460, true=  7, accuracy=0.00
# ID =   434, predicted =   1, probability = 0.9639, true=  1, accuracy=1.00
# ID =   435, predicted =   6, probability = 1.0000, true=  6, accuracy=1.00
# ID =   436, predicted =   3, probability = 0.7092, true=  9, accuracy=0.00
# ID =   437, predicted =   2, probability = 0.5890, true=  2, accuracy=1.00
# ID =   438, predicted =   2, probability = 0.4704, true=  7, accuracy=0.00
# ID =   439, predicted =   3, probability = 0.6289, true=  3, accuracy=1.00
# ID =   440, predicted =   1, probability = 0.4952, true=  3, accuracy=0.00
# ID =   441, predicted =   2, probability = 0.5193, true=  2, accuracy=1.00
# ID =   442, predicted =   5, probability = 0.8506, true=  3, accuracy=0.00
# ID =   443, predicted =   2, probability = 0.4516, true=  2, accuracy=1.00
# ID =   444, predicted =   1, probability = 0.3961, true=  7, accuracy=0.00
# ID =   445, predicted =   1, probability = 0.4589, true=  7, accuracy=0.00
# ID =   446, predicted =   3, probability = 0.7245, true=  3, accuracy=1.00
# ID =   447, predicted =   4, probability = 0.8377, true=  8, accuracy=0.00
# ID =   448, predicted =   1, probability = 0.5726, true=  7, accuracy=0.00
# ID =   449, predicted =   2, probability = 0.8777, true=  7, accuracy=0.00
# ID =   450, predicted =   2, probability = 0.4259, true=  7, accuracy=0.00
# ID =   451, predicted =   3, probability = 0.3393, true=  3, accuracy=1.00
# ID =   452, predicted =   2, probability = 0.5300, true=  2, accuracy=1.00
# ID =   453, predicted =   1, probability = 0.5605, true=  2, accuracy=0.00
# ID =   454, predicted =   2, probability = 0.9955, true=  2, accuracy=1.00
# ID =   455, predicted =   3, probability = 0.9128, true=  3, accuracy=1.00
# ID =   456, predicted =   1, probability = 0.9805, true=  1, accuracy=1.00
# ID =   457, predicted =   1, probability = 0.4822, true=  2, accuracy=0.00
# ID =   458, predicted =   2, probability = 0.4493, true=  2, accuracy=1.00
# ID =   459, predicted =   2, probability = 0.8419, true=  7, accuracy=0.00
# ID =   460, predicted =   4, probability = 0.9996, true=  4, accuracy=1.00
# ID =   461, predicted =   2, probability = 0.3701, true=  7, accuracy=0.00
# ID =   462, predicted =   2, probability = 0.5858, true=  2, accuracy=1.00
# ID =   463, predicted =   2, probability = 1.0000, true=  2, accuracy=1.00
# ID =   464, predicted =   1, probability = 0.9929, true=  1, accuracy=1.00
# ID =   465, predicted =   3, probability = 0.9909, true=  3, accuracy=1.00
# ID =   466, predicted =   2, probability = 0.6347, true=  2, accuracy=1.00
# ID =   467, predicted =   1, probability = 0.3804, true=  7, accuracy=0.00
# ID =   468, predicted =   2, probability = 0.6289, true=  2, accuracy=1.00
# ID =   469, predicted =   1, probability = 0.5833, true=  7, accuracy=0.00
# ID =   470, predicted =   5, probability = 0.5384, true=  1, accuracy=0.00
# ID =   471, predicted =   1, probability = 0.9980, true=  1, accuracy=1.00
# ID =   472, predicted =   8, probability = 0.6153, true=  4, accuracy=0.00
# ID =   473, predicted =   8, probability = 0.9734, true=  8, accuracy=1.00
# ID =   474, predicted =   1, probability = 0.9901, true=  1, accuracy=1.00
# ID =   475, predicted =   2, probability = 0.4794, true=  1, accuracy=0.00
# ID =   476, predicted =   1, probability = 0.7959, true=  1, accuracy=1.00
# ID =   477, predicted =   1, probability = 0.9524, true=  1, accuracy=1.00
# ID =   478, predicted =   5, probability = 0.7678, true=  5, accuracy=1.00
# ID =   479, predicted =   3, probability = 0.6374, true=  3, accuracy=1.00
# ID =   480, predicted =   1, probability = 0.7349, true=  2, accuracy=0.00
# ID =   481, predicted =   1, probability = 0.6293, true=  8, accuracy=0.00
# ID =   482, predicted =   1, probability = 0.4926, true=  2, accuracy=0.00
# ID =   483, predicted =   1, probability = 0.4400, true=  1, accuracy=1.00
# classification accuracy=0.4483
