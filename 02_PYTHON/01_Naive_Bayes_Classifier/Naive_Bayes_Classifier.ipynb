# %% [markdown]
# <a href="https://github.com/milaan9/Machine_Learning_Algorithms_from_Scratch"><img src="https://img.shields.io/badge/All the IPython Notebooks in Machine_Learning_Algorithms_from_Scratch lecture series by Dr. Milaan Parmar are available ➔ -GitHub-blueviolet.svg" alt="logo"/></a>

# %%
import math
"""
Program performs naive bayes classifier on numerical data
"""

class Histogram:
	def __init__(self, train_file, test_file, number_of_gaussians):
		self.classifier_dic = {}
		self.probability_dic = {}
		self.column_bin_dic = {}
		self.unique_labels = []
		self.train_file = train_file
		self.test_file = test_file
		self.number_of_gaussians = number_of_gaussians

	def train(self):
		""" Trains the naive bayes classifier """
		
		train_file_path = self.train_file
		number_of_bins = self.number_of_gaussians
		data_dic, self.unique_labels, total_number_of_rows, data_list = load_data_set(train_file_path)
		self.unique_labels = sorted(self.unique_labels)
		self.unique_labels = list(map(int, self.unique_labels))
		total_number_of_columns = len(data_list[0]) - 1
		bin_range_dic = {}
		column_bin_dic = {}
		histogram_training = HistogramTraining
		for x in range(0, total_number_of_columns):
			for label in data_dic:
				bin_list, bin_range = histogram_training.bining(x, number_of_bins, data_dic[label])
				if label in column_bin_dic:
					column_bin_dic[label][x] = bin_list
					bin_range_dic[label][x] = bin_range
				else:
					col_dic = {}
					range_dic = {}
					col_dic[x] = bin_list
					range_dic[x] = bin_range
					column_bin_dic[label] = col_dic
					bin_range_dic[label] = range_dic
		self.column_bin_dic = column_bin_dic
		data_dic = histogram_training.change_data(column_bin_dic, data_dic)
		self.probability_dic = histogram_training.probability_of_classifiers(self.unique_labels, total_number_of_rows, data_dic)
		self.classifier_dic = histogram_training.calculate_conditional_probability(data_dic, number_of_bins, bin_range_dic)

	def test(self):
		""" performs testing on test data """
		
		test_file_path = self.test_file
		number_of_test_rows, test_data = load_test_set(test_file_path)
		classification = HistogramClassification(self.probability_dic, self.classifier_dic, self.column_bin_dic, self.unique_labels, self.column_bin_dic)
		for row in test_data:
			classification.classify(row)
		classification.display_accuracy(number_of_test_rows)


class HistogramTraining:
	data_dic = {}

	@staticmethod
	def bining(column_number, total_bins, data_list):
		""" performs binning on given dimension
			Parameters
			--------------------------------------------------
			column_number :    int
					   dimension number
			total_bins    :    int
				           number of bins to be created
			data_list     :    list
					   list of training data


		    	Returns
		    	--------------------------------------------------
			bin_list  : list
		                    list of list containing the range of the bin for the given dimension
		    	bin_range : float
		    		    range for each bin in binning
		"""
		
		bin_list = []
		if total_bins == 1:
			bin_list.append([-1, 9999])
			return bin_list, 0
		maximum = 0
		minimum = 99999
		for row in data_list:
			if row[column_number] > maximum:
				maximum = row[column_number]
			elif row[column_number] < minimum:
				minimum = row[column_number]
		bin_range = (maximum - minimum) / float((total_bins-3))
		x = 0
		for y in range(2, total_bins-1):
			bin_list.append([minimum + x*bin_range + (bin_range/2.0), minimum + (x+1)*bin_range + (bin_range/2.0)])
			x += 1
		bin_list.insert(0, [-999, minimum - (bin_range / 2.0)])
		bin_list.insert(1, [minimum - (bin_range / 2.0), minimum + (bin_range / 2.0)])
		bin_list.append([minimum + x * bin_range + (bin_range/2.0), 9999.0])
		return bin_list, bin_range

	@staticmethod
	def change_data(column_bin_dic, data_dic):
		""" changes the data to the bin number indicating which bin does the data goes in
		
			Parameters
			--------------------------------------------------
			column_bin_dic :    dictionary

			data_dic       :    dictionary
							    
		    Returns
		   	--------------------------------------------------
			data_dic  : dictionary
		                
		"""
		
		for labels in data_dic:
			for column in range(0, len(data_dic[labels][0])):
				for row in data_dic[labels]:
					index = 0
					for bin_range in column_bin_dic[labels][column]:
						if (row[column] >= bin_range[0]) and (row[column] < bin_range[1]):
							row[column] = index
							break
						index += 1
		return data_dic

	@staticmethod
	def probability_of_classifiers(unique_labels, total_number_of_rows, data_dic):
		"""Calculates probability of class labels

		Parameters
		--------------------------------------------------
		unique_labels        :    list
					  contains list of unique class labels.
		total_number_of_rows :    int
					  number of samples in the training data
		data_dic	     :    dictionary

		Returns
		--------------------------------------------------
		probability_dic      : 	dictionary
					class labels are key and their probabilities are dictionary
		"""
		probability_dic = {}
		for labels in unique_labels:
			probability = len(data_dic[labels]) / float(total_number_of_rows)
			probability_dic[labels] = probability
		return probability_dic

	@staticmethod
	def add_to_dictionary(probability, label, column, column_value, classifier_dic):
		if column in classifier_dic:
			if column_value in classifier_dic[column]:
				if label in classifier_dic[column][column_value]:
					classifier_dic[column][column_value][label] = probability
				else:
					inside_dic = {}
					inside_dic[label] = probability
					classifier_dic[column][column_value][label] = probability
			else:
				out_dic = {}
				inside_dic = {}
				inside_dic[label] = probability
				out_dic[column_value] = inside_dic
				classifier_dic[column][column_value] = inside_dic
		else:
			outer_dic = {}
			out_dic = {}
			inside_dic = {}
			inside_dic[label] = probability
			out_dic[column_value] = inside_dic
			outer_dic[column] = out_dic
			classifier_dic[column] = out_dic
		return classifier_dic

	@staticmethod
	def calculate_conditional_probability(data_dic, number_of_bins, bin_range):
		"""calcualtes the conditional probability of P(bin|class)

		Parameters
		--------------------------------------------------
		data_dic        :    dictionary
					         
		number_of_bins  :    int
				     number of bins for the dimension
		bin_range       :    int
				     bin range of the dimension
					         
		Returns
		--------------------------------------------------
		classifier_dic	: dictionary
		"""
		
		classifier_dic = {}
		for labels in data_dic:
			for column in range(0, len(data_dic[labels][0])):
				bin_count = {}
				row_count = 0
				for row in data_dic[labels]:
					if row[column] in bin_count:
						bin_count[row[column]] += 1
					else:
						bin_count[row[column]] = 1
					row_count += 1
				for bins in range(0, number_of_bins):
					if bins in bin_count:
						if bin_range[labels][column] == 0:
							bin_range[labels][column] = 0.1
						pro = (bin_count[bins] / (float(row_count) * bin_range[labels][column]))
						print("Class %d, attribute %d, bin %d, P(bin | class) = %.2f" % (labels, column, bins, pro))
						classifier_dic = HistogramTraining.add_to_dictionary(pro, labels, column, bins, classifier_dic)
					else:
						print("Class %d, attribute %d, bin %d, P(bin | class) = %.2f" % (labels, column, bins, 0 / row_count))
						classifier_dic = HistogramTraining.add_to_dictionary(0, labels, column, bins, classifier_dic)
		return classifier_dic


class HistogramClassification:
	def __init__(self, probability_dic, classifier_dic, column_dic, unique_labels, column_bin_dic):
		self.probability_dic = probability_dic
		self.classifier_dic = classifier_dic
		self.column_dic = column_dic
		self.unique_labels = unique_labels
		self.correctly_classifed = 0
		self.column_bin_dic = column_bin_dic

	def classify(self, data_row):
		"""classifies a new data

		Parameters
		----------
		data_row 	:    list
				         contains unknown data to be classified
		"""
		
		result = {}
		for label in self.unique_labels:
			for column in range(0, len(data_row)-2):
				data = data_row[0:]
				index = 0
				for bin_range in self.column_bin_dic[label][column]:
					if (data[column] >= bin_range[0]) and (data[column] < bin_range[1]):
						data[column] = index
						break
					index += 1
				if label in result:
					result[label] *= self.classifier_dic[column][data[column]][label]
				else:
					result[label] = self.classifier_dic[column][data[column]][label] * self.probability_dic[label]
		summation = sum(result.values())
		for label in result:
			if summation == 0:
				break
			result[label] /= float(summation)
		maximum = -9999
		for label in result:
			if result[label] > maximum:
				predicted = label
				maximum = result[label]

		accuracy = 0
		if predicted == data_row[-2]:
			accuracy = 1
		self.correctly_classifed += accuracy
		print("ID = %5d, predicted = %3d, probability = %.4f, true=%3d, accuracy=%4.2f" % (data_row[-1], predicted, result[predicted], data_row[-2], accuracy))

	def display_accuracy(self, number_of_test_rows):
		print("classification accuracy=%6.4lf" % (self.correctly_classifed / float(number_of_test_rows)))


def load_data_set(filename):
	"""Loads the training data from a file to the dictionary

		Parameters
		--------------------------------------------------
		filename   :   string
			       file path of training data

		Returns
		--------------------------------------------------
		dictionary    : dictionary
				class label as key : list of rows as value
		unique_labels : list
		 		list of unique labels in the training data
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
	"""
	
	data_list = []
	input_file = open(filename, "r")
	unique_labels = []
	dictionary = {}
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list)
		if row_list[-1] in dictionary:
			dictionary[row_list[-1]].append(row_list[0:-1])
		else:
			unique_labels.append(row_list[-1])
			dictionary[row_list[-1]] = [row_list[0:-1]]
		loop_count += 1
	return dictionary, unique_labels, loop_count, data_list


def load_test_set(filename):
	"""Loads the testing data from a file to the dictionary

		Parameters
		----------
		filename   :   string
			       File path of training data

		Returns
		-------
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
	"""
	
	data_list = []
	input_file = open(filename, "r")
	print("⤵\n")
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list+[loop_count])
		loop_count += 1
	return loop_count, data_list


def main():
	
	input_line = input()  							# Taking file path from user as input
	print("⤵\n")
	input_list = input_line.split()  				# converting  the input to a list

	histogram = Histogram(input_list[1], input_list[2], int((input_list[4])))
	histogram.train()
	histogram.test()

main()


# ▶ Run and Enter ➜ naive_bayes data/yeast_training.txt data/yeast_test.txt histograms 7
# or
# ▶ Run and Enter ➜ naive_bayes data/satellite_training.txt data/satellite_test.txt histograms 7
# or
# ▶ Run and Enter ➜ naive_bayes data/pendigits_training.txt data/pendigits_test.txt histograms 7
# Out:
# naive_bayes data/yeast_training.txt data/yeast_test.txt histograms 7
# ⤵
#
# Class 1, attribute 0, bin 0, P(bin | class) = 0.00
# Class 1, attribute 0, bin 1, P(bin | class) = 0.16
# Class 1, attribute 0, bin 2, P(bin | class) = 1.10
# Class 1, attribute 0, bin 3, P(bin | class) = 4.24
# Class 1, attribute 0, bin 4, P(bin | class) = 1.22
# Class 1, attribute 0, bin 5, P(bin | class) = 0.16
# Class 1, attribute 0, bin 6, P(bin | class) = 0.00
# Class 1, attribute 1, bin 0, P(bin | class) = 0.00
# Class 1, attribute 1, bin 1, P(bin | class) = 0.06
# Class 1, attribute 1, bin 2, P(bin | class) = 1.27
# Class 1, attribute 1, bin 3, P(bin | class) = 3.32
# Class 1, attribute 1, bin 4, P(bin | class) = 0.20
# Class 1, attribute 1, bin 5, P(bin | class) = 0.03
# Class 1, attribute 1, bin 6, P(bin | class) = 0.00
# Class 1, attribute 2, bin 0, P(bin | class) = 0.00
# Class 1, attribute 2, bin 1, P(bin | class) = 0.33
# Class 1, attribute 2, bin 2, P(bin | class) = 1.32
# Class 1, attribute 2, bin 3, P(bin | class) = 5.06
# Class 1, attribute 2, bin 4, P(bin | class) = 2.42
# Class 1, attribute 2, bin 5, P(bin | class) = 0.17
# Class 1, attribute 2, bin 6, P(bin | class) = 0.00
# Class 1, attribute 3, bin 0, P(bin | class) = 0.00
# Class 1, attribute 3, bin 1, P(bin | class) = 0.81
# Class 1, attribute 3, bin 2, P(bin | class) = 1.46
# Class 1, attribute 3, bin 3, P(bin | class) = 2.12
# Class 1, attribute 3, bin 4, P(bin | class) = 0.81
# Class 1, attribute 3, bin 5, P(bin | class) = 0.06
# Class 1, attribute 3, bin 6, P(bin | class) = 0.00
# Class 1, attribute 4, bin 0, P(bin | class) = 0.00
# Class 1, attribute 4, bin 1, P(bin | class) = 0.00
# Class 1, attribute 4, bin 2, P(bin | class) = 0.00
# Class 1, attribute 4, bin 3, P(bin | class) = 0.00
# Class 1, attribute 4, bin 4, P(bin | class) = 0.00
# Class 1, attribute 4, bin 5, P(bin | class) = 0.00
# Class 1, attribute 4, bin 6, P(bin | class) = 10.00
# Class 1, attribute 5, bin 0, P(bin | class) = 0.00
# Class 1, attribute 5, bin 1, P(bin | class) = 0.00
# Class 1, attribute 5, bin 2, P(bin | class) = 0.00
# Class 1, attribute 5, bin 3, P(bin | class) = 0.00
# Class 1, attribute 5, bin 4, P(bin | class) = 0.00
# Class 1, attribute 5, bin 5, P(bin | class) = 0.00
# Class 1, attribute 5, bin 6, P(bin | class) = 10.00
# Class 1, attribute 6, bin 0, P(bin | class) = 0.00
# Class 1, attribute 6, bin 1, P(bin | class) = 0.06
# Class 1, attribute 6, bin 2, P(bin | class) = 0.55
# Class 1, attribute 6, bin 3, P(bin | class) = 5.72
# Class 1, attribute 6, bin 4, P(bin | class) = 2.92
# Class 1, attribute 6, bin 5, P(bin | class) = 0.06
# Class 1, attribute 6, bin 6, P(bin | class) = 0.00
# Class 1, attribute 7, bin 0, P(bin | class) = 0.00
# Class 1, attribute 7, bin 1, P(bin | class) = 0.09
# Class 1, attribute 7, bin 2, P(bin | class) = 6.83
# Class 1, attribute 7, bin 3, P(bin | class) = 0.58
# Class 1, attribute 7, bin 4, P(bin | class) = 0.00
# Class 1, attribute 7, bin 5, P(bin | class) = 0.04
# Class 1, attribute 7, bin 6, P(bin | class) = 0.00
# Class 3, attribute 0, bin 0, P(bin | class) = 0.00
# Class 3, attribute 0, bin 1, P(bin | class) = 0.37
# Class 3, attribute 0, bin 2, P(bin | class) = 2.22
# Class 3, attribute 0, bin 3, P(bin | class) = 3.61
# Class 3, attribute 0, bin 4, P(bin | class) = 2.13
# Class 3, attribute 0, bin 5, P(bin | class) = 0.56
# Class 3, attribute 0, bin 6, P(bin | class) = 0.00
# Class 3, attribute 1, bin 0, P(bin | class) = 0.00
# Class 3, attribute 1, bin 1, P(bin | class) = 0.07
# Class 3, attribute 1, bin 2, P(bin | class) = 0.89
# Class 3, attribute 1, bin 3, P(bin | class) = 3.35
# Class 3, attribute 1, bin 4, P(bin | class) = 2.05
# Class 3, attribute 1, bin 5, P(bin | class) = 0.20
# Class 3, attribute 1, bin 6, P(bin | class) = 0.00
# Class 3, attribute 2, bin 0, P(bin | class) = 0.00
# Class 3, attribute 2, bin 1, P(bin | class) = 0.57
# Class 3, attribute 2, bin 2, P(bin | class) = 2.01
# Class 3, attribute 2, bin 3, P(bin | class) = 7.90
# Class 3, attribute 2, bin 4, P(bin | class) = 2.87
# Class 3, attribute 2, bin 5, P(bin | class) = 0.43
# Class 3, attribute 2, bin 6, P(bin | class) = 0.00
# Class 3, attribute 3, bin 0, P(bin | class) = 0.00
# Class 3, attribute 3, bin 1, P(bin | class) = 1.42
# Class 3, attribute 3, bin 2, P(bin | class) = 5.30
# Class 3, attribute 3, bin 3, P(bin | class) = 1.99
# Class 3, attribute 3, bin 4, P(bin | class) = 0.28
# Class 3, attribute 3, bin 5, P(bin | class) = 0.09
# Class 3, attribute 3, bin 6, P(bin | class) = 0.00
# Class 3, attribute 4, bin 0, P(bin | class) = 0.00
# Class 3, attribute 4, bin 1, P(bin | class) = 7.92
# Class 3, attribute 4, bin 2, P(bin | class) = 0.00
# Class 3, attribute 4, bin 3, P(bin | class) = 0.00
# Class 3, attribute 4, bin 4, P(bin | class) = 0.00
# Class 3, attribute 4, bin 5, P(bin | class) = 0.08
# Class 3, attribute 4, bin 6, P(bin | class) = 0.00
# Class 3, attribute 5, bin 0, P(bin | class) = 0.00
# Class 3, attribute 5, bin 1, P(bin | class) = 0.00
# Class 3, attribute 5, bin 2, P(bin | class) = 0.00
# Class 3, attribute 5, bin 3, P(bin | class) = 0.00
# Class 3, attribute 5, bin 4, P(bin | class) = 0.00
# Class 3, attribute 5, bin 5, P(bin | class) = 0.00
# Class 3, attribute 5, bin 6, P(bin | class) = 10.00
# Class 3, attribute 6, bin 0, P(bin | class) = 0.00
# Class 3, attribute 6, bin 1, P(bin | class) = 0.69
# Class 3, attribute 6, bin 2, P(bin | class) = 0.93
# Class 3, attribute 6, bin 3, P(bin | class) = 5.56
# Class 3, attribute 6, bin 4, P(bin | class) = 11.81
# Class 3, attribute 6, bin 5, P(bin | class) = 3.24
# Class 3, attribute 6, bin 6, P(bin | class) = 0.00
# Class 3, attribute 7, bin 0, P(bin | class) = 0.00
# Class 3, attribute 7, bin 1, P(bin | class) = 4.85
# Class 3, attribute 7, bin 2, P(bin | class) = 1.30
# Class 3, attribute 7, bin 3, P(bin | class) = 0.34
# Class 3, attribute 7, bin 4, P(bin | class) = 0.00
# Class 3, attribute 7, bin 5, P(bin | class) = 0.07
# Class 3, attribute 7, bin 6, P(bin | class) = 0.00
# Class 2, attribute 0, bin 0, P(bin | class) = 0.00
# Class 2, attribute 0, bin 1, P(bin | class) = 0.19
# Class 2, attribute 0, bin 2, P(bin | class) = 2.38
# Class 2, attribute 0, bin 3, P(bin | class) = 2.66
# Class 2, attribute 0, bin 4, P(bin | class) = 0.20
# Class 2, attribute 0, bin 5, P(bin | class) = 0.06
# Class 2, attribute 0, bin 6, P(bin | class) = 0.00
# Class 2, attribute 1, bin 0, P(bin | class) = 0.00
# Class 2, attribute 1, bin 1, P(bin | class) = 0.17
# Class 2, attribute 1, bin 2, P(bin | class) = 1.97
# Class 2, attribute 1, bin 3, P(bin | class) = 3.28
# Class 2, attribute 1, bin 4, P(bin | class) = 0.98
# Class 2, attribute 1, bin 5, P(bin | class) = 0.04
# Class 2, attribute 1, bin 6, P(bin | class) = 0.00
# Class 2, attribute 2, bin 0, P(bin | class) = 0.00
# Class 2, attribute 2, bin 1, P(bin | class) = 0.08
# Class 2, attribute 2, bin 2, P(bin | class) = 0.56
# Class 2, attribute 2, bin 3, P(bin | class) = 5.82
# Class 2, attribute 2, bin 4, P(bin | class) = 4.55
# Class 2, attribute 2, bin 5, P(bin | class) = 0.76
# Class 2, attribute 2, bin 6, P(bin | class) = 0.00
# Class 2, attribute 3, bin 0, P(bin | class) = 0.00
# Class 2, attribute 3, bin 1, P(bin | class) = 0.19
# Class 2, attribute 3, bin 2, P(bin | class) = 3.74
# Class 2, attribute 3, bin 3, P(bin | class) = 0.66
# Class 2, attribute 3, bin 4, P(bin | class) = 0.03
# Class 2, attribute 3, bin 5, P(bin | class) = 0.03
# Class 2, attribute 3, bin 6, P(bin | class) = 0.00
# Class 2, attribute 4, bin 0, P(bin | class) = 0.00
# Class 2, attribute 4, bin 1, P(bin | class) = 7.95
# Class 2, attribute 4, bin 2, P(bin | class) = 0.00
# Class 2, attribute 4, bin 3, P(bin | class) = 0.00
# Class 2, attribute 4, bin 4, P(bin | class) = 0.00
# Class 2, attribute 4, bin 5, P(bin | class) = 0.05
# Class 2, attribute 4, bin 6, P(bin | class) = 0.00
# Class 2, attribute 5, bin 0, P(bin | class) = 0.00
# Class 2, attribute 5, bin 1, P(bin | class) = 0.00
# Class 2, attribute 5, bin 2, P(bin | class) = 0.00
# Class 2, attribute 5, bin 3, P(bin | class) = 0.00
# Class 2, attribute 5, bin 4, P(bin | class) = 0.00
# Class 2, attribute 5, bin 5, P(bin | class) = 0.00
# Class 2, attribute 5, bin 6, P(bin | class) = 10.00
# Class 2, attribute 6, bin 0, P(bin | class) = 0.00
# Class 2, attribute 6, bin 1, P(bin | class) = 0.03
# Class 2, attribute 6, bin 2, P(bin | class) = 0.13
# Class 2, attribute 6, bin 3, P(bin | class) = 1.88
# Class 2, attribute 6, bin 4, P(bin | class) = 5.32
# Class 2, attribute 6, bin 5, P(bin | class) = 0.05
# Class 2, attribute 6, bin 6, P(bin | class) = 0.00
# Class 2, attribute 7, bin 0, P(bin | class) = 0.00
# Class 2, attribute 7, bin 1, P(bin | class) = 2.02
# Class 2, attribute 7, bin 2, P(bin | class) = 2.11
# Class 2, attribute 7, bin 3, P(bin | class) = 0.50
# Class 2, attribute 7, bin 4, P(bin | class) = 0.10
# Class 2, attribute 7, bin 5, P(bin | class) = 0.03
# Class 2, attribute 7, bin 6, P(bin | class) = 0.00
# Class 4, attribute 0, bin 0, P(bin | class) = 0.00
# Class 4, attribute 0, bin 1, P(bin | class) = 1.89
# Class 4, attribute 0, bin 2, P(bin | class) = 5.30
# Class 4, attribute 0, bin 3, P(bin | class) = 3.41
# Class 4, attribute 0, bin 4, P(bin | class) = 1.14
# Class 4, attribute 0, bin 5, P(bin | class) = 0.38
# Class 4, attribute 0, bin 6, P(bin | class) = 0.00
# Class 4, attribute 1, bin 0, P(bin | class) = 0.00
# Class 4, attribute 1, bin 1, P(bin | class) = 1.44
# Class 4, attribute 1, bin 2, P(bin | class) = 2.88
# Class 4, attribute 1, bin 3, P(bin | class) = 5.29
# Class 4, attribute 1, bin 4, P(bin | class) = 3.85
# Class 4, attribute 1, bin 5, P(bin | class) = 1.92
# Class 4, attribute 1, bin 6, P(bin | class) = 0.00
# Class 4, attribute 2, bin 0, P(bin | class) = 0.00
# Class 4, attribute 2, bin 1, P(bin | class) = 2.00
# Class 4, attribute 2, bin 2, P(bin | class) = 6.50
# Class 4, attribute 2, bin 3, P(bin | class) = 3.00
# Class 4, attribute 2, bin 4, P(bin | class) = 4.00
# Class 4, attribute 2, bin 5, P(bin | class) = 0.50
# Class 4, attribute 2, bin 6, P(bin | class) = 0.00
# Class 4, attribute 3, bin 0, P(bin | class) = 0.00
# Class 4, attribute 3, bin 1, P(bin | class) = 0.20
# Class 4, attribute 3, bin 2, P(bin | class) = 3.83
# Class 4, attribute 3, bin 3, P(bin | class) = 2.02
# Class 4, attribute 3, bin 4, P(bin | class) = 0.20
# Class 4, attribute 3, bin 5, P(bin | class) = 0.20
# Class 4, attribute 3, bin 6, P(bin | class) = 0.00
# Class 4, attribute 4, bin 0, P(bin | class) = 0.00
# Class 4, attribute 4, bin 1, P(bin | class) = 0.00
# Class 4, attribute 4, bin 2, P(bin | class) = 0.00
# Class 4, attribute 4, bin 3, P(bin | class) = 0.00
# Class 4, attribute 4, bin 4, P(bin | class) = 0.00
# Class 4, attribute 4, bin 5, P(bin | class) = 0.00
# Class 4, attribute 4, bin 6, P(bin | class) = 10.00
# Class 4, attribute 5, bin 0, P(bin | class) = 0.00
# Class 4, attribute 5, bin 1, P(bin | class) = 0.00
# Class 4, attribute 5, bin 2, P(bin | class) = 0.00
# Class 4, attribute 5, bin 3, P(bin | class) = 0.00
# Class 4, attribute 5, bin 4, P(bin | class) = 0.00
# Class 4, attribute 5, bin 5, P(bin | class) = 0.00
# Class 4, attribute 5, bin 6, P(bin | class) = 10.00
# Class 4, attribute 6, bin 0, P(bin | class) = 0.00
# Class 4, attribute 6, bin 1, P(bin | class) = 0.39
# Class 4, attribute 6, bin 2, P(bin | class) = 0.39
# Class 4, attribute 6, bin 3, P(bin | class) = 1.56
# Class 4, attribute 6, bin 4, P(bin | class) = 7.03
# Class 4, attribute 6, bin 5, P(bin | class) = 3.13
# Class 4, attribute 6, bin 6, P(bin | class) = 0.00
# Class 4, attribute 7, bin 0, P(bin | class) = 0.00
# Class 4, attribute 7, bin 1, P(bin | class) = 6.40
# Class 4, attribute 7, bin 2, P(bin | class) = 2.13
# Class 4, attribute 7, bin 3, P(bin | class) = 0.91
# Class 4, attribute 7, bin 4, P(bin | class) = 0.00
# Class 4, attribute 7, bin 5, P(bin | class) = 0.30
# Class 4, attribute 7, bin 6, P(bin | class) = 0.00
# Class 7, attribute 0, bin 0, P(bin | class) = 0.00
# Class 7, attribute 0, bin 1, P(bin | class) = 0.15
# Class 7, attribute 0, bin 2, P(bin | class) = 1.70
# Class 7, attribute 0, bin 3, P(bin | class) = 3.22
# Class 7, attribute 0, bin 4, P(bin | class) = 1.49
# Class 7, attribute 0, bin 5, P(bin | class) = 0.11
# Class 7, attribute 0, bin 6, P(bin | class) = 0.00
# Class 7, attribute 1, bin 0, P(bin | class) = 0.00
# Class 7, attribute 1, bin 1, P(bin | class) = 0.12
# Class 7, attribute 1, bin 2, P(bin | class) = 2.23
# Class 7, attribute 1, bin 3, P(bin | class) = 3.64
# Class 7, attribute 1, bin 4, P(bin | class) = 0.54
# Class 7, attribute 1, bin 5, P(bin | class) = 0.02
# Class 7, attribute 1, bin 6, P(bin | class) = 0.00
# Class 7, attribute 2, bin 0, P(bin | class) = 0.00
# Class 7, attribute 2, bin 1, P(bin | class) = 0.60
# Class 7, attribute 2, bin 2, P(bin | class) = 5.46
# Class 7, attribute 2, bin 3, P(bin | class) = 0.46
# Class 7, attribute 2, bin 4, P(bin | class) = 0.02
# Class 7, attribute 2, bin 5, P(bin | class) = 0.02
# Class 7, attribute 2, bin 6, P(bin | class) = 0.00
# Class 7, attribute 3, bin 0, P(bin | class) = 0.00
# Class 7, attribute 3, bin 1, P(bin | class) = 0.43
# Class 7, attribute 3, bin 2, P(bin | class) = 3.22
# Class 7, attribute 3, bin 3, P(bin | class) = 0.28
# Class 7, attribute 3, bin 4, P(bin | class) = 0.06
# Class 7, attribute 3, bin 5, P(bin | class) = 0.01
# Class 7, attribute 3, bin 6, P(bin | class) = 0.00
# Class 7, attribute 4, bin 0, P(bin | class) = 0.00
# Class 7, attribute 4, bin 1, P(bin | class) = 7.95
# Class 7, attribute 4, bin 2, P(bin | class) = 0.00
# Class 7, attribute 4, bin 3, P(bin | class) = 0.00
# Class 7, attribute 4, bin 4, P(bin | class) = 0.00
# Class 7, attribute 4, bin 5, P(bin | class) = 0.05
# Class 7, attribute 4, bin 6, P(bin | class) = 0.00
# Class 7, attribute 5, bin 0, P(bin | class) = 0.00
# Class 7, attribute 5, bin 1, P(bin | class) = 7.97
# Class 7, attribute 5, bin 2, P(bin | class) = 0.00
# Class 7, attribute 5, bin 3, P(bin | class) = 0.00
# Class 7, attribute 5, bin 4, P(bin | class) = 0.00
# Class 7, attribute 5, bin 5, P(bin | class) = 0.03
# Class 7, attribute 5, bin 6, P(bin | class) = 0.00
# Class 7, attribute 6, bin 0, P(bin | class) = 0.00
# Class 7, attribute 6, bin 1, P(bin | class) = 0.02
# Class 7, attribute 6, bin 2, P(bin | class) = 0.21
# Class 7, attribute 6, bin 3, P(bin | class) = 2.99
# Class 7, attribute 6, bin 4, P(bin | class) = 3.39
# Class 7, attribute 6, bin 5, P(bin | class) = 0.06
# Class 7, attribute 6, bin 6, P(bin | class) = 0.00
# Class 7, attribute 7, bin 0, P(bin | class) = 0.00
# Class 7, attribute 7, bin 1, P(bin | class) = 0.03
# Class 7, attribute 7, bin 2, P(bin | class) = 4.06
# Class 7, attribute 7, bin 3, P(bin | class) = 0.86
# Class 7, attribute 7, bin 4, P(bin | class) = 0.05
# Class 7, attribute 7, bin 5, P(bin | class) = 0.06
# Class 7, attribute 7, bin 6, P(bin | class) = 0.00
# Class 8, attribute 0, bin 0, P(bin | class) = 0.00
# Class 8, attribute 0, bin 1, P(bin | class) = 0.40
# Class 8, attribute 0, bin 2, P(bin | class) = 0.40
# Class 8, attribute 0, bin 3, P(bin | class) = 0.79
# Class 8, attribute 0, bin 4, P(bin | class) = 5.53
# Class 8, attribute 0, bin 5, P(bin | class) = 1.58
# Class 8, attribute 0, bin 6, P(bin | class) = 0.00
# Class 8, attribute 1, bin 0, P(bin | class) = 0.00
# Class 8, attribute 1, bin 1, P(bin | class) = 0.38
# Class 8, attribute 1, bin 2, P(bin | class) = 0.00
# Class 8, attribute 1, bin 3, P(bin | class) = 1.52
# Class 8, attribute 1, bin 4, P(bin | class) = 4.17
# Class 8, attribute 1, bin 5, P(bin | class) = 2.27
# Class 8, attribute 1, bin 6, P(bin | class) = 0.00
# Class 8, attribute 2, bin 0, P(bin | class) = 0.00
# Class 8, attribute 2, bin 1, P(bin | class) = 0.91
# Class 8, attribute 2, bin 2, P(bin | class) = 2.73
# Class 8, attribute 2, bin 3, P(bin | class) = 8.18
# Class 8, attribute 2, bin 4, P(bin | class) = 5.45
# Class 8, attribute 2, bin 5, P(bin | class) = 2.73
# Class 8, attribute 2, bin 6, P(bin | class) = 0.00
# Class 8, attribute 3, bin 0, P(bin | class) = 0.00
# Class 8, attribute 3, bin 1, P(bin | class) = 0.76
# Class 8, attribute 3, bin 2, P(bin | class) = 3.79
# Class 8, attribute 3, bin 3, P(bin | class) = 6.06
# Class 8, attribute 3, bin 4, P(bin | class) = 3.03
# Class 8, attribute 3, bin 5, P(bin | class) = 3.03
# Class 8, attribute 3, bin 6, P(bin | class) = 0.00
# Class 8, attribute 4, bin 0, P(bin | class) = 0.00
# Class 8, attribute 4, bin 1, P(bin | class) = 0.00
# Class 8, attribute 4, bin 2, P(bin | class) = 0.00
# Class 8, attribute 4, bin 3, P(bin | class) = 0.00
# Class 8, attribute 4, bin 4, P(bin | class) = 0.00
# Class 8, attribute 4, bin 5, P(bin | class) = 0.00
# Class 8, attribute 4, bin 6, P(bin | class) = 10.00
# Class 8, attribute 5, bin 0, P(bin | class) = 0.00
# Class 8, attribute 5, bin 1, P(bin | class) = 0.00
# Class 8, attribute 5, bin 2, P(bin | class) = 0.00
# Class 8, attribute 5, bin 3, P(bin | class) = 0.00
# Class 8, attribute 5, bin 4, P(bin | class) = 0.00
# Class 8, attribute 5, bin 5, P(bin | class) = 0.00
# Class 8, attribute 5, bin 6, P(bin | class) = 10.00
# Class 8, attribute 6, bin 0, P(bin | class) = 0.00
# Class 8, attribute 6, bin 1, P(bin | class) = 0.57
# Class 8, attribute 6, bin 2, P(bin | class) = 1.70
# Class 8, attribute 6, bin 3, P(bin | class) = 2.27
# Class 8, attribute 6, bin 4, P(bin | class) = 6.82
# Class 8, attribute 6, bin 5, P(bin | class) = 1.14
# Class 8, attribute 6, bin 6, P(bin | class) = 0.00
# Class 8, attribute 7, bin 0, P(bin | class) = 0.00
# Class 8, attribute 7, bin 1, P(bin | class) = 69.09
# Class 8, attribute 7, bin 2, P(bin | class) = 0.00
# Class 8, attribute 7, bin 3, P(bin | class) = 0.00
# Class 8, attribute 7, bin 4, P(bin | class) = 3.64
# Class 8, attribute 7, bin 5, P(bin | class) = 7.27
# Class 8, attribute 7, bin 6, P(bin | class) = 0.00
# Class 5, attribute 0, bin 0, P(bin | class) = 0.00
# Class 5, attribute 0, bin 1, P(bin | class) = 0.36
# Class 5, attribute 0, bin 2, P(bin | class) = 0.73
# Class 5, attribute 0, bin 3, P(bin | class) = 1.45
# Class 5, attribute 0, bin 4, P(bin | class) = 3.08
# Class 5, attribute 0, bin 5, P(bin | class) = 0.73
# Class 5, attribute 0, bin 6, P(bin | class) = 0.00
# Class 5, attribute 1, bin 0, P(bin | class) = 0.00
# Class 5, attribute 1, bin 1, P(bin | class) = 0.61
# Class 5, attribute 1, bin 2, P(bin | class) = 1.22
# Class 5, attribute 1, bin 3, P(bin | class) = 3.27
# Class 5, attribute 1, bin 4, P(bin | class) = 1.84
# Class 5, attribute 1, bin 5, P(bin | class) = 0.20
# Class 5, attribute 1, bin 6, P(bin | class) = 0.00
# Class 5, attribute 2, bin 0, P(bin | class) = 0.00
# Class 5, attribute 2, bin 1, P(bin | class) = 0.69
# Class 5, attribute 2, bin 2, P(bin | class) = 4.85
# Class 5, attribute 2, bin 3, P(bin | class) = 3.81
# Class 5, attribute 2, bin 4, P(bin | class) = 1.39
# Class 5, attribute 2, bin 5, P(bin | class) = 1.39
# Class 5, attribute 2, bin 6, P(bin | class) = 0.00
# Class 5, attribute 3, bin 0, P(bin | class) = 0.00
# Class 5, attribute 3, bin 1, P(bin | class) = 1.63
# Class 5, attribute 3, bin 2, P(bin | class) = 3.54
# Class 5, attribute 3, bin 3, P(bin | class) = 1.63
# Class 5, attribute 3, bin 4, P(bin | class) = 1.63
# Class 5, attribute 3, bin 5, P(bin | class) = 1.09
# Class 5, attribute 3, bin 6, P(bin | class) = 0.00
# Class 5, attribute 4, bin 0, P(bin | class) = 0.00
# Class 5, attribute 4, bin 1, P(bin | class) = 0.00
# Class 5, attribute 4, bin 2, P(bin | class) = 0.00
# Class 5, attribute 4, bin 3, P(bin | class) = 0.00
# Class 5, attribute 4, bin 4, P(bin | class) = 0.00
# Class 5, attribute 4, bin 5, P(bin | class) = 0.00
# Class 5, attribute 4, bin 6, P(bin | class) = 10.00
# Class 5, attribute 5, bin 0, P(bin | class) = 0.00
# Class 5, attribute 5, bin 1, P(bin | class) = 0.00
# Class 5, attribute 5, bin 2, P(bin | class) = 0.00
# Class 5, attribute 5, bin 3, P(bin | class) = 0.00
# Class 5, attribute 5, bin 4, P(bin | class) = 0.00
# Class 5, attribute 5, bin 5, P(bin | class) = 0.00
# Class 5, attribute 5, bin 6, P(bin | class) = 10.00
# Class 5, attribute 6, bin 0, P(bin | class) = 0.00
# Class 5, attribute 6, bin 1, P(bin | class) = 0.38
# Class 5, attribute 6, bin 2, P(bin | class) = 0.76
# Class 5, attribute 6, bin 3, P(bin | class) = 1.14
# Class 5, attribute 6, bin 4, P(bin | class) = 10.29
# Class 5, attribute 6, bin 5, P(bin | class) = 0.76
# Class 5, attribute 6, bin 6, P(bin | class) = 0.00
# Class 5, attribute 7, bin 0, P(bin | class) = 0.00
# Class 5, attribute 7, bin 1, P(bin | class) = 18.82
# Class 5, attribute 7, bin 2, P(bin | class) = 2.02
# Class 5, attribute 7, bin 3, P(bin | class) = 1.34
# Class 5, attribute 7, bin 4, P(bin | class) = 0.67
# Class 5, attribute 7, bin 5, P(bin | class) = 0.67
# Class 5, attribute 7, bin 6, P(bin | class) = 0.00
# Class 6, attribute 0, bin 0, P(bin | class) = 0.00
# Class 6, attribute 0, bin 1, P(bin | class) = 1.90
# Class 6, attribute 0, bin 2, P(bin | class) = 3.81
# Class 6, attribute 0, bin 3, P(bin | class) = 0.63
# Class 6, attribute 0, bin 4, P(bin | class) = 1.90
# Class 6, attribute 0, bin 5, P(bin | class) = 0.63
# Class 6, attribute 0, bin 6, P(bin | class) = 0.00
# Class 6, attribute 1, bin 0, P(bin | class) = 0.00
# Class 6, attribute 1, bin 1, P(bin | class) = 0.60
# Class 6, attribute 1, bin 2, P(bin | class) = 2.38
# Class 6, attribute 1, bin 3, P(bin | class) = 2.98
# Class 6, attribute 1, bin 4, P(bin | class) = 1.79
# Class 6, attribute 1, bin 5, P(bin | class) = 0.60
# Class 6, attribute 1, bin 6, P(bin | class) = 0.00
# Class 6, attribute 2, bin 0, P(bin | class) = 0.00
# Class 6, attribute 2, bin 1, P(bin | class) = 5.36
# Class 6, attribute 2, bin 2, P(bin | class) = 5.36
# Class 6, attribute 2, bin 3, P(bin | class) = 7.14
# Class 6, attribute 2, bin 4, P(bin | class) = 3.57
# Class 6, attribute 2, bin 5, P(bin | class) = 3.57
# Class 6, attribute 2, bin 6, P(bin | class) = 0.00
# Class 6, attribute 3, bin 0, P(bin | class) = 0.00
# Class 6, attribute 3, bin 1, P(bin | class) = 1.73
# Class 6, attribute 3, bin 2, P(bin | class) = 6.93
# Class 6, attribute 3, bin 3, P(bin | class) = 1.73
# Class 6, attribute 3, bin 4, P(bin | class) = 0.00
# Class 6, attribute 3, bin 5, P(bin | class) = 1.73
# Class 6, attribute 3, bin 6, P(bin | class) = 0.00
# Class 6, attribute 4, bin 0, P(bin | class) = 0.00
# Class 6, attribute 4, bin 1, P(bin | class) = 0.00
# Class 6, attribute 4, bin 2, P(bin | class) = 0.00
# Class 6, attribute 4, bin 3, P(bin | class) = 0.00
# Class 6, attribute 4, bin 4, P(bin | class) = 0.00
# Class 6, attribute 4, bin 5, P(bin | class) = 0.00
# Class 6, attribute 4, bin 6, P(bin | class) = 10.00
# Class 6, attribute 5, bin 0, P(bin | class) = 0.00
# Class 6, attribute 5, bin 1, P(bin | class) = 1.72
# Class 6, attribute 5, bin 2, P(bin | class) = 0.00
# Class 6, attribute 5, bin 3, P(bin | class) = 0.69
# Class 6, attribute 5, bin 4, P(bin | class) = 0.00
# Class 6, attribute 5, bin 5, P(bin | class) = 2.41
# Class 6, attribute 5, bin 6, P(bin | class) = 0.00
# Class 6, attribute 6, bin 0, P(bin | class) = 0.00
# Class 6, attribute 6, bin 1, P(bin | class) = 2.20
# Class 6, attribute 6, bin 2, P(bin | class) = 0.00
# Class 6, attribute 6, bin 3, P(bin | class) = 10.99
# Class 6, attribute 6, bin 4, P(bin | class) = 8.79
# Class 6, attribute 6, bin 5, P(bin | class) = 8.79
# Class 6, attribute 6, bin 6, P(bin | class) = 0.00
# Class 6, attribute 7, bin 0, P(bin | class) = 0.00
# Class 6, attribute 7, bin 1, P(bin | class) = 18.05
# Class 6, attribute 7, bin 2, P(bin | class) = 1.50
# Class 6, attribute 7, bin 3, P(bin | class) = 0.00
# Class 6, attribute 7, bin 4, P(bin | class) = 0.00
# Class 6, attribute 7, bin 5, P(bin | class) = 1.50
# Class 6, attribute 7, bin 6, P(bin | class) = 0.00
# Class 9, attribute 0, bin 0, P(bin | class) = 0.00
# Class 9, attribute 0, bin 1, P(bin | class) = 1.70
# Class 9, attribute 0, bin 2, P(bin | class) = 3.41
# Class 9, attribute 0, bin 3, P(bin | class) = 0.00
# Class 9, attribute 0, bin 4, P(bin | class) = 3.41
# Class 9, attribute 0, bin 5, P(bin | class) = 0.57
# Class 9, attribute 0, bin 6, P(bin | class) = 0.00
# Class 9, attribute 1, bin 0, P(bin | class) = 0.00
# Class 9, attribute 1, bin 1, P(bin | class) = 2.00
# Class 9, attribute 1, bin 2, P(bin | class) = 1.50
# Class 9, attribute 1, bin 3, P(bin | class) = 1.50
# Class 9, attribute 1, bin 4, P(bin | class) = 2.00
# Class 9, attribute 1, bin 5, P(bin | class) = 1.00
# Class 9, attribute 1, bin 6, P(bin | class) = 0.00
# Class 9, attribute 2, bin 0, P(bin | class) = 0.00
# Class 9, attribute 2, bin 1, P(bin | class) = 1.09
# Class 9, attribute 2, bin 2, P(bin | class) = 1.09
# Class 9, attribute 2, bin 3, P(bin | class) = 4.35
# Class 9, attribute 2, bin 4, P(bin | class) = 6.52
# Class 9, attribute 2, bin 5, P(bin | class) = 4.35
# Class 9, attribute 2, bin 6, P(bin | class) = 0.00
# Class 9, attribute 3, bin 0, P(bin | class) = 0.00
# Class 9, attribute 3, bin 1, P(bin | class) = 1.14
# Class 9, attribute 3, bin 2, P(bin | class) = 6.82
# Class 9, attribute 3, bin 3, P(bin | class) = 3.41
# Class 9, attribute 3, bin 4, P(bin | class) = 3.41
# Class 9, attribute 3, bin 5, P(bin | class) = 3.41
# Class 9, attribute 3, bin 6, P(bin | class) = 0.00
# Class 9, attribute 4, bin 0, P(bin | class) = 0.00
# Class 9, attribute 4, bin 1, P(bin | class) = 0.00
# Class 9, attribute 4, bin 2, P(bin | class) = 0.00
# Class 9, attribute 4, bin 3, P(bin | class) = 0.00
# Class 9, attribute 4, bin 4, P(bin | class) = 0.00
# Class 9, attribute 4, bin 5, P(bin | class) = 0.00
# Class 9, attribute 4, bin 6, P(bin | class) = 10.00
# Class 9, attribute 5, bin 0, P(bin | class) = 0.00
# Class 9, attribute 5, bin 1, P(bin | class) = 0.00
# Class 9, attribute 5, bin 2, P(bin | class) = 0.00
# Class 9, attribute 5, bin 3, P(bin | class) = 0.00
# Class 9, attribute 5, bin 4, P(bin | class) = 0.00
# Class 9, attribute 5, bin 5, P(bin | class) = 0.00
# Class 9, attribute 5, bin 6, P(bin | class) = 10.00
# Class 9, attribute 6, bin 0, P(bin | class) = 0.00
# Class 9, attribute 6, bin 1, P(bin | class) = 1.09
# Class 9, attribute 6, bin 2, P(bin | class) = 0.00
# Class 9, attribute 6, bin 3, P(bin | class) = 7.61
# Class 9, attribute 6, bin 4, P(bin | class) = 6.52
# Class 9, attribute 6, bin 5, P(bin | class) = 2.17
# Class 9, attribute 6, bin 6, P(bin | class) = 0.00
# Class 9, attribute 7, bin 0, P(bin | class) = 0.00
# Class 9, attribute 7, bin 1, P(bin | class) = 15.28
# Class 9, attribute 7, bin 2, P(bin | class) = 5.56
# Class 9, attribute 7, bin 3, P(bin | class) = 0.00
# Class 9, attribute 7, bin 4, P(bin | class) = 0.00
# Class 9, attribute 7, bin 5, P(bin | class) = 1.39
# Class 9, attribute 7, bin 6, P(bin | class) = 0.00
# Class 10, attribute 0, bin 0, P(bin | class) = 12.50
# Class 10, attribute 0, bin 1, P(bin | class) = 12.50
# Class 10, attribute 0, bin 2, P(bin | class) = 12.50
# Class 10, attribute 0, bin 3, P(bin | class) = 0.00
# Class 10, attribute 0, bin 4, P(bin | class) = 0.00
# Class 10, attribute 0, bin 5, P(bin | class) = 12.50
# Class 10, attribute 0, bin 6, P(bin | class) = 0.00
# Class 10, attribute 1, bin 0, P(bin | class) = 0.00
# Class 10, attribute 1, bin 1, P(bin | class) = 3.57
# Class 10, attribute 1, bin 2, P(bin | class) = 0.00
# Class 10, attribute 1, bin 3, P(bin | class) = 0.00
# Class 10, attribute 1, bin 4, P(bin | class) = 7.14
# Class 10, attribute 1, bin 5, P(bin | class) = 3.57
# Class 10, attribute 1, bin 6, P(bin | class) = 0.00
# Class 10, attribute 2, bin 0, P(bin | class) = 0.00
# Class 10, attribute 2, bin 1, P(bin | class) = 4.00
# Class 10, attribute 2, bin 2, P(bin | class) = 0.00
# Class 10, attribute 2, bin 3, P(bin | class) = 0.00
# Class 10, attribute 2, bin 4, P(bin | class) = 8.00
# Class 10, attribute 2, bin 5, P(bin | class) = 4.00
# Class 10, attribute 2, bin 6, P(bin | class) = 0.00
# Class 10, attribute 3, bin 0, P(bin | class) = 0.00
# Class 10, attribute 3, bin 1, P(bin | class) = 6.67
# Class 10, attribute 3, bin 2, P(bin | class) = 6.67
# Class 10, attribute 3, bin 3, P(bin | class) = 0.00
# Class 10, attribute 3, bin 4, P(bin | class) = 6.67
# Class 10, attribute 3, bin 5, P(bin | class) = 6.67
# Class 10, attribute 3, bin 6, P(bin | class) = 0.00
# Class 10, attribute 4, bin 0, P(bin | class) = 0.00
# Class 10, attribute 4, bin 1, P(bin | class) = 0.00
# Class 10, attribute 4, bin 2, P(bin | class) = 0.00
# Class 10, attribute 4, bin 3, P(bin | class) = 0.00
# Class 10, attribute 4, bin 4, P(bin | class) = 0.00
# Class 10, attribute 4, bin 5, P(bin | class) = 0.00
# Class 10, attribute 4, bin 6, P(bin | class) = 10.00
# Class 10, attribute 5, bin 0, P(bin | class) = 0.00
# Class 10, attribute 5, bin 1, P(bin | class) = 0.00
# Class 10, attribute 5, bin 2, P(bin | class) = 0.00
# Class 10, attribute 5, bin 3, P(bin | class) = 0.00
# Class 10, attribute 5, bin 4, P(bin | class) = 0.00
# Class 10, attribute 5, bin 5, P(bin | class) = 0.00
# Class 10, attribute 5, bin 6, P(bin | class) = 10.00
# Class 10, attribute 6, bin 0, P(bin | class) = 0.00
# Class 10, attribute 6, bin 1, P(bin | class) = 20.00
# Class 10, attribute 6, bin 2, P(bin | class) = 20.00
# Class 10, attribute 6, bin 3, P(bin | class) = 20.00
# Class 10, attribute 6, bin 4, P(bin | class) = 0.00
# Class 10, attribute 6, bin 5, P(bin | class) = 20.00
# Class 10, attribute 6, bin 6, P(bin | class) = 0.00
# Class 10, attribute 7, bin 0, P(bin | class) = 0.00
# Class 10, attribute 7, bin 1, P(bin | class) = 100.00
# Class 10, attribute 7, bin 2, P(bin | class) = 0.00
# Class 10, attribute 7, bin 3, P(bin | class) = 0.00
# Class 10, attribute 7, bin 4, P(bin | class) = 0.00
# Class 10, attribute 7, bin 5, P(bin | class) = 33.33
# Class 10, attribute 7, bin 6, P(bin | class) = 0.00
# ⤵
#
# ID =     0, predicted =   3, probability = 0.9270, true=  3, accuracy=1.00
# ID =     1, predicted =   7, probability = 0.6364, true=  7, accuracy=1.00
# ID =     2, predicted =   7, probability = 0.5176, true=  7, accuracy=1.00
# ID =     3, predicted =   7, probability = 0.5557, true=  2, accuracy=0.00
# ID =     4, predicted =   2, probability = 0.8364, true=  2, accuracy=1.00
# ID =     5, predicted =   2, probability = 0.7116, true=  2, accuracy=1.00
# ID =     6, predicted =   1, probability = 0.5094, true=  7, accuracy=0.00
# ID =     7, predicted =   1, probability = 0.8298, true=  1, accuracy=1.00
# ID =     8, predicted =   2, probability = 0.3835, true=  7, accuracy=0.00
# ID =     9, predicted =   1, probability = 0.4169, true=  7, accuracy=0.00
# ID =    10, predicted =   3, probability = 0.6746, true=  3, accuracy=1.00
# ID =    11, predicted =   7, probability = 0.3627, true=  6, accuracy=0.00
# ID =    12, predicted =   7, probability = 0.6496, true=  2, accuracy=0.00
# ID =    13, predicted =   2, probability = 0.6672, true=  5, accuracy=0.00
# ID =    14, predicted =   5, probability = 0.8655, true=  5, accuracy=1.00
# ID =    15, predicted =   7, probability = 0.3499, true=  7, accuracy=1.00
# ID =    16, predicted =   7, probability = 0.3367, true=  3, accuracy=0.00
# ID =    17, predicted =   2, probability = 0.6647, true=  2, accuracy=1.00
# ID =    18, predicted =   2, probability = 0.9947, true=  3, accuracy=0.00
# ID =    19, predicted =   1, probability = 0.7441, true=  2, accuracy=0.00
# ID =    20, predicted =   2, probability = 0.8287, true=  2, accuracy=1.00
# ID =    21, predicted =   3, probability = 0.8517, true=  3, accuracy=1.00
# ID =    22, predicted =   2, probability = 0.8078, true=  2, accuracy=1.00
# ID =    23, predicted =   1, probability = 0.5324, true=  5, accuracy=0.00
# ID =    24, predicted =   2, probability = 0.7316, true=  3, accuracy=0.00
# ID =    25, predicted =   2, probability = 0.8690, true=  2, accuracy=1.00
# ID =    26, predicted =   2, probability = 0.8746, true=  2, accuracy=1.00
# ID =    27, predicted =   7, probability = 0.4523, true=  7, accuracy=1.00
# ID =    28, predicted =   3, probability = 0.5694, true=  3, accuracy=1.00
# ID =    29, predicted =   2, probability = 0.4753, true=  9, accuracy=0.00
# ID =    30, predicted =   7, probability = 0.6685, true=  7, accuracy=1.00
# ID =    31, predicted =   1, probability = 0.7248, true=  7, accuracy=0.00
# ID =    32, predicted =   1, probability = 0.4549, true=  7, accuracy=0.00
# ID =    33, predicted =   1, probability = 0.8108, true=  1, accuracy=1.00
# ID =    34, predicted =   9, probability = 0.5727, true=  7, accuracy=0.00
# ID =    35, predicted =   3, probability = 0.9027, true=  3, accuracy=1.00
# ID =    36, predicted =   3, probability = 0.9309, true=  3, accuracy=1.00
# ID =    37, predicted =   9, probability = 0.3468, true=  2, accuracy=0.00
# ID =    38, predicted =   7, probability = 0.4075, true=  7, accuracy=1.00
# ID =    39, predicted =   2, probability = 0.5080, true=  7, accuracy=0.00
# ID =    40, predicted =   9, probability = 0.6443, true=  3, accuracy=0.00
# ID =    41, predicted =   5, probability = 0.7669, true=  9, accuracy=0.00
# ID =    42, predicted =   4, probability = 0.6185, true=  1, accuracy=0.00
# ID =    43, predicted =   2, probability = 0.8355, true=  2, accuracy=1.00
# ID =    44, predicted =   2, probability = 0.5646, true=  2, accuracy=1.00
# ID =    45, predicted =   7, probability = 0.6096, true=  2, accuracy=0.00
# ID =    46, predicted =   7, probability = 0.4515, true=  7, accuracy=1.00
# ID =    47, predicted =   1, probability = 0.4901, true=  1, accuracy=1.00
# ID =    48, predicted =   1, probability = 0.6021, true=  1, accuracy=1.00
# ID =    49, predicted =   1, probability = 0.6940, true=  1, accuracy=1.00
# ID =    50, predicted =   2, probability = 0.9862, true=  7, accuracy=0.00
# ID =    51, predicted =   1, probability = 0.5299, true=  7, accuracy=0.00
# ID =    52, predicted =   2, probability = 0.5128, true=  2, accuracy=1.00
# ID =    53, predicted =   2, probability = 0.8866, true=  2, accuracy=1.00
# ID =    54, predicted =   2, probability = 0.4303, true=  7, accuracy=0.00
# ID =    55, predicted =   1, probability = 0.8380, true=  2, accuracy=0.00
# ID =    56, predicted =   1, probability = 0.4376, true=  2, accuracy=0.00
# ID =    57, predicted =   1, probability = 0.0000, true=  2, accuracy=0.00
# ID =    58, predicted =   1, probability = 0.4557, true=  3, accuracy=0.00
# ID =    59, predicted =   1, probability = 0.6141, true=  3, accuracy=0.00
# ID =    60, predicted =   3, probability = 0.3373, true=  2, accuracy=0.00
# ID =    61, predicted =   2, probability = 0.7507, true=  2, accuracy=1.00
# ID =    62, predicted =   5, probability = 0.5100, true=  1, accuracy=0.00
# ID =    63, predicted =   8, probability = 0.9339, true=  8, accuracy=1.00
# ID =    64, predicted =   3, probability = 0.8397, true=  3, accuracy=1.00
# ID =    65, predicted =   9, probability = 0.7687, true=  9, accuracy=1.00
# ID =    66, predicted =   2, probability = 0.6072, true=  2, accuracy=1.00
# ID =    67, predicted =   8, probability = 0.9544, true=  8, accuracy=1.00
# ID =    68, predicted =   2, probability = 0.5186, true=  7, accuracy=0.00
# ID =    69, predicted =   7, probability = 0.4438, true=  2, accuracy=0.00
# ID =    70, predicted =   3, probability = 0.9239, true=  9, accuracy=0.00
# ID =    71, predicted =   2, probability = 0.8559, true=  2, accuracy=1.00
# ID =    72, predicted =   2, probability = 0.3812, true=  3, accuracy=0.00
# ID =    73, predicted =   7, probability = 0.6364, true=  7, accuracy=1.00
# ID =    74, predicted =   7, probability = 0.5086, true=  7, accuracy=1.00
# ID =    75, predicted =   7, probability = 0.3781, true=  9, accuracy=0.00
# ID =    76, predicted =   3, probability = 0.7505, true=  3, accuracy=1.00
# ID =    77, predicted =   7, probability = 0.3323, true=  7, accuracy=1.00
# ID =    78, predicted =   8, probability = 0.8398, true=  8, accuracy=1.00
# ID =    79, predicted =   1, probability = 0.3054, true=  7, accuracy=0.00
# ID =    80, predicted =   2, probability = 0.7492, true=  7, accuracy=0.00
# ID =    81, predicted =   5, probability = 0.5662, true=  5, accuracy=1.00
# ID =    82, predicted =   3, probability = 0.7438, true=  5, accuracy=0.00
# ID =    83, predicted =   7, probability = 0.5055, true=  7, accuracy=1.00
# ID =    84, predicted =   7, probability = 0.3416, true=  1, accuracy=0.00
# ID =    85, predicted =   4, probability = 0.9706, true=  4, accuracy=1.00
# ID =    86, predicted =   5, probability = 0.3082, true=  7, accuracy=0.00
# ID =    87, predicted =   3, probability = 0.8491, true=  3, accuracy=1.00
# ID =    88, predicted =   7, probability = 0.4360, true=  2, accuracy=0.00
# ID =    89, predicted =   1, probability = 0.6216, true=  7, accuracy=0.00
# ID =    90, predicted =   7, probability = 0.3490, true=  7, accuracy=1.00
# ID =    91, predicted =   7, probability = 0.5473, true=  7, accuracy=1.00
# ID =    92, predicted =   7, probability = 0.9492, true=  7, accuracy=1.00
# ID =    93, predicted =   1, probability = 0.9273, true=  1, accuracy=1.00
# ID =    94, predicted =   7, probability = 0.5372, true=  2, accuracy=0.00
# ID =    95, predicted =   2, probability = 0.4525, true=  2, accuracy=1.00
# ID =    96, predicted =   1, probability = 0.9286, true=  1, accuracy=1.00
# ID =    97, predicted =   2, probability = 0.5657, true=  2, accuracy=1.00
# ID =    98, predicted =   7, probability = 0.3182, true=  7, accuracy=1.00
# ID =    99, predicted =   2, probability = 0.9614, true=  2, accuracy=1.00
# ID =   100, predicted =   2, probability = 0.4513, true=  3, accuracy=0.00
# ID =   101, predicted =   3, probability = 0.8956, true=  3, accuracy=1.00
# ID =   102, predicted =   7, probability = 0.5177, true=  2, accuracy=0.00
# ID =   103, predicted =   1, probability = 0.6541, true=  7, accuracy=0.00
# ID =   104, predicted =   3, probability = 0.4242, true=  3, accuracy=1.00
# ID =   105, predicted =   3, probability = 0.9849, true=  9, accuracy=0.00
# ID =   106, predicted =   7, probability = 0.4504, true=  6, accuracy=0.00
# ID =   107, predicted =   1, probability = 0.5867, true=  7, accuracy=0.00
# ID =   108, predicted =   2, probability = 0.7962, true=  7, accuracy=0.00
# ID =   109, predicted =   2, probability = 0.5566, true=  1, accuracy=0.00
# ID =   110, predicted =   1, probability = 0.5303, true=  2, accuracy=0.00
# ID =   111, predicted =   8, probability = 0.6281, true=  2, accuracy=0.00
# ID =   112, predicted =   7, probability = 0.4723, true=  7, accuracy=1.00
# ID =   113, predicted =   1, probability = 0.8756, true=  1, accuracy=1.00
# ID =   114, predicted =   7, probability = 0.4349, true=  7, accuracy=1.00
# ID =   115, predicted =   3, probability = 0.8304, true=  2, accuracy=0.00
# ID =   116, predicted =   3, probability = 0.6721, true=  2, accuracy=0.00
# ID =   117, predicted =   8, probability = 0.9961, true=  8, accuracy=1.00
# ID =   118, predicted =   2, probability = 0.9069, true=  5, accuracy=0.00
# ID =   119, predicted =   2, probability = 0.6936, true=  2, accuracy=1.00
# ID =   120, predicted =   2, probability = 0.5828, true=  7, accuracy=0.00
# ID =   121, predicted =   2, probability = 0.3725, true=  2, accuracy=1.00
# ID =   122, predicted =   5, probability = 0.5452, true=  4, accuracy=0.00
# ID =   123, predicted =   7, probability = 0.3649, true=  7, accuracy=1.00
# ID =   124, predicted =   1, probability = 0.9618, true=  1, accuracy=1.00
# ID =   125, predicted =   7, probability = 0.3158, true=  7, accuracy=1.00
# ID =   126, predicted =   2, probability = 0.5119, true=  7, accuracy=0.00
# ID =   127, predicted =   2, probability = 0.5387, true=  7, accuracy=0.00
# ID =   128, predicted =   2, probability = 0.5602, true=  7, accuracy=0.00
# ID =   129, predicted =   2, probability = 0.5294, true=  2, accuracy=1.00
# ID =   130, predicted =   2, probability = 0.5797, true=  7, accuracy=0.00
# ID =   131, predicted =   9, probability = 0.6864, true=  2, accuracy=0.00
# ID =   132, predicted =   3, probability = 0.4771, true=  2, accuracy=0.00
# ID =   133, predicted =   7, probability = 0.3560, true=  2, accuracy=0.00
# ID =   134, predicted =   1, probability = 0.3854, true=  1, accuracy=1.00
# ID =   135, predicted =   2, probability = 0.7172, true=  7, accuracy=0.00
# ID =   136, predicted =   8, probability = 0.7128, true=  8, accuracy=1.00
# ID =   137, predicted =   3, probability = 0.9917, true=  3, accuracy=1.00
# ID =   138, predicted =   2, probability = 0.4452, true=  2, accuracy=1.00
# ID =   139, predicted =   3, probability = 0.3832, true=  2, accuracy=0.00
# ID =   140, predicted =   2, probability = 0.5039, true=  7, accuracy=0.00
# ID =   141, predicted =   2, probability = 0.8137, true=  2, accuracy=1.00
# ID =   142, predicted =   3, probability = 0.8606, true=  3, accuracy=1.00
# ID =   143, predicted =   1, probability = 0.7795, true=  1, accuracy=1.00
# ID =   144, predicted =   7, probability = 0.4837, true=  7, accuracy=1.00
# ID =   145, predicted =   3, probability = 0.9701, true=  2, accuracy=0.00
# ID =   146, predicted =   2, probability = 0.7369, true=  2, accuracy=1.00
# ID =   147, predicted =   1, probability = 0.8263, true=  1, accuracy=1.00
# ID =   148, predicted =   2, probability = 0.6241, true=  2, accuracy=1.00
# ID =   149, predicted =   2, probability = 0.9053, true=  2, accuracy=1.00
# ID =   150, predicted =   2, probability = 0.8219, true=  7, accuracy=0.00
# ID =   151, predicted =   7, probability = 0.4019, true=  2, accuracy=0.00
# ID =   152, predicted =   2, probability = 0.9603, true=  2, accuracy=1.00
# ID =   153, predicted =   1, probability = 0.6204, true=  1, accuracy=1.00
# ID =   154, predicted =   5, probability = 0.7295, true=  5, accuracy=1.00
# ID =   155, predicted =   2, probability = 0.8574, true=  2, accuracy=1.00
# ID =   156, predicted =   2, probability = 0.7140, true=  7, accuracy=0.00
# ID =   157, predicted =   1, probability = 0.6735, true=  7, accuracy=0.00
# ID =   158, predicted =   2, probability = 0.7230, true=  7, accuracy=0.00
# ID =   159, predicted =   1, probability = 0.5201, true=  2, accuracy=0.00
# ID =   160, predicted =   1, probability = 0.5564, true=  7, accuracy=0.00
# ID =   161, predicted =   7, probability = 0.5825, true=  1, accuracy=0.00
# ID =   162, predicted =   1, probability = 0.3988, true=  2, accuracy=0.00
# ID =   163, predicted =   1, probability = 0.8773, true=  1, accuracy=1.00
# ID =   164, predicted =   8, probability = 0.7296, true=  4, accuracy=0.00
# ID =   165, predicted =   2, probability = 0.6333, true=  7, accuracy=0.00
# ID =   166, predicted =   7, probability = 0.4813, true=  7, accuracy=1.00
# ID =   167, predicted =   2, probability = 0.4014, true=  2, accuracy=1.00
# ID =   168, predicted =   1, probability = 0.5997, true=  2, accuracy=0.00
# ID =   169, predicted =   1, probability = 0.4056, true=  1, accuracy=1.00
# ID =   170, predicted =   1, probability = 0.5663, true=  1, accuracy=1.00
# ID =   171, predicted =   5, probability = 0.9998, true=  4, accuracy=0.00
# ID =   172, predicted =   5, probability = 0.9550, true=  1, accuracy=0.00
# ID =   173, predicted =   2, probability = 0.6741, true=  7, accuracy=0.00
# ID =   174, predicted =   2, probability = 0.7759, true=  2, accuracy=1.00
# ID =   175, predicted =   7, probability = 0.4804, true=  7, accuracy=1.00
# ID =   176, predicted =   2, probability = 0.9870, true=  2, accuracy=1.00
# ID =   177, predicted =   1, probability = 0.9425, true=  1, accuracy=1.00
# ID =   178, predicted =   2, probability = 0.4325, true=  7, accuracy=0.00
# ID =   179, predicted =   7, probability = 0.9713, true=  7, accuracy=1.00
# ID =   180, predicted =   8, probability = 0.7279, true=  4, accuracy=0.00
# ID =   181, predicted =   3, probability = 0.9605, true=  3, accuracy=1.00
# ID =   182, predicted =   3, probability = 0.9670, true=  3, accuracy=1.00
# ID =   183, predicted =   1, probability = 0.4987, true=  2, accuracy=0.00
# ID =   184, predicted =   2, probability = 0.9143, true=  2, accuracy=1.00
# ID =   185, predicted =   7, probability = 0.5016, true=  7, accuracy=1.00
# ID =   186, predicted =   2, probability = 0.8080, true=  3, accuracy=0.00
# ID =   187, predicted =   7, probability = 0.4967, true=  7, accuracy=1.00
# ID =   188, predicted =   2, probability = 0.9533, true=  2, accuracy=1.00
# ID =   189, predicted =   1, probability = 0.6330, true=  1, accuracy=1.00
# ID =   190, predicted =   7, probability = 0.6855, true=  7, accuracy=1.00
# ID =   191, predicted =   7, probability = 0.3427, true=  7, accuracy=1.00
# ID =   192, predicted =   7, probability = 0.4791, true=  7, accuracy=1.00
# ID =   193, predicted =   1, probability = 0.6538, true=  9, accuracy=0.00
# ID =   194, predicted =   5, probability = 0.6276, true=  1, accuracy=0.00
# ID =   195, predicted =   2, probability = 0.5322, true=  2, accuracy=1.00
# ID =   196, predicted =   7, probability = 0.2525, true=  2, accuracy=0.00
# ID =   197, predicted =   3, probability = 0.6496, true=  3, accuracy=1.00
# ID =   198, predicted =   2, probability = 0.6768, true=  7, accuracy=0.00
# ID =   199, predicted =   2, probability = 0.4739, true=  7, accuracy=0.00
# ID =   200, predicted =   3, probability = 0.7768, true=  1, accuracy=0.00
# ID =   201, predicted =   3, probability = 0.8886, true=  3, accuracy=1.00
# ID =   202, predicted =   2, probability = 0.6647, true=  2, accuracy=1.00
# ID =   203, predicted =   2, probability = 0.5650, true=  7, accuracy=0.00
# ID =   204, predicted =   3, probability = 0.8856, true=  3, accuracy=1.00
# ID =   205, predicted =   3, probability = 0.8709, true=  3, accuracy=1.00
# ID =   206, predicted =   2, probability = 0.8205, true=  7, accuracy=0.00
# ID =   207, predicted =   5, probability = 0.3187, true=  1, accuracy=0.00
# ID =   208, predicted =   3, probability = 0.5908, true=  3, accuracy=1.00
# ID =   209, predicted =   2, probability = 0.8124, true=  2, accuracy=1.00
# ID =   210, predicted =   1, probability = 0.5944, true=  3, accuracy=0.00
# ID =   211, predicted =   1, probability = 0.5203, true=  2, accuracy=0.00
# ID =   212, predicted =   7, probability = 0.9408, true=  1, accuracy=0.00
# ID =   213, predicted =   2, probability = 0.7472, true=  1, accuracy=0.00
# ID =   214, predicted =   2, probability = 0.8805, true=  7, accuracy=0.00
# ID =   215, predicted =   2, probability = 0.8165, true=  2, accuracy=1.00
# ID =   216, predicted =   1, probability = 0.9894, true=  1, accuracy=1.00
# ID =   217, predicted =   5, probability = 0.6835, true=  3, accuracy=0.00
# ID =   218, predicted =   7, probability = 0.7904, true=  1, accuracy=0.00
# ID =   219, predicted =   1, probability = 0.9653, true=  1, accuracy=1.00
# ID =   220, predicted =   2, probability = 0.4603, true=  2, accuracy=1.00
# ID =   221, predicted =   2, probability = 0.4743, true=  7, accuracy=0.00
# ID =   222, predicted =   3, probability = 0.4610, true=  3, accuracy=1.00
# ID =   223, predicted =   1, probability = 0.3406, true=  1, accuracy=1.00
# ID =   224, predicted =   5, probability = 0.7022, true=  8, accuracy=0.00
# ID =   225, predicted =   2, probability = 0.9579, true=  7, accuracy=0.00
# ID =   226, predicted =   1, probability = 0.9247, true=  1, accuracy=1.00
# ID =   227, predicted =   1, probability = 0.7390, true=  7, accuracy=0.00
# ID =   228, predicted =   2, probability = 0.4972, true=  9, accuracy=0.00
# ID =   229, predicted =   1, probability = 0.6056, true=  1, accuracy=1.00
# ID =   230, predicted =   2, probability = 0.7334, true=  1, accuracy=0.00
# ID =   231, predicted =   7, probability = 1.0000, true=  7, accuracy=1.00
# ID =   232, predicted =   3, probability = 0.5767, true=  3, accuracy=1.00
# ID =   233, predicted =   7, probability = 0.3610, true=  7, accuracy=1.00
# ID =   234, predicted =   5, probability = 0.5670, true=  1, accuracy=0.00
# ID =   235, predicted =   2, probability = 0.9414, true=  2, accuracy=1.00
# ID =   236, predicted =   2, probability = 0.5654, true=  7, accuracy=0.00
# ID =   237, predicted =   9, probability = 0.5332, true=  1, accuracy=0.00
# ID =   238, predicted =   4, probability = 0.4085, true=  4, accuracy=1.00
# ID =   239, predicted =   5, probability = 0.5710, true=  3, accuracy=0.00
# ID =   240, predicted =   7, probability = 0.5483, true=  7, accuracy=1.00
# ID =   241, predicted =   7, probability = 0.3293, true=  7, accuracy=1.00
# ID =   242, predicted =   1, probability = 0.6157, true=  3, accuracy=0.00
# ID =   243, predicted =   8, probability = 0.9036, true=  8, accuracy=1.00
# ID =   244, predicted =   2, probability = 0.5381, true=  2, accuracy=1.00
# ID =   245, predicted =   2, probability = 0.8981, true=  7, accuracy=0.00
# ID =   246, predicted =   7, probability = 0.5554, true=  2, accuracy=0.00
# ID =   247, predicted =   1, probability = 0.6476, true=  1, accuracy=1.00
# ID =   248, predicted =   7, probability = 0.3014, true=  7, accuracy=1.00
# ID =   249, predicted =   1, probability = 0.7555, true=  1, accuracy=1.00
# ID =   250, predicted =   2, probability = 0.4106, true=  9, accuracy=0.00
# ID =   251, predicted =   3, probability = 0.6036, true=  3, accuracy=1.00
# ID =   252, predicted =   2, probability = 0.7879, true=  1, accuracy=0.00
# ID =   253, predicted =   1, probability = 0.3833, true=  7, accuracy=0.00
# ID =   254, predicted =   1, probability = 0.9688, true=  1, accuracy=1.00
# ID =   255, predicted =   8, probability = 0.7035, true=  4, accuracy=0.00
# ID =   256, predicted =   3, probability = 0.5094, true=  3, accuracy=1.00
# ...
# ID =   272, predicted =   8, probability = 0.5153, true=  8, accuracy=1.00
# ID =   273, predicted =   2, probability = 0.5171, true=  2, accuracy=1.00
# ID =   274, predicted =   7, probability = 0.5529, true=  2, accuracy=0.00
# ID =   275, predicted =   2, probability = 0.3696, true=  7, accuracy=0.00
# ID =   276, predicted =   3, probability = 0.6179, true=  3, accuracy=1.00
# ID =   277, predicted =   2, probability = 0.4875, true=  2, accuracy=1.00
# ID =   278, predicted =   9, probability = 0.3007, true=  1, accuracy=0.00
# ID =   279, predicted =   2, probability = 0.4859, true=  2, accuracy=1.00
# ID =   280, predicted =   2, probability = 0.3875, true=  7, accuracy=0.00
# ID =   281, predicted =   8, probability = 0.8505, true=  7, accuracy=0.00
# ID =   282, predicted =   2, probability = 0.9003, true=  2, accuracy=1.00
# ID =   283, predicted =   1, probability = 0.8404, true=  7, accuracy=0.00
# ID =   284, predicted =   2, probability = 0.6130, true=  2, accuracy=1.00
# ID =   285, predicted =   7, probability = 0.6333, true=  7, accuracy=1.00
# ID =   286, predicted =   8, probability = 0.9049, true=  2, accuracy=0.00
# ID =   287, predicted =   2, probability = 0.4717, true=  7, accuracy=0.00
# ID =   288, predicted =   3, probability = 0.7635, true=  3, accuracy=1.00
# ID =   289, predicted =   3, probability = 0.7087, true=  2, accuracy=0.00
# ID =   290, predicted =   3, probability = 0.7673, true=  3, accuracy=1.00
# ID =   291, predicted =   5, probability = 0.8245, true=  5, accuracy=1.00
# ID =   292, predicted =   2, probability = 0.5716, true=  2, accuracy=1.00
# ID =   293, predicted =   3, probability = 0.4339, true=  7, accuracy=0.00
# ID =   294, predicted =   7, probability = 0.6418, true=  8, accuracy=0.00
# ID =   295, predicted =   7, probability = 0.3271, true=  1, accuracy=0.00
# ID =   296, predicted =   5, probability = 0.4022, true=  3, accuracy=0.00
# ID =   297, predicted =   2, probability = 0.8866, true=  2, accuracy=1.00
# ID =   298, predicted =   7, probability = 0.4317, true=  7, accuracy=1.00
# ID =   299, predicted =   1, probability = 0.5052, true=  1, accuracy=1.00
# ID =   300, predicted =   1, probability = 0.8723, true=  7, accuracy=0.00
# ID =   301, predicted =   1, probability = 0.3233, true=  1, accuracy=1.00
# ID =   302, predicted =   1, probability = 0.6757, true=  1, accuracy=1.00
# ID =   303, predicted =   2, probability = 0.8391, true=  3, accuracy=0.00
# ID =   304, predicted =   7, probability = 0.7406, true=  2, accuracy=0.00
# ID =   305, predicted =   7, probability = 0.6787, true=  2, accuracy=0.00
# ID =   306, predicted =   9, probability = 0.4811, true=  7, accuracy=0.00
# ID =   307, predicted =   1, probability = 0.3184, true=  8, accuracy=0.00
# ID =   308, predicted =   9, probability = 0.4604, true=  7, accuracy=0.00
# ID =   309, predicted =   1, probability = 0.8124, true=  1, accuracy=1.00
# ID =   310, predicted =   3, probability = 0.7742, true=  3, accuracy=1.00
# ID =   311, predicted =   7, probability = 0.5971, true=  7, accuracy=1.00
# ID =   312, predicted =   7, probability = 0.3600, true=  1, accuracy=0.00
# ID =   313, predicted =   2, probability = 0.4914, true=  7, accuracy=0.00
# ID =   314, predicted =   2, probability = 0.5086, true=  7, accuracy=0.00
# ID =   315, predicted =   7, probability = 0.5123, true=  7, accuracy=1.00
# ID =   316, predicted =   7, probability = 0.5432, true=  7, accuracy=1.00
# ID =   317, predicted =   2, probability = 0.8456, true=  7, accuracy=0.00
# ID =   318, predicted =   3, probability = 0.9782, true=  3, accuracy=1.00
# ID =   319, predicted =   1, probability = 0.9811, true=  1, accuracy=1.00
# ID =   320, predicted =   3, probability = 0.9548, true=  9, accuracy=0.00
# ID =   321, predicted =   7, probability = 0.6351, true=  7, accuracy=1.00
# ID =   322, predicted =   1, probability = 0.4557, true=  7, accuracy=0.00
# ID =   323, predicted =   3, probability = 0.4820, true=  3, accuracy=1.00
# ID =   324, predicted =   5, probability = 0.6571, true=  5, accuracy=1.00
# ID =   325, predicted =   1, probability = 0.3874, true=  2, accuracy=0.00
# ID =   326, predicted =   3, probability = 0.6845, true=  2, accuracy=0.00
# ID =   327, predicted =   2, probability = 0.3296, true=  7, accuracy=0.00
# ID =   328, predicted =   3, probability = 0.6954, true=  3, accuracy=1.00
# ID =   329, predicted =   1, probability = 0.7383, true=  1, accuracy=1.00
# ID =   330, predicted =   3, probability = 0.7054, true=  7, accuracy=0.00
# ID =   331, predicted =   1, probability = 0.6404, true=  5, accuracy=0.00
# ID =   332, predicted =   2, probability = 0.8457, true=  2, accuracy=1.00
# ID =   333, predicted =   1, probability = 0.7096, true=  7, accuracy=0.00
# ID =   334, predicted =   7, probability = 0.4861, true=  2, accuracy=0.00
# ID =   335, predicted =   9, probability = 0.5228, true=  6, accuracy=0.00
# ID =   336, predicted =   2, probability = 0.6615, true=  2, accuracy=1.00
# ID =   337, predicted =   7, probability = 0.9391, true=  2, accuracy=0.00
# ID =   338, predicted =   1, probability = 0.6120, true=  9, accuracy=0.00
# ID =   339, predicted =   1, probability = 0.7965, true=  7, accuracy=0.00
# ID =   340, predicted =   3, probability = 0.9722, true=  9, accuracy=0.00
# ID =   341, predicted =   5, probability = 0.4937, true=  3, accuracy=0.00
# ID =   342, predicted =   5, probability = 0.9580, true=  5, accuracy=1.00
# ID =   343, predicted =   1, probability = 0.7392, true=  5, accuracy=0.00
# ID =   344, predicted =   2, probability = 0.5286, true=  2, accuracy=1.00
# ID =   345, predicted =   2, probability = 0.9435, true=  2, accuracy=1.00
# ID =   346, predicted =   1, probability = 0.3564, true=  2, accuracy=0.00
# ID =   347, predicted =   1, probability = 0.8931, true=  1, accuracy=1.00
# ID =   348, predicted =   3, probability = 0.7922, true=  2, accuracy=0.00
# ID =   349, predicted =   3, probability = 0.3320, true=  2, accuracy=0.00
# ID =   350, predicted =   7, probability = 0.4411, true=  7, accuracy=1.00
# ID =   351, predicted =   7, probability = 0.6663, true=  7, accuracy=1.00
# ID =   352, predicted =   1, probability = 0.9435, true=  7, accuracy=0.00
# ID =   353, predicted =   1, probability = 0.6796, true=  6, accuracy=0.00
# ID =   354, predicted =   8, probability = 0.3311, true=  1, accuracy=0.00
# ID =   355, predicted =   1, probability = 0.8392, true=  1, accuracy=1.00
# ID =   356, predicted =   2, probability = 0.8313, true=  2, accuracy=1.00
# ID =   357, predicted =   7, probability = 0.4434, true=  7, accuracy=1.00
# ID =   358, predicted =   1, probability = 0.6342, true=  7, accuracy=0.00
# ID =   359, predicted =   2, probability = 0.8317, true=  7, accuracy=0.00
# ID =   360, predicted =   3, probability = 0.6169, true=  3, accuracy=1.00
# ID =   361, predicted =   9, probability = 0.3606, true=  7, accuracy=0.00
# ID =   362, predicted =   1, probability = 0.4810, true=  2, accuracy=0.00
# ID =   363, predicted =   2, probability = 0.5279, true=  2, accuracy=1.00
# ID =   364, predicted =   2, probability = 0.9395, true=  7, accuracy=0.00
# ID =   365, predicted =   9, probability = 0.3359, true=  7, accuracy=0.00
# ID =   366, predicted =   2, probability = 0.6688, true=  2, accuracy=1.00
# ID =   367, predicted =   1, probability = 0.6151, true=  6, accuracy=0.00
# ID =   368, predicted =   3, probability = 0.8259, true=  2, accuracy=0.00
# ID =   369, predicted =   5, probability = 0.6641, true=  1, accuracy=0.00
# ID =   370, predicted =   3, probability = 0.9008, true=  3, accuracy=1.00
# ID =   371, predicted =   2, probability = 0.8895, true=  2, accuracy=1.00
# ID =   372, predicted =   7, probability = 0.6642, true=  2, accuracy=0.00
# ID =   373, predicted =   2, probability = 0.6036, true=  7, accuracy=0.00
# ID =   374, predicted =   2, probability = 0.9212, true=  2, accuracy=1.00
# ID =   375, predicted =   7, probability = 0.4983, true=  2, accuracy=0.00
# ID =   376, predicted =   3, probability = 0.3481, true=  3, accuracy=1.00
# ID =   377, predicted =   7, probability = 0.7947, true=  7, accuracy=1.00
# ID =   378, predicted =   2, probability = 0.7323, true=  7, accuracy=0.00
# ID =   379, predicted =   2, probability = 0.4433, true=  2, accuracy=1.00
# ID =   380, predicted =   1, probability = 0.5841, true=  1, accuracy=1.00
# ID =   381, predicted =   2, probability = 0.9797, true=  7, accuracy=0.00
# ID =   382, predicted =   7, probability = 0.5186, true=  1, accuracy=0.00
# ID =   383, predicted =   8, probability = 0.7967, true=  4, accuracy=0.00
# ID =   384, predicted =   1, probability = 0.5320, true=  1, accuracy=1.00
# ID =   385, predicted =   2, probability = 0.4413, true=  7, accuracy=0.00
# ID =   386, predicted =   7, probability = 0.7396, true=  5, accuracy=0.00
# ID =   387, predicted =   2, probability = 0.6379, true=  2, accuracy=1.00
# ID =   388, predicted =   1, probability = 0.4483, true=  7, accuracy=0.00
# ID =   389, predicted =   1, probability = 0.3580, true=  1, accuracy=1.00
# ID =   390, predicted =   7, probability = 0.2816, true=  7, accuracy=1.00
# ID =   391, predicted =   7, probability = 0.3396, true=  7, accuracy=1.00
# ID =   392, predicted =   1, probability = 0.4815, true=  2, accuracy=0.00
# ID =   393, predicted =   7, probability = 0.3837, true=  7, accuracy=1.00
# ID =   394, predicted =   1, probability = 0.6871, true=  7, accuracy=0.00
# ID =   395, predicted =   2, probability = 0.6887, true=  2, accuracy=1.00
# ID =   396, predicted =   3, probability = 0.9836, true=  3, accuracy=1.00
# ID =   397, predicted =   7, probability = 0.9605, true=  7, accuracy=1.00
# ID =   398, predicted =   9, probability = 0.3559, true=  2, accuracy=0.00
# ID =   399, predicted =   7, probability = 0.3788, true=  2, accuracy=0.00
# ID =   400, predicted =   2, probability = 0.5387, true=  7, accuracy=0.00
# ID =   401, predicted =   5, probability = 0.4475, true=  1, accuracy=0.00
# ID =   402, predicted =   2, probability = 0.7717, true=  2, accuracy=1.00
# ID =   403, predicted =   1, probability = 0.6042, true=  7, accuracy=0.00
# ID =   404, predicted =   7, probability = 0.4554, true=  2, accuracy=0.00
# ID =   405, predicted =   5, probability = 0.3413, true=  3, accuracy=0.00
# ID =   406, predicted =   4, probability = 0.8195, true= 10, accuracy=0.00
# ID =   407, predicted =   2, probability = 0.9246, true=  2, accuracy=1.00
# ID =   408, predicted =   3, probability = 0.6260, true=  3, accuracy=1.00
# ID =   409, predicted =   2, probability = 0.4640, true=  2, accuracy=1.00
# ID =   410, predicted =   3, probability = 0.9542, true=  3, accuracy=1.00
# ID =   411, predicted =   3, probability = 0.8860, true=  3, accuracy=1.00
# ID =   412, predicted =   2, probability = 0.7190, true=  7, accuracy=0.00
# ID =   413, predicted =   2, probability = 0.8081, true=  7, accuracy=0.00
# ID =   414, predicted =   4, probability = 0.5282, true=  5, accuracy=0.00
# ID =   415, predicted =   3, probability = 0.9122, true=  3, accuracy=1.00
# ID =   416, predicted =   9, probability = 0.3624, true=  5, accuracy=0.00
# ID =   417, predicted =   1, probability = 0.7182, true=  1, accuracy=1.00
# ID =   418, predicted =   2, probability = 0.8458, true=  2, accuracy=1.00
# ID =   419, predicted =   1, probability = 0.7209, true=  1, accuracy=1.00
# ID =   420, predicted =   1, probability = 0.4669, true=  7, accuracy=0.00
# ID =   421, predicted =   3, probability = 0.4141, true=  2, accuracy=0.00
# ID =   422, predicted =   3, probability = 0.8991, true=  3, accuracy=1.00
# ID =   423, predicted =   2, probability = 0.4310, true=  2, accuracy=1.00
# ID =   424, predicted =   2, probability = 0.6969, true=  7, accuracy=0.00
# ID =   425, predicted =   3, probability = 0.9902, true=  3, accuracy=1.00
# ID =   426, predicted =   7, probability = 0.9605, true=  7, accuracy=1.00
# ID =   427, predicted =   7, probability = 0.7069, true=  7, accuracy=1.00
# ID =   428, predicted =   1, probability = 0.3850, true=  7, accuracy=0.00
# ID =   429, predicted =   1, probability = 0.8622, true=  1, accuracy=1.00
# ID =   430, predicted =   1, probability = 0.8115, true=  1, accuracy=1.00
# ID =   431, predicted =   2, probability = 0.7290, true=  7, accuracy=0.00
# ID =   432, predicted =   1, probability = 0.5481, true=  2, accuracy=0.00
# ID =   433, predicted =   1, probability = 0.5882, true=  7, accuracy=0.00
# ID =   434, predicted =   1, probability = 0.8823, true=  1, accuracy=1.00
# ID =   435, predicted =   2, probability = 0.3499, true=  6, accuracy=0.00
# ID =   436, predicted =   3, probability = 0.8507, true=  9, accuracy=0.00
# ID =   437, predicted =   2, probability = 0.7329, true=  2, accuracy=1.00
# ID =   438, predicted =   2, probability = 0.8122, true=  7, accuracy=0.00
# ID =   439, predicted =   7, probability = 0.3442, true=  3, accuracy=0.00
# ID =   440, predicted =   1, probability = 0.6355, true=  3, accuracy=0.00
# ID =   441, predicted =   7, probability = 0.5999, true=  2, accuracy=0.00
# ID =   442, predicted =   5, probability = 0.4886, true=  3, accuracy=0.00
# ID =   443, predicted =   7, probability = 0.5575, true=  2, accuracy=0.00
# ID =   444, predicted =   7, probability = 0.4372, true=  7, accuracy=1.00
# ID =   445, predicted =   7, probability = 0.4349, true=  7, accuracy=1.00
# ID =   446, predicted =   3, probability = 0.8768, true=  3, accuracy=1.00
# ID =   447, predicted =   4, probability = 0.7996, true=  8, accuracy=0.00
# ID =   448, predicted =   1, probability = 0.3659, true=  7, accuracy=0.00
# ID =   449, predicted =   2, probability = 0.9462, true=  7, accuracy=0.00
# ID =   450, predicted =   2, probability = 0.7202, true=  7, accuracy=0.00
# ID =   451, predicted =   3, probability = 0.5339, true=  3, accuracy=1.00
# ID =   452, predicted =   2, probability = 0.7761, true=  2, accuracy=1.00
# ID =   453, predicted =   5, probability = 0.3764, true=  2, accuracy=0.00
# ID =   454, predicted =   2, probability = 0.9451, true=  2, accuracy=1.00
# ID =   455, predicted =   9, probability = 0.3588, true=  3, accuracy=0.00
# ID =   456, predicted =   1, probability = 0.7029, true=  1, accuracy=1.00
# ID =   457, predicted =   1, probability = 0.6477, true=  2, accuracy=0.00
# ID =   458, predicted =   7, probability = 0.4967, true=  2, accuracy=0.00
# ID =   459, predicted =   2, probability = 0.7674, true=  7, accuracy=0.00
# ID =   460, predicted =   2, probability = 0.5832, true=  4, accuracy=0.00
# ID =   461, predicted =   2, probability = 0.4267, true=  7, accuracy=0.00
# ID =   462, predicted =   2, probability = 1.0000, true=  2, accuracy=1.00
# ID =   463, predicted =   2, probability = 0.8713, true=  2, accuracy=1.00
# ID =   464, predicted =   1, probability = 0.9566, true=  1, accuracy=1.00
# ID =   465, predicted =   3, probability = 0.8493, true=  3, accuracy=1.00
# ID =   466, predicted =   2, probability = 0.8920, true=  2, accuracy=1.00
# ID =   467, predicted =   2, probability = 0.9282, true=  7, accuracy=0.00
# ID =   468, predicted =   2, probability = 0.7422, true=  2, accuracy=1.00
# ID =   469, predicted =   2, probability = 0.3749, true=  7, accuracy=0.00
# ID =   470, predicted =   5, probability = 0.7642, true=  1, accuracy=0.00
# ID =   471, predicted =   1, probability = 0.8993, true=  1, accuracy=1.00
# ID =   472, predicted =   8, probability = 0.6492, true=  4, accuracy=0.00
# ID =   473, predicted =   8, probability = 0.9850, true=  8, accuracy=1.00
# ID =   474, predicted =   1, probability = 0.9754, true=  1, accuracy=1.00
# ID =   475, predicted =   7, probability = 0.6596, true=  1, accuracy=0.00
# ID =   476, predicted =   2, probability = 0.5821, true=  1, accuracy=0.00
# ID =   477, predicted =   1, probability = 0.5588, true=  1, accuracy=1.00
# ID =   478, predicted =   3, probability = 0.6649, true=  5, accuracy=0.00
# ID =   479, predicted =   3, probability = 0.7703, true=  3, accuracy=1.00
# ID =   480, predicted =   9, probability = 0.2459, true=  2, accuracy=0.00
# ID =   481, predicted =   1, probability = 0.5012, true=  8, accuracy=0.00
# ID =   482, predicted =   7, probability = 0.6901, true=  2, accuracy=0.00
# ID =   483, predicted =   2, probability = 0.3884, true=  1, accuracy=0.00
# classification accuracy=0.4855
