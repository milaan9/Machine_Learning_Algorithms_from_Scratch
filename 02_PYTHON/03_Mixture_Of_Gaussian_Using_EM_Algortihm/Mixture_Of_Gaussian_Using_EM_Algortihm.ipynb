# %% [markdown]
# <a href="https://github.com/milaan9/Machine_Learning_Algorithms_from_Scratch"><img src="https://img.shields.io/badge/All the IPython Notebooks in Machine_Learning_Algorithms_from_Scratch lecture series by Dr. Milaan Parmar are available ➔ -GitHub-blueviolet.svg" alt="logo"/></a>

# %%
import math


mean_dic = {}
sigma_dic = {}
weight_dic = {}
normal_dic = {}


class GaussianMixture:
	def __init__(self, train_file, test_file,  number_of_gaussians):
		self.classifier_dic = {}
		self.mean_dic = {}
		self.variance_dic = {}
		self.normal_dic = []
		self.unique_labels = []
		self.probability_dic = {}
		self.data_dic = {}
		self.total_training_object = 0
		self.train_file = train_file
		self.test_file = test_file
		self.number_of_gaussians = number_of_gaussians

	def train(self):
		""" Trains the mixture of gaussian naive bayes classifier """
		
		number_of_gaussians = self.number_of_gaussians
		train_file_path = self.train_file
		data_dic, self.unique_labels, total_number_of_rows, data_list = load_data_set(train_file_path)
		self.total_training_object = total_number_of_rows
		self.unique_labels = list(map(int, self.unique_labels))
		self.unique_labels = sorted(self.unique_labels)
		self.data_dic = data_dic
		train_mixture = GaussianMixtureTraining(number_of_gaussians, data_dic)
		for label in data_dic:
			mean_dic[label] = {}
			sigma_dic[label] = {}
			weight_dic[label] = {}
			for col in range(0, len(data_dic[label][0])):
				mean, sigma, weight = train_mixture.initialise_parameters(col, label)
				mean_dic[label][col] = mean
				sigma_dic[label][col] = sigma
				weight_dic[label][col] = weight

		for x in range(0, 50):
			train_mixture.e_step()
			train_mixture.m_step()

		for label in data_dic:
			for col in range(0, len(data_dic[label][0])):
				for gaussian in range(0, number_of_gaussians):
					print("Class %d, attribute %d, Gaussian %d, mean = %.2f, std = %.2f" % (label, col, gaussian, mean_dic[label][col][gaussian], sigma_dic[label][col][gaussian]))

	def test(self):
		""" performs testing on test data """
		
		number_of_gaussians = self.number_of_gaussians
		test_file = self.test_file
		number_of_test_row, test_data = load_test_set(test_file)
		probability_dic = self.probability_of_classifiers()
		mixture_classify = GaussianMixtureClassification(test_data, self.data_dic, number_of_gaussians, probability_dic, number_of_test_row)
		for row in test_data:
			mixture_classify.classification(row)
		mixture_classify.display_accuracy()

	def probability_of_classifiers(self):
		"""Calculates probability of class labels
				
				Returns
				------------------------------------------------------
				probability_dic      : dictionary
						       class labels are key and their probabilities are dictionary
				"""
		probability_dic = {}
		for labels in self.unique_labels:
			probability = len(self.data_dic[labels]) / float(self.total_training_object)
			probability_dic[labels] = probability
		return probability_dic


class GaussianMixtureClassification:
	def __init__(self, test_data, data_dic, number_of_gaussians, probability_dic, total_test_rows):
		self.test_data = test_data
		self.data_dic = data_dic
		self.number_of_gaussians = number_of_gaussians
		self.probability_dic = probability_dic
		self.classifier_dic = {}
		self.accuracy_count = 0
		self.total_tes_rows = total_test_rows

	def classification(self, test_row):
		data_structure = {}
		for label in self.data_dic:
			for col in range(0, len(self.test_data[0][0:-2])):
				for gaussian in range(0, self.number_of_gaussians):
					pdf = GaussianMixtureTraining.calculate_normal(test_row[col], label, col, gaussian)
					pdf *= weight_dic[label][col][gaussian]
					if label in data_structure:
						if col in data_structure[label]:
							if gaussian in data_structure[label][col]:
								data_structure[label][col][gaussian] = pdf
							else:
								data_structure[label][col][gaussian] = pdf
						else:
							gaussian_dic = {}
							gaussian_dic[gaussian] = pdf
							data_structure[label][col] = gaussian_dic
					else:
						gaussian_dic = {}
						gaussian_dic[gaussian] = pdf
						col_dic = {}
						col_dic[col] = gaussian_dic
						data_structure[label] = col_dic
		data_struct = {}
		for label in self.data_dic:
			for col in range(0, len(self.test_data[0][0:-2])):
				for gaussian in range(0, self.number_of_gaussians):
					if label in data_struct:
						if col in data_struct[label]:
							data_struct[label][col] = data_struct[label][col] + data_structure[label][col][gaussian]
						else:
							data_struct[label][col] = data_structure[label][col][gaussian]
					else:

						data_struct[label] = {col: data_structure[label][col][gaussian]}
		posterior = {}
		for label in self.data_dic:
			for col in range(0, len(self.test_data[0][0:-2])):
				if label in posterior:
					posterior[label] = posterior[label] * data_struct[label][col]
				else:
					posterior[label] = data_struct[label][col] * self.probability_dic[label]
		summation = 0
		for label in posterior:
			summation += posterior[label]
		for label in posterior:
			if summation == 0:
				summation = 0.1
			posterior[label] /= (float(summation))
		maximum = -9999
		for label in posterior:
			if posterior[label] > maximum:
				maximum = posterior[label]
				predicted = label

		accuracy = 0
		if predicted == test_row[-2]:
			accuracy = 1
		self.accuracy_count += accuracy
		print("ID=%5d, predicted=%3d, probability = %.4lf, true=%3d, accuracy=%4.2lf" % (test_row[-1], predicted, maximum, test_row[-2], accuracy))

	def display_accuracy(self):
		print("classification accuracy=%6.4lf" % (self.accuracy_count / float(self.total_tes_rows)))


class GaussianMixtureTraining:
	def __init__(self, number_of_gaussians, data_dic):
		self.number_of_gaussians = number_of_gaussians
		self.data_dic = data_dic

	def initialise_parameters(self, column_number, label):
		mean = {}
		sigma = {}
		weight = {}
		maximum = -1
		minimum = 99999
		for row in self.data_dic[label]:
			if row[column_number] > maximum:
				maximum = row[column_number]
			elif row[column_number] < minimum:
				minimum = row[column_number]
		g = (maximum - minimum) / float(self.number_of_gaussians)
		for x in range(0, self.number_of_gaussians):
			mean[x] = minimum + x*g + g/2.0
			sigma[x] = 1
			weight[x] = 1.0/self.number_of_gaussians
		return mean, sigma, weight

	def e_step(self):
		""" Updates the normal distribution of every element in the training data """
		
		for label in self.data_dic:
			for col in range(len(self.data_dic[label][0])):
				for row in range(0, len(self.data_dic[label])):
					summation = 0.0
					for gaussian in range(0, self.number_of_gaussians):
						pdf = GaussianMixtureTraining.calculate_normal(self.data_dic[label][row][col], label, col, gaussian)
						pdf *= weight_dic[label][col][gaussian]
						summation += pdf
						if label in normal_dic:
							if col in normal_dic[label]:
								if row in normal_dic[label][col]:
									if gaussian in normal_dic[label][col][row]:
										normal_dic[label][col][row][gaussian] = pdf
									else:
										normal_dic[label][col][row][gaussian] = pdf
								else:
									normal_dict1 = {}
									normal_dict1[gaussian] = pdf
									normal_dic[label][col][row] = normal_dict1

							else:
								normal_dict1 = {}
								normal_dict1[gaussian] = pdf
								normal_dict2 = {}
								normal_dict2[row] = normal_dict1
								normal_dic[label][col] = normal_dict2

						else:
							normal_dict3 = {}
							normal_dict3[gaussian] = pdf
							normal_dict4 = {}
							normal_dict4[row] = normal_dict3
							normal_dict5 = {}
							normal_dict5[col] = normal_dict4
							normal_dic[label] = normal_dict5

					for gaussian in range(0, self.number_of_gaussians):
						normal_dic[label][col][row][gaussian] = float(normal_dic[label][col][row][gaussian] / summation)

	def m_step(self):
		""" Updates mean, sigma, and weights of of every gaussian for every dimension for every training data"""
		
		for label in self.data_dic:
			for col in range(0, len(self.data_dic[label][0])):
				for gaussian in range(0, self.number_of_gaussians):
					numerator = 0
					denominator = 0
					for row in range(0, len(self.data_dic[label])):
						numerator += normal_dic[label][col][row][gaussian] * self.data_dic[label][row][col]
						denominator += normal_dic[label][col][row][gaussian]
					mean_dic[label][col][gaussian] = numerator / denominator

				for gaussian in range(0, self.number_of_gaussians):
					numerator = 0
					denominator = 0
					for row in range(0, len(self.data_dic[label])):
						numerator += normal_dic[label][col][row][gaussian] * (math.pow((self.data_dic[label][row][col] - mean_dic[label][col][gaussian]), 2))
						denominator += normal_dic[label][col][row][gaussian]
					sigma_dic[label][col][gaussian] = math.sqrt(numerator / denominator)
				denominator = 0
				for gaussian in range(0, self.number_of_gaussians):
					for row in range(0, len(self.data_dic[label])):
						denominator += normal_dic[label][col][row][gaussian]
				for gaussian in range(0, self.number_of_gaussians):
					numerator = 0
					for row in range(0, len(self.data_dic[label])):
						numerator += normal_dic[label][col][row][gaussian]
					weight_dic[label][col][gaussian] = numerator / denominator

	@staticmethod
	def calculate_normal(value, label, col, gaussian):
		"""Calculates normal distribution

			Parameters
			------------------------------------------------------
			value     :    float
				       value of x in f(x)
			label     :    float
				       class label
			col       :    int
			      	       dimension number
			gaussian  :    int
				       gaussian number

			Returns
			------------------------------------------------------
			normal : float
					 normal distribution over a dimension.
		"""
		if sigma_dic[label][col][gaussian] < 0.01:
			sigma_dic[label][col][gaussian] = 0.01
		sigma = sigma_dic[label][col][gaussian]
		denominator = sigma * math.sqrt(2*math.pi)
		power = ((-1)*math.pow((value - mean_dic[label][col][gaussian]), 2)) / float((2*sigma*sigma))
		numerator = math.pow(math.e, power)
		normal = numerator / float(denominator)
		return normal


def load_data_set(filename):
	"""Loads the training data from a file to the dictionary

		Parameters
		------------------------------------------------------
		filename   :   string
			       File path of training data

		Returns
		------------------------------------------------------
		dictionary    : dictionary
				class label as key : list of rows as value
		unique_labels : list
		  		list of unique labels in the training data
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
		"""
	data_list = []
	input_file = open(filename, "r")
	unique_labels = []
	dictionary = {}
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list)
		if row_list[-1] in dictionary:
			dictionary[row_list[-1]].append(row_list[0:-1])
		else:
			unique_labels.append(row_list[-1])
			dictionary[row_list[-1]] = [row_list[0:-1]]
		loop_count += 1
	return dictionary, unique_labels, loop_count, data_list


def load_test_set(filename):
	""""Loads the testing data from a file to the dictionary

		Parameters
		------------------------------------------------------
		filename   :   string
		      	       file path of training data

		Returns
		------------------------------------------------------
		loop_count    : int
				number of training samples
		data_list     : list
				list of training data
	"""
	data_list = []
	input_file = open(filename, "r")
	print("⤵\n")
	loop_count = 0
	for line in input_file:
		row_list = (line.split(" "))
		row_list = list(filter(None, row_list))
		row_list = list(map(float, row_list))
		data_list.append(row_list+[loop_count])
		loop_count += 1
	return loop_count, data_list


def main():

	input_line = input()							# Taking file path from user as input
	print("⤵\n")
	input_list = input_line.split()  					# converting  the input to a list

	gaussian_mixture = GaussianMixture(input_list[1], input_list[2], int(input_list[4]))
	gaussian_mixture.train()
	gaussian_mixture.test()


main()


# ▶ Run and Enter ➜ naive_bayes data/yeast_training.txt data/yeast_test.txt mixtures 3
# or
# ▶ Run and Enter ➜ naive_bayes data/satellite_training.txt data/satellite_test.txt mixtures 3
# or
# ▶ Run and Enter ➜ naive_bayes data/pendigits_training.txt data/pendigits_test.txt mixtures 3
# Out:
# naive_bayes data/yeast_training.txt data/yeast_test.txt mixtures 3
# ⤵
#
# Class 1, attribute 0, Gaussian 0, mean = 0.50, std = 0.06
# Class 1, attribute 0, Gaussian 1, mean = 0.53, std = 0.10
# Class 1, attribute 0, Gaussian 2, mean = 0.52, std = 0.12
# Class 1, attribute 1, Gaussian 0, mean = 0.54, std = 0.08
# Class 1, attribute 1, Gaussian 1, mean = 0.53, std = 0.09
# Class 1, attribute 1, Gaussian 2, mean = 0.53, std = 0.18
# Class 1, attribute 2, Gaussian 0, mean = 0.50, std = 0.10
# Class 1, attribute 2, Gaussian 1, mean = 0.53, std = 0.06
# Class 1, attribute 2, Gaussian 2, mean = 0.51, std = 0.05
# Class 1, attribute 3, Gaussian 0, mean = 0.39, std = 0.17
# Class 1, attribute 3, Gaussian 1, mean = 0.41, std = 0.17
# Class 1, attribute 3, Gaussian 2, mean = 0.42, std = 0.17
# Class 1, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 1, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 1, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 1, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 1, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 1, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 1, attribute 6, Gaussian 0, mean = 0.46, std = 0.09
# Class 1, attribute 6, Gaussian 1, mean = 0.51, std = 0.03
# Class 1, attribute 6, Gaussian 2, mean = 0.51, std = 0.03
# Class 1, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 1, attribute 7, Gaussian 1, mean = 0.27, std = 0.01
# Class 1, attribute 7, Gaussian 2, mean = 0.32, std = 0.10
# Class 3, attribute 0, Gaussian 0, mean = 0.42, std = 0.10
# Class 3, attribute 0, Gaussian 1, mean = 0.43, std = 0.10
# Class 3, attribute 0, Gaussian 2, mean = 0.44, std = 0.10
# Class 3, attribute 1, Gaussian 0, mean = 0.45, std = 0.12
# Class 3, attribute 1, Gaussian 1, mean = 0.48, std = 0.10
# Class 3, attribute 1, Gaussian 2, mean = 0.49, std = 0.10
# Class 3, attribute 2, Gaussian 0, mean = 0.33, std = 0.07
# Class 3, attribute 2, Gaussian 1, mean = 0.39, std = 0.05
# Class 3, attribute 2, Gaussian 2, mean = 0.35, std = 0.03
# Class 3, attribute 3, Gaussian 0, mean = 0.17, std = 0.04
# Class 3, attribute 3, Gaussian 1, mean = 0.23, std = 0.05
# Class 3, attribute 3, Gaussian 2, mean = 0.34, std = 0.10
# Class 3, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 3, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 3, attribute 4, Gaussian 2, mean = 1.00, std = 0.00
# Class 3, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 3, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 3, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 3, attribute 6, Gaussian 0, mean = 0.46, std = 0.04
# Class 3, attribute 6, Gaussian 1, mean = 0.52, std = 0.02
# Class 3, attribute 6, Gaussian 2, mean = 0.53, std = 0.02
# Class 3, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 3, attribute 7, Gaussian 1, mean = 0.29, std = 0.03
# Class 3, attribute 7, Gaussian 2, mean = 0.48, std = 0.15
# Class 2, attribute 0, Gaussian 0, mean = 0.44, std = 0.10
# Class 2, attribute 0, Gaussian 1, mean = 0.45, std = 0.10
# Class 2, attribute 0, Gaussian 2, mean = 0.54, std = 0.17
# Class 2, attribute 1, Gaussian 0, mean = 0.45, std = 0.10
# Class 2, attribute 1, Gaussian 1, mean = 0.45, std = 0.10
# Class 2, attribute 1, Gaussian 2, mean = 0.46, std = 0.11
# Class 2, attribute 2, Gaussian 0, mean = 0.51, std = 0.07
# Class 2, attribute 2, Gaussian 1, mean = 0.53, std = 0.05
# Class 2, attribute 2, Gaussian 2, mean = 0.54, std = 0.05
# Class 2, attribute 3, Gaussian 0, mean = 0.16, std = 0.04
# Class 2, attribute 3, Gaussian 1, mean = 0.24, std = 0.07
# Class 2, attribute 3, Gaussian 2, mean = 0.36, std = 0.16
# Class 2, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 2, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 2, attribute 4, Gaussian 2, mean = 1.00, std = 0.00
# Class 2, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 2, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 2, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 2, attribute 6, Gaussian 0, mean = 0.45, std = 0.11
# Class 2, attribute 6, Gaussian 1, mean = 0.49, std = 0.04
# Class 2, attribute 6, Gaussian 2, mean = 0.51, std = 0.02
# Class 2, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 2, attribute 7, Gaussian 1, mean = 0.31, std = 0.06
# Class 2, attribute 7, Gaussian 2, mean = 0.50, std = 0.16
# Class 4, attribute 0, Gaussian 0, mean = 0.76, std = 0.05
# Class 4, attribute 0, Gaussian 1, mean = 0.76, std = 0.05
# Class 4, attribute 0, Gaussian 2, mean = 0.87, std = 0.07
# Class 4, attribute 1, Gaussian 0, mean = 0.76, std = 0.07
# Class 4, attribute 1, Gaussian 1, mean = 0.76, std = 0.07
# Class 4, attribute 1, Gaussian 2, mean = 0.76, std = 0.07
# Class 4, attribute 2, Gaussian 0, mean = 0.33, std = 0.03
# Class 4, attribute 2, Gaussian 1, mean = 0.40, std = 0.05
# Class 4, attribute 2, Gaussian 2, mean = 0.41, std = 0.05
# Class 4, attribute 3, Gaussian 0, mean = 0.29, std = 0.06
# Class 4, attribute 3, Gaussian 1, mean = 0.30, std = 0.06
# Class 4, attribute 3, Gaussian 2, mean = 0.39, std = 0.19
# Class 4, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 4, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 4, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 4, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 4, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 4, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 4, attribute 6, Gaussian 0, mean = 0.40, std = 0.09
# Class 4, attribute 6, Gaussian 1, mean = 0.50, std = 0.05
# Class 4, attribute 6, Gaussian 2, mean = 0.55, std = 0.01
# Class 4, attribute 7, Gaussian 0, mean = 0.22, std = 0.01
# Class 4, attribute 7, Gaussian 1, mean = 0.31, std = 0.02
# Class 4, attribute 7, Gaussian 2, mean = 0.43, std = 0.11
# Class 7, attribute 0, Gaussian 0, mean = 0.48, std = 0.11
# Class 7, attribute 0, Gaussian 1, mean = 0.48, std = 0.11
# Class 7, attribute 0, Gaussian 2, mean = 0.48, std = 0.11
# Class 7, attribute 1, Gaussian 0, mean = 0.45, std = 0.07
# Class 7, attribute 1, Gaussian 1, mean = 0.47, std = 0.09
# Class 7, attribute 1, Gaussian 2, mean = 0.49, std = 0.11
# Class 7, attribute 2, Gaussian 0, mean = 0.52, std = 0.04
# Class 7, attribute 2, Gaussian 1, mean = 0.53, std = 0.05
# Class 7, attribute 2, Gaussian 2, mean = 0.65, std = 0.12
# Class 7, attribute 3, Gaussian 0, mean = 0.16, std = 0.04
# Class 7, attribute 3, Gaussian 1, mean = 0.24, std = 0.06
# Class 7, attribute 3, Gaussian 2, mean = 0.41, std = 0.19
# Class 7, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 7, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 7, attribute 4, Gaussian 2, mean = 1.00, std = 0.00
# Class 7, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 7, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 7, attribute 5, Gaussian 2, mean = 0.50, std = 0.00
# Class 7, attribute 6, Gaussian 0, mean = 0.45, std = 0.12
# Class 7, attribute 6, Gaussian 1, mean = 0.49, std = 0.05
# Class 7, attribute 6, Gaussian 2, mean = 0.52, std = 0.03
# Class 7, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 7, attribute 7, Gaussian 1, mean = 0.27, std = 0.03
# Class 7, attribute 7, Gaussian 2, mean = 0.31, std = 0.16
# Class 8, attribute 0, Gaussian 0, mean = 0.45, std = 0.04
# Class 8, attribute 0, Gaussian 1, mean = 0.77, std = 0.05
# Class 8, attribute 0, Gaussian 2, mean = 0.77, std = 0.05
# Class 8, attribute 1, Gaussian 0, mean = 0.54, std = 0.14
# Class 8, attribute 1, Gaussian 1, mean = 0.71, std = 0.08
# Class 8, attribute 1, Gaussian 2, mean = 0.78, std = 0.05
# Class 8, attribute 2, Gaussian 0, mean = 0.49, std = 0.05
# Class 8, attribute 2, Gaussian 1, mean = 0.49, std = 0.05
# Class 8, attribute 2, Gaussian 2, mean = 0.50, std = 0.05
# Class 8, attribute 3, Gaussian 0, mean = 0.29, std = 0.07
# Class 8, attribute 3, Gaussian 1, mean = 0.29, std = 0.07
# Class 8, attribute 3, Gaussian 2, mean = 0.29, std = 0.07
# Class 8, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 8, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 8, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 8, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 8, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 8, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 8, attribute 6, Gaussian 0, mean = 0.36, std = 0.04
# Class 8, attribute 6, Gaussian 1, mean = 0.53, std = 0.03
# Class 8, attribute 6, Gaussian 2, mean = 0.48, std = 0.01
# Class 8, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 8, attribute 7, Gaussian 1, mean = 0.22, std = 0.00
# Class 8, attribute 7, Gaussian 2, mean = 0.27, std = 0.00
# Class 5, attribute 0, Gaussian 0, mean = 0.50, std = 0.13
# Class 5, attribute 0, Gaussian 1, mean = 0.72, std = 0.08
# Class 5, attribute 0, Gaussian 2, mean = 0.86, std = 0.06
# Class 5, attribute 1, Gaussian 0, mean = 0.58, std = 0.13
# Class 5, attribute 1, Gaussian 1, mean = 0.61, std = 0.13
# Class 5, attribute 1, Gaussian 2, mean = 0.67, std = 0.09
# Class 5, attribute 2, Gaussian 0, mean = 0.38, std = 0.05
# Class 5, attribute 2, Gaussian 1, mean = 0.46, std = 0.08
# Class 5, attribute 2, Gaussian 2, mean = 0.52, std = 0.06
# Class 5, attribute 3, Gaussian 0, mean = 0.19, std = 0.04
# Class 5, attribute 3, Gaussian 1, mean = 0.38, std = 0.09
# Class 5, attribute 3, Gaussian 2, mean = 0.39, std = 0.09
# Class 5, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 5, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 5, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 5, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 5, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 5, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 5, attribute 6, Gaussian 0, mean = 0.38, std = 0.05
# Class 5, attribute 6, Gaussian 1, mean = 0.56, std = 0.03
# Class 5, attribute 6, Gaussian 2, mean = 0.52, std = 0.02
# Class 5, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 5, attribute 7, Gaussian 1, mean = 0.22, std = 0.00
# Class 5, attribute 7, Gaussian 2, mean = 0.30, std = 0.05
# Class 6, attribute 0, Gaussian 0, mean = 0.44, std = 0.04
# Class 6, attribute 0, Gaussian 1, mean = 0.58, std = 0.09
# Class 6, attribute 0, Gaussian 2, mean = 0.73, std = 0.06
# Class 6, attribute 1, Gaussian 0, mean = 0.48, std = 0.07
# Class 6, attribute 1, Gaussian 1, mean = 0.49, std = 0.13
# Class 6, attribute 1, Gaussian 2, mean = 0.53, std = 0.13
# Class 6, attribute 2, Gaussian 0, mean = 0.49, std = 0.04
# Class 6, attribute 2, Gaussian 1, mean = 0.51, std = 0.05
# Class 6, attribute 2, Gaussian 2, mean = 0.52, std = 0.05
# Class 6, attribute 3, Gaussian 0, mean = 0.19, std = 0.01
# Class 6, attribute 3, Gaussian 1, mean = 0.22, std = 0.07
# Class 6, attribute 3, Gaussian 2, mean = 0.45, std = 0.01
# Class 6, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 6, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 6, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 6, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 6, attribute 5, Gaussian 1, mean = 0.50, std = 0.00
# Class 6, attribute 5, Gaussian 2, mean = 0.83, std = 0.00
# Class 6, attribute 6, Gaussian 0, mean = 0.42, std = 0.00
# Class 6, attribute 6, Gaussian 1, mean = 0.51, std = 0.02
# Class 6, attribute 6, Gaussian 2, mean = 0.52, std = 0.02
# Class 6, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 6, attribute 7, Gaussian 1, mean = 0.22, std = 0.00
# Class 6, attribute 7, Gaussian 2, mean = 0.34, std = 0.07
# Class 9, attribute 0, Gaussian 0, mean = 0.53, std = 0.13
# Class 9, attribute 0, Gaussian 1, mean = 0.55, std = 0.14
# Class 9, attribute 0, Gaussian 2, mean = 0.56, std = 0.14
# Class 9, attribute 1, Gaussian 0, mean = 0.55, std = 0.15
# Class 9, attribute 1, Gaussian 1, mean = 0.56, std = 0.15
# Class 9, attribute 1, Gaussian 2, mean = 0.56, std = 0.15
# Class 9, attribute 2, Gaussian 0, mean = 0.37, std = 0.02
# Class 9, attribute 2, Gaussian 1, mean = 0.48, std = 0.02
# Class 9, attribute 2, Gaussian 2, mean = 0.55, std = 0.02
# Class 9, attribute 3, Gaussian 0, mean = 0.20, std = 0.06
# Class 9, attribute 3, Gaussian 1, mean = 0.20, std = 0.06
# Class 9, attribute 3, Gaussian 2, mean = 0.20, std = 0.06
# Class 9, attribute 4, Gaussian 0, mean = 0.50, std = 0.00
# Class 9, attribute 4, Gaussian 1, mean = 0.50, std = 0.00
# Class 9, attribute 4, Gaussian 2, mean = 0.50, std = 0.00
# Class 9, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 9, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 9, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 9, attribute 6, Gaussian 0, mean = 0.42, std = 0.05
# Class 9, attribute 6, Gaussian 1, mean = 0.56, std = 0.04
# Class 9, attribute 6, Gaussian 2, mean = 0.52, std = 0.03
# Class 9, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 9, attribute 7, Gaussian 1, mean = 0.26, std = 0.01
# Class 9, attribute 7, Gaussian 2, mean = 0.40, std = 0.00
# Class 10, attribute 0, Gaussian 0, mean = 0.77, std = 0.05
# Class 10, attribute 0, Gaussian 1, mean = 0.78, std = 0.05
# Class 10, attribute 0, Gaussian 2, mean = 0.78, std = 0.05
# Class 10, attribute 1, Gaussian 0, mean = 0.56, std = 0.00
# Class 10, attribute 1, Gaussian 1, mean = 0.74, std = 0.00
# Class 10, attribute 1, Gaussian 2, mean = 0.82, std = 0.02
# Class 10, attribute 2, Gaussian 0, mean = 0.33, std = 0.00
# Class 10, attribute 2, Gaussian 1, mean = 0.50, std = 0.01
# Class 10, attribute 2, Gaussian 2, mean = 0.53, std = 0.04
# Class 10, attribute 3, Gaussian 0, mean = 0.33, std = 0.06
# Class 10, attribute 3, Gaussian 1, mean = 0.33, std = 0.06
# Class 10, attribute 3, Gaussian 2, mean = 0.33, std = 0.06
# Class 10, attribute 4, Gaussian 0, mean = 1.00, std = 0.00
# Class 10, attribute 4, Gaussian 1, mean = 1.00, std = 0.00
# Class 10, attribute 4, Gaussian 2, mean = 1.00, std = 0.00
# Class 10, attribute 5, Gaussian 0, mean = 0.00, std = 0.00
# Class 10, attribute 5, Gaussian 1, mean = 0.00, std = 0.00
# Class 10, attribute 5, Gaussian 2, mean = 0.00, std = 0.00
# Class 10, attribute 6, Gaussian 0, mean = 0.54, std = 0.01
# Class 10, attribute 6, Gaussian 1, mean = 0.58, std = 0.00
# Class 10, attribute 6, Gaussian 2, mean = 0.58, std = 0.00
# Class 10, attribute 7, Gaussian 0, mean = 0.22, std = 0.00
# Class 10, attribute 7, Gaussian 1, mean = 0.24, std = 0.01
# Class 10, attribute 7, Gaussian 2, mean = 0.25, std = 0.00
# ⤵
#
# ID=    0, predicted=  3, probability = 0.9354, true=  3, accuracy=1.00
# ID=    1, predicted=  7, probability = 0.4629, true=  7, accuracy=1.00
# ID=    2, predicted=  7, probability = 0.6195, true=  7, accuracy=1.00
# ID=    3, predicted=  7, probability = 0.5524, true=  2, accuracy=0.00
# ID=    4, predicted=  2, probability = 0.8392, true=  2, accuracy=1.00
# ID=    5, predicted=  2, probability = 0.7319, true=  2, accuracy=1.00
# ID=    6, predicted=  7, probability = 0.3526, true=  7, accuracy=1.00
# ID=    7, predicted=  1, probability = 0.7330, true=  1, accuracy=1.00
# ID=    8, predicted=  7, probability = 0.5739, true=  7, accuracy=1.00
# ID=    9, predicted=  7, probability = 0.6019, true=  7, accuracy=1.00
# ID=   10, predicted=  3, probability = 0.8416, true=  3, accuracy=1.00
# ID=   11, predicted=  7, probability = 0.3862, true=  6, accuracy=0.00
# ID=   12, predicted=  1, probability = 0.6144, true=  2, accuracy=0.00
# ID=   13, predicted=  2, probability = 0.6027, true=  5, accuracy=0.00
# ID=   14, predicted=  5, probability = 0.7860, true=  5, accuracy=1.00
# ID=   15, predicted=  7, probability = 0.7767, true=  7, accuracy=1.00
# ID=   16, predicted=  2, probability = 0.3589, true=  3, accuracy=0.00
# ID=   17, predicted=  2, probability = 0.8627, true=  2, accuracy=1.00
# ID=   18, predicted=  2, probability = 0.7850, true=  3, accuracy=0.00
# ID=   19, predicted=  7, probability = 0.4960, true=  2, accuracy=0.00
# ID=   20, predicted=  2, probability = 0.6629, true=  2, accuracy=1.00
# ID=   21, predicted=  3, probability = 0.9397, true=  3, accuracy=1.00
# ID=   22, predicted=  2, probability = 0.5400, true=  2, accuracy=1.00
# ID=   23, predicted=  5, probability = 0.2457, true=  5, accuracy=1.00
# ID=   24, predicted=  2, probability = 0.4991, true=  3, accuracy=0.00
# ID=   25, predicted=  2, probability = 0.5390, true=  2, accuracy=1.00
# ID=   26, predicted=  2, probability = 0.7170, true=  2, accuracy=1.00
# ID=   27, predicted=  7, probability = 0.6656, true=  7, accuracy=1.00
# ID=   28, predicted=  3, probability = 0.7483, true=  3, accuracy=1.00
# ID=   29, predicted=  9, probability = 0.7464, true=  9, accuracy=1.00
# ID=   30, predicted=  1, probability = 0.4181, true=  7, accuracy=0.00
# ID=   31, predicted=  1, probability = 0.7542, true=  7, accuracy=0.00
# ID=   32, predicted=  7, probability = 0.4302, true=  7, accuracy=1.00
# ID=   33, predicted=  1, probability = 0.8239, true=  1, accuracy=1.00
# ID=   34, predicted=  7, probability = 0.4466, true=  7, accuracy=1.00
# ID=   35, predicted=  3, probability = 0.9597, true=  3, accuracy=1.00
# ID=   36, predicted=  3, probability = 0.9156, true=  3, accuracy=1.00
# ID=   37, predicted=  7, probability = 0.5252, true=  2, accuracy=0.00
# ID=   38, predicted=  2, probability = 0.5776, true=  7, accuracy=0.00
# ID=   39, predicted=  7, probability = 0.7062, true=  7, accuracy=1.00
# ID=   40, predicted=  7, probability = 0.3018, true=  3, accuracy=0.00
# ID=   41, predicted=  5, probability = 0.8104, true=  9, accuracy=0.00
# ID=   42, predicted=  1, probability = 0.2705, true=  1, accuracy=1.00
# ID=   43, predicted=  2, probability = 0.8373, true=  2, accuracy=1.00
# ID=   44, predicted=  2, probability = 0.6301, true=  2, accuracy=1.00
# ID=   45, predicted=  7, probability = 0.5926, true=  2, accuracy=0.00
# ID=   46, predicted=  7, probability = 0.7554, true=  7, accuracy=1.00
# ID=   47, predicted=  1, probability = 0.7045, true=  1, accuracy=1.00
# ID=   48, predicted=  1, probability = 0.5652, true=  1, accuracy=1.00
# ID=   49, predicted=  1, probability = 0.4733, true=  1, accuracy=1.00
# ID=   50, predicted=  2, probability = 0.8188, true=  7, accuracy=0.00
# ID=   51, predicted=  7, probability = 0.4860, true=  7, accuracy=1.00
# ID=   52, predicted=  7, probability = 0.7081, true=  2, accuracy=0.00
# ID=   53, predicted=  2, probability = 0.6998, true=  2, accuracy=1.00
# ID=   54, predicted=  7, probability = 0.5119, true=  7, accuracy=1.00
# ID=   55, predicted=  7, probability = 0.5312, true=  2, accuracy=0.00
# ID=   56, predicted=  1, probability = 0.7344, true=  2, accuracy=0.00
# ID=   57, predicted=  7, probability = 0.8829, true=  2, accuracy=0.00
# ID=   58, predicted=  3, probability = 0.4605, true=  3, accuracy=1.00
# ID=   59, predicted=  2, probability = 0.3791, true=  3, accuracy=0.00
# ID=   60, predicted=  2, probability = 0.3558, true=  2, accuracy=1.00
# ID=   61, predicted=  2, probability = 0.6202, true=  2, accuracy=1.00
# ID=   62, predicted=  1, probability = 0.6210, true=  1, accuracy=1.00
# ID=   63, predicted=  8, probability = 0.8974, true=  8, accuracy=1.00
# ID=   64, predicted=  3, probability = 0.8841, true=  3, accuracy=1.00
# ID=   65, predicted=  8, probability = 0.3704, true=  9, accuracy=0.00
# ID=   66, predicted=  7, probability = 0.5913, true=  2, accuracy=0.00
# ID=   67, predicted=  8, probability = 0.9020, true=  8, accuracy=1.00
# ID=   68, predicted=  7, probability = 0.5931, true=  7, accuracy=1.00
# ID=   69, predicted=  7, probability = 0.4990, true=  2, accuracy=0.00
# ID=   70, predicted=  3, probability = 0.9419, true=  9, accuracy=0.00
# ID=   71, predicted=  2, probability = 0.4913, true=  2, accuracy=1.00
# ID=   72, predicted=  3, probability = 0.8774, true=  3, accuracy=1.00
# ID=   73, predicted=  7, probability = 0.4629, true=  7, accuracy=1.00
# ID=   74, predicted=  7, probability = 0.5586, true=  7, accuracy=1.00
# ID=   75, predicted=  7, probability = 0.6991, true=  9, accuracy=0.00
# ID=   76, predicted=  3, probability = 0.5312, true=  3, accuracy=1.00
# ID=   77, predicted=  7, probability = 0.5798, true=  7, accuracy=1.00
# ID=   78, predicted=  4, probability = 0.5549, true=  8, accuracy=0.00
# ID=   79, predicted=  7, probability = 0.6704, true=  7, accuracy=1.00
# ID=   80, predicted=  2, probability = 0.5564, true=  7, accuracy=0.00
# ID=   81, predicted=  5, probability = 0.7460, true=  5, accuracy=1.00
# ID=   82, predicted=  3, probability = 0.5765, true=  5, accuracy=0.00
# ID=   83, predicted=  2, probability = 0.5852, true=  7, accuracy=0.00
# ID=   84, predicted=  7, probability = 0.4453, true=  1, accuracy=0.00
# ID=   85, predicted=  4, probability = 0.9128, true=  4, accuracy=1.00
# ID=   86, predicted=  1, probability = 0.5718, true=  7, accuracy=0.00
# ID=   87, predicted=  3, probability = 0.9064, true=  3, accuracy=1.00
# ID=   88, predicted=  2, probability = 0.7411, true=  2, accuracy=1.00
# ID=   89, predicted=  2, probability = 0.8997, true=  7, accuracy=0.00
# ID=   90, predicted=  7, probability = 0.4890, true=  7, accuracy=1.00
# ID=   91, predicted=  7, probability = 0.6458, true=  7, accuracy=1.00
# ID=   92, predicted=  7, probability = 0.9559, true=  7, accuracy=1.00
# ID=   93, predicted=  1, probability = 0.9248, true=  1, accuracy=1.00
# ID=   94, predicted=  1, probability = 0.4447, true=  2, accuracy=0.00
# ID=   95, predicted=  2, probability = 0.4876, true=  2, accuracy=1.00
# ID=   96, predicted=  1, probability = 0.9013, true=  1, accuracy=1.00
# ID=   97, predicted=  7, probability = 0.6430, true=  2, accuracy=0.00
# ID=   98, predicted=  7, probability = 0.6092, true=  7, accuracy=1.00
# ID=   99, predicted=  2, probability = 0.9116, true=  2, accuracy=1.00
# ID=  100, predicted=  3, probability = 0.5455, true=  3, accuracy=1.00
# ID=  101, predicted=  3, probability = 0.9186, true=  3, accuracy=1.00
# ID=  102, predicted=  2, probability = 0.6749, true=  2, accuracy=1.00
# ID=  103, predicted=  1, probability = 0.7573, true=  7, accuracy=0.00
# ID=  104, predicted=  3, probability = 0.5598, true=  3, accuracy=1.00
# ID=  105, predicted=  3, probability = 0.9806, true=  9, accuracy=0.00
# ID=  106, predicted=  2, probability = 0.3756, true=  6, accuracy=0.00
# ID=  107, predicted=  7, probability = 0.5594, true=  7, accuracy=1.00
# ID=  108, predicted=  2, probability = 0.5832, true=  7, accuracy=0.00
# ID=  109, predicted=  7, probability = 0.7695, true=  1, accuracy=0.00
# ID=  110, predicted=  1, probability = 0.4069, true=  2, accuracy=0.00
# ID=  111, predicted=  1, probability = 0.5569, true=  2, accuracy=0.00
# ID=  112, predicted=  7, probability = 0.5475, true=  7, accuracy=1.00
# ID=  113, predicted=  1, probability = 0.7805, true=  1, accuracy=1.00
# ID=  114, predicted=  7, probability = 0.6409, true=  7, accuracy=1.00
# ID=  115, predicted=  3, probability = 0.6927, true=  2, accuracy=0.00
# ID=  116, predicted=  3, probability = 0.3275, true=  2, accuracy=0.00
# ID=  117, predicted=  8, probability = 0.9810, true=  8, accuracy=1.00
# ID=  118, predicted=  2, probability = 0.5411, true=  5, accuracy=0.00
# ID=  119, predicted=  2, probability = 0.6835, true=  2, accuracy=1.00
# ID=  120, predicted=  7, probability = 0.7366, true=  7, accuracy=1.00
# ID=  121, predicted=  7, probability = 0.4689, true=  2, accuracy=0.00
# ID=  122, predicted=  4, probability = 0.7273, true=  4, accuracy=1.00
# ID=  123, predicted=  7, probability = 0.6594, true=  7, accuracy=1.00
# ID=  124, predicted=  1, probability = 0.7915, true=  1, accuracy=1.00
# ID=  125, predicted=  7, probability = 0.4350, true=  7, accuracy=1.00
# ID=  126, predicted=  7, probability = 0.6868, true=  7, accuracy=1.00
# ID=  127, predicted=  7, probability = 0.4619, true=  7, accuracy=1.00
# ID=  128, predicted=  2, probability = 0.8275, true=  7, accuracy=0.00
# ID=  129, predicted=  2, probability = 0.6497, true=  2, accuracy=1.00
# ID=  130, predicted=  2, probability = 0.8233, true=  7, accuracy=0.00
# ID=  131, predicted=  9, probability = 0.4549, true=  2, accuracy=0.00
# ID=  132, predicted=  7, probability = 0.3324, true=  2, accuracy=0.00
# ID=  133, predicted=  7, probability = 0.6156, true=  2, accuracy=0.00
# ID=  134, predicted=  7, probability = 0.4123, true=  1, accuracy=0.00
# ID=  135, predicted=  7, probability = 0.6072, true=  7, accuracy=1.00
# ID=  136, predicted=  8, probability = 0.4497, true=  8, accuracy=1.00
# ID=  137, predicted=  3, probability = 0.9674, true=  3, accuracy=1.00
# ID=  138, predicted=  2, probability = 0.5136, true=  2, accuracy=1.00
# ID=  139, predicted=  5, probability = 0.2389, true=  2, accuracy=0.00
# ID=  140, predicted=  2, probability = 0.6952, true=  7, accuracy=0.00
# ID=  141, predicted=  7, probability = 0.7232, true=  2, accuracy=0.00
# ID=  142, predicted=  3, probability = 0.9642, true=  3, accuracy=1.00
# ID=  143, predicted=  1, probability = 0.7828, true=  1, accuracy=1.00
# ID=  144, predicted=  7, probability = 0.4067, true=  7, accuracy=1.00
# ID=  145, predicted=  3, probability = 0.9067, true=  2, accuracy=0.00
# ID=  146, predicted=  2, probability = 0.6995, true=  2, accuracy=1.00
# ID=  147, predicted=  6, probability = 0.7742, true=  1, accuracy=0.00
# ID=  148, predicted=  2, probability = 0.4858, true=  2, accuracy=1.00
# ID=  149, predicted=  2, probability = 0.7165, true=  2, accuracy=1.00
# ID=  150, predicted=  2, probability = 0.6775, true=  7, accuracy=0.00
# ID=  151, predicted=  2, probability = 0.6043, true=  2, accuracy=1.00
# ID=  152, predicted=  2, probability = 0.7373, true=  2, accuracy=1.00
# ID=  153, predicted=  7, probability = 0.6333, true=  1, accuracy=0.00
# ID=  154, predicted=  5, probability = 0.6836, true=  5, accuracy=1.00
# ID=  155, predicted=  2, probability = 0.7023, true=  2, accuracy=1.00
# ID=  156, predicted=  2, probability = 0.6122, true=  7, accuracy=0.00
# ID=  157, predicted=  1, probability = 0.8691, true=  7, accuracy=0.00
# ID=  158, predicted=  7, probability = 0.8036, true=  7, accuracy=1.00
# ID=  159, predicted=  1, probability = 0.5141, true=  2, accuracy=0.00
# ID=  160, predicted=  7, probability = 0.6573, true=  7, accuracy=1.00
# ID=  161, predicted=  1, probability = 0.5851, true=  1, accuracy=1.00
# ID=  162, predicted=  7, probability = 0.3723, true=  2, accuracy=0.00
# ID=  163, predicted=  1, probability = 0.6773, true=  1, accuracy=1.00
# ID=  164, predicted=  4, probability = 0.6942, true=  4, accuracy=1.00
# ID=  165, predicted=  2, probability = 0.9221, true=  7, accuracy=0.00
# ID=  166, predicted=  7, probability = 0.5390, true=  7, accuracy=1.00
# ID=  167, predicted=  2, probability = 0.7314, true=  2, accuracy=1.00
# ID=  168, predicted=  7, probability = 0.6200, true=  2, accuracy=0.00
# ID=  169, predicted=  1, probability = 0.5428, true=  1, accuracy=1.00
# ID=  170, predicted=  1, probability = 0.5673, true=  1, accuracy=1.00
# ID=  171, predicted=  4, probability = 0.5011, true=  4, accuracy=1.00
# ID=  172, predicted=  5, probability = 0.6122, true=  1, accuracy=0.00
# ID=  173, predicted=  7, probability = 0.4455, true=  7, accuracy=1.00
# ID=  174, predicted=  2, probability = 0.6966, true=  2, accuracy=1.00
# ID=  175, predicted=  7, probability = 0.6712, true=  7, accuracy=1.00
# ID=  176, predicted=  2, probability = 0.7250, true=  2, accuracy=1.00
# ID=  177, predicted=  1, probability = 0.7748, true=  1, accuracy=1.00
# ID=  178, predicted=  7, probability = 0.6096, true=  7, accuracy=1.00
# ID=  179, predicted=  7, probability = 0.7966, true=  7, accuracy=1.00
# ID=  180, predicted=  4, probability = 0.6393, true=  4, accuracy=1.00
# ID=  181, predicted=  3, probability = 0.9801, true=  3, accuracy=1.00
# ID=  182, predicted=  3, probability = 0.8464, true=  3, accuracy=1.00
# ID=  183, predicted=  2, probability = 0.5269, true=  2, accuracy=1.00
# ID=  184, predicted=  2, probability = 0.6389, true=  2, accuracy=1.00
# ID=  185, predicted=  7, probability = 0.7240, true=  7, accuracy=1.00
# ID=  186, predicted=  2, probability = 0.6010, true=  3, accuracy=0.00
# ID=  187, predicted=  7, probability = 0.6045, true=  7, accuracy=1.00
# ID=  188, predicted=  2, probability = 0.8996, true=  2, accuracy=1.00
# ID=  189, predicted=  1, probability = 0.8671, true=  1, accuracy=1.00
# ID=  190, predicted=  7, probability = 0.6586, true=  7, accuracy=1.00
# ID=  191, predicted=  7, probability = 0.5602, true=  7, accuracy=1.00
# ID=  192, predicted=  7, probability = 0.3520, true=  7, accuracy=1.00
# ID=  193, predicted=  1, probability = 0.8384, true=  9, accuracy=0.00
# ID=  194, predicted=  1, probability = 0.3487, true=  1, accuracy=1.00
# ID=  195, predicted=  7, probability = 0.5388, true=  2, accuracy=0.00
# ID=  196, predicted=  7, probability = 0.5015, true=  2, accuracy=0.00
# ID=  197, predicted=  3, probability = 0.7867, true=  3, accuracy=1.00
# ID=  198, predicted=  7, probability = 0.5908, true=  7, accuracy=1.00
# ID=  199, predicted=  7, probability = 0.5908, true=  7, accuracy=1.00
# ID=  200, predicted=  3, probability = 0.6286, true=  1, accuracy=0.00
# ID=  201, predicted=  3, probability = 0.8393, true=  3, accuracy=1.00
# ID=  202, predicted=  2, probability = 0.5802, true=  2, accuracy=1.00
# ID=  203, predicted=  2, probability = 0.5710, true=  7, accuracy=0.00
# ID=  204, predicted=  3, probability = 0.8333, true=  3, accuracy=1.00
# ID=  205, predicted=  3, probability = 0.9505, true=  3, accuracy=1.00
# ID=  206, predicted=  2, probability = 0.7073, true=  7, accuracy=0.00
# ID=  207, predicted=  7, probability = 0.5240, true=  1, accuracy=0.00
# ID=  208, predicted=  3, probability = 0.9784, true=  3, accuracy=1.00
# ID=  209, predicted=  2, probability = 0.4858, true=  2, accuracy=1.00
# ID=  210, predicted=  1, probability = 0.5485, true=  3, accuracy=0.00
# ID=  211, predicted=  7, probability = 0.6395, true=  2, accuracy=0.00
# ID=  212, predicted=  7, probability = 0.8258, true=  1, accuracy=0.00
# ID=  213, predicted=  7, probability = 0.6393, true=  1, accuracy=0.00
# ID=  214, predicted=  2, probability = 0.5030, true=  7, accuracy=0.00
# ID=  215, predicted=  2, probability = 0.6398, true=  2, accuracy=1.00
# ID=  216, predicted=  1, probability = 0.9455, true=  1, accuracy=1.00
# ID=  217, predicted=  7, probability = 0.3220, true=  3, accuracy=0.00
# ID=  218, predicted=  1, probability = 0.5237, true=  1, accuracy=1.00
# ID=  219, predicted=  1, probability = 0.8047, true=  1, accuracy=1.00
# ID=  220, predicted=  7, probability = 0.6018, true=  2, accuracy=0.00
# ID=  221, predicted=  7, probability = 0.6779, true=  7, accuracy=1.00
# ID=  222, predicted=  3, probability = 0.6259, true=  3, accuracy=1.00
# ID=  223, predicted=  1, probability = 0.6432, true=  1, accuracy=1.00
# ID=  224, predicted=  8, probability = 0.6664, true=  8, accuracy=1.00
# ID=  225, predicted=  2, probability = 0.9119, true=  7, accuracy=0.00
# ID=  226, predicted=  1, probability = 0.9158, true=  1, accuracy=1.00
# ID=  227, predicted=  1, probability = 0.5329, true=  7, accuracy=0.00
# ID=  228, predicted=  7, probability = 0.6458, true=  9, accuracy=0.00
# ID=  229, predicted=  7, probability = 0.4719, true=  1, accuracy=0.00
# ID=  230, predicted=  7, probability = 0.7222, true=  1, accuracy=0.00
# ID=  231, predicted=  7, probability = 1.0000, true=  7, accuracy=1.00
# ID=  232, predicted=  3, probability = 0.7372, true=  3, accuracy=1.00
# ID=  233, predicted=  7, probability = 0.5713, true=  7, accuracy=1.00
# ID=  234, predicted=  4, probability = 0.5110, true=  1, accuracy=0.00
# ID=  235, predicted=  2, probability = 0.6134, true=  2, accuracy=1.00
# ID=  236, predicted=  2, probability = 0.6755, true=  7, accuracy=0.00
# ID=  237, predicted=  7, probability = 0.5515, true=  1, accuracy=0.00
# ID=  238, predicted=  9, probability = 0.4273, true=  4, accuracy=0.00
# ID=  239, predicted=  5, probability = 0.6261, true=  3, accuracy=0.00
# ID=  240, predicted=  7, probability = 0.7230, true=  7, accuracy=1.00
# ID=  241, predicted=  7, probability = 0.6126, true=  7, accuracy=1.00
# ID=  242, predicted=  1, probability = 0.7708, true=  3, accuracy=0.00
# ID=  243, predicted=  8, probability = 0.5609, true=  8, accuracy=1.00
# ID=  244, predicted=  2, probability = 0.5912, true=  2, accuracy=1.00
# ID=  245, predicted=  2, probability = 0.5221, true=  7, accuracy=0.00
# ID=  246, predicted=  2, probability = 0.7209, true=  2, accuracy=1.00
# ID=  247, predicted=  2, probability = 0.8240, true=  1, accuracy=0.00
# ID=  248, predicted=  7, probability = 0.5616, true=  7, accuracy=1.00
# ID=  249, predicted=  1, probability = 0.6656, true=  1, accuracy=1.00
# ID=  250, predicted=  7, probability = 0.6336, true=  9, accuracy=0.00
# ID=  251, predicted=  3, probability = 0.7315, true=  3, accuracy=1.00
# ID=  252, predicted=  2, probability = 0.5688, true=  1, accuracy=0.00
# ID=  253, predicted=  7, probability = 0.5208, true=  7, accuracy=1.00
# ID=  254, predicted=  1, probability = 0.9149, true=  1, accuracy=1.00
# ID=  255, predicted=  4, probability = 0.4768, true=  4, accuracy=1.00
# ID=  256, predicted=  3, probability = 0.5071, true=  3, accuracy=1.00
# ID=  257, predicted=  2, probability = 0.9571, true=  2, accuracy=1.00
# ID=  258, predicted=  7, probability = 0.5281, true=  1, accuracy=0.00
# ID=  259, predicted=  2, probability = 0.7608, true=  3, accuracy=0.00
# ID=  260, predicted=  7, probability = 0.6334, true=  2, accuracy=0.00
# ID=  261, predicted=  9, probability = 0.6804, true=  2, accuracy=0.00
# ID=  262, predicted=  4, probability = 0.8849, true=  4, accuracy=1.00
# ID=  263, predicted=  7, probability = 0.7736, true=  9, accuracy=0.00
# ID=  264, predicted=  7, probability = 0.4547, true=  2, accuracy=0.00
# ID=  265, predicted=  2, probability = 0.3922, true=  2, accuracy=1.00
# ID=  266, predicted=  4, probability = 0.8236, true=  4, accuracy=1.00
# ID=  267, predicted=  7, probability = 0.4527, true=  7, accuracy=1.00
# ID=  268, predicted=  1, probability = 0.8003, true=  7, accuracy=0.00
# ID=  269, predicted=  7, probability = 0.6591, true=  7, accuracy=1.00
# ID=  270, predicted=  7, probability = 0.7133, true=  7, accuracy=1.00
# ID=  271, predicted=  7, probability = 0.5329, true=  7, accuracy=1.00
# ID=  272, predicted=  4, probability = 0.9423, true=  8, accuracy=0.00
# ID=  273, predicted=  2, probability = 0.5898, true=  2, accuracy=1.00
# ID=  274, predicted=  7, probability = 0.4992, true=  2, accuracy=0.00
# ID=  275, predicted=  7, probability = 0.4402, true=  7, accuracy=1.00
# ID=  276, predicted=  3, probability = 0.9287, true=  3, accuracy=1.00
# ID=  277, predicted=  2, probability = 0.4468, true=  2, accuracy=1.00
# ID=  278, predicted=  7, probability = 0.3131, true=  1, accuracy=0.00
# ID=  279, predicted=  7, probability = 0.7045, true=  2, accuracy=0.00
# ID=  280, predicted=  7, probability = 0.3692, true=  7, accuracy=1.00
# ID=  281, predicted=  8, probability = 0.5389, true=  7, accuracy=0.00
# ID=  282, predicted=  2, probability = 0.8613, true=  2, accuracy=1.00
# ID=  283, predicted=  1, probability = 0.7028, true=  7, accuracy=0.00
# ID=  284, predicted=  2, probability = 0.4551, true=  2, accuracy=1.00
# ID=  285, predicted=  7, probability = 0.5935, true=  7, accuracy=1.00
# ID=  286, predicted=  7, probability = 0.3757, true=  2, accuracy=0.00
# ID=  287, predicted=  7, probability = 0.7139, true=  7, accuracy=1.00
# ID=  288, predicted=  3, probability = 0.6828, true=  3, accuracy=1.00
# ID=  289, predicted=  3, probability = 0.4295, true=  2, accuracy=0.00
# ID=  290, predicted=  3, probability = 0.4169, true=  3, accuracy=1.00
# ID=  291, predicted=  5, probability = 0.6486, true=  5, accuracy=1.00
# ID=  292, predicted=  7, probability = 0.6817, true=  2, accuracy=0.00
# ID=  293, predicted=  7, probability = 0.5518, true=  7, accuracy=1.00
# ID=  294, predicted=  7, probability = 0.6670, true=  8, accuracy=0.00
# ID=  295, predicted=  2, probability = 0.5519, true=  1, accuracy=0.00
# ID=  296, predicted=  3, probability = 0.7344, true=  3, accuracy=1.00
# ID=  297, predicted=  3, probability = 0.5049, true=  2, accuracy=0.00
# ID=  298, predicted=  7, probability = 0.6541, true=  7, accuracy=1.00
# ID=  299, predicted=  6, probability = 1.0000, true=  1, accuracy=0.00
# ID=  300, predicted=  7, probability = 0.7460, true=  7, accuracy=1.00
# ID=  301, predicted=  1, probability = 0.6219, true=  1, accuracy=1.00
# ID=  302, predicted=  7, probability = 0.5414, true=  1, accuracy=0.00
# ID=  303, predicted=  2, probability = 0.7585, true=  3, accuracy=0.00
# ID=  304, predicted=  2, probability = 0.6140, true=  2, accuracy=1.00
# ID=  305, predicted=  2, probability = 0.7473, true=  2, accuracy=1.00
# ID=  306, predicted=  8, probability = 0.4954, true=  7, accuracy=0.00
# ID=  307, predicted=  7, probability = 0.4535, true=  8, accuracy=0.00
# ID=  308, predicted=  7, probability = 0.5399, true=  7, accuracy=1.00
# ID=  309, predicted=  1, probability = 0.8635, true=  1, accuracy=1.00
# ID=  310, predicted=  3, probability = 0.8549, true=  3, accuracy=1.00
# ID=  311, predicted=  2, probability = 0.4697, true=  7, accuracy=0.00
# ID=  312, predicted=  1, probability = 0.4297, true=  1, accuracy=1.00
# ID=  313, predicted=  7, probability = 0.6399, true=  7, accuracy=1.00
# ID=  314, predicted=  7, probability = 0.6619, true=  7, accuracy=1.00
# ID=  315, predicted=  7, probability = 0.5977, true=  7, accuracy=1.00
# ID=  316, predicted=  7, probability = 0.4845, true=  7, accuracy=1.00
# ID=  317, predicted=  2, probability = 0.6189, true=  7, accuracy=0.00
# ID=  318, predicted=  3, probability = 0.9896, true=  3, accuracy=1.00
# ID=  319, predicted=  1, probability = 0.8052, true=  1, accuracy=1.00
# ID=  320, predicted=  3, probability = 0.9829, true=  9, accuracy=0.00
# ID=  321, predicted=  7, probability = 0.5223, true=  7, accuracy=1.00
# ID=  322, predicted=  7, probability = 0.5337, true=  7, accuracy=1.00
# ID=  323, predicted=  3, probability = 0.9648, true=  3, accuracy=1.00
# ID=  324, predicted=  5, probability = 0.9488, true=  5, accuracy=1.00
# ID=  325, predicted=  7, probability = 0.4847, true=  2, accuracy=0.00
# ID=  326, predicted=  2, probability = 0.4680, true=  2, accuracy=1.00
# ID=  327, predicted=  7, probability = 0.4436, true=  7, accuracy=1.00
# ID=  328, predicted=  3, probability = 0.5480, true=  3, accuracy=1.00
# ID=  329, predicted=  1, probability = 0.5921, true=  1, accuracy=1.00
# ID=  330, predicted=  1, probability = 0.4239, true=  7, accuracy=0.00
# ID=  331, predicted=  5, probability = 0.5189, true=  5, accuracy=1.00
# ID=  332, predicted=  2, probability = 0.7786, true=  2, accuracy=1.00
# ID=  333, predicted=  1, probability = 0.4672, true=  7, accuracy=0.00
# ID=  334, predicted=  7, probability = 0.4578, true=  2, accuracy=0.00
# ID=  335, predicted=  6, probability = 1.0000, true=  6, accuracy=1.00
# ID=  336, predicted=  2, probability = 0.7314, true=  2, accuracy=1.00
# ID=  337, predicted=  7, probability = 0.5246, true=  2, accuracy=0.00
# ID=  338, predicted=  1, probability = 0.5359, true=  9, accuracy=0.00
# ID=  339, predicted=  2, probability = 0.6008, true=  7, accuracy=0.00
# ID=  340, predicted=  3, probability = 0.9793, true=  9, accuracy=0.00
# ID=  341, predicted=  3, probability = 0.7460, true=  3, accuracy=1.00
# ID=  342, predicted=  5, probability = 0.7975, true=  5, accuracy=1.00
# ID=  343, predicted=  7, probability = 0.4758, true=  5, accuracy=0.00
# ID=  344, predicted=  2, probability = 0.5548, true=  2, accuracy=1.00
# ID=  345, predicted=  2, probability = 0.6259, true=  2, accuracy=1.00
# ID=  346, predicted=  1, probability = 0.7974, true=  2, accuracy=0.00
# ID=  347, predicted=  7, probability = 0.3848, true=  1, accuracy=0.00
# ID=  348, predicted=  2, probability = 0.8140, true=  2, accuracy=1.00
# ID=  349, predicted=  7, probability = 0.4203, true=  2, accuracy=0.00
# ID=  350, predicted=  1, probability = 0.4568, true=  7, accuracy=0.00
# ID=  351, predicted=  7, probability = 0.7163, true=  7, accuracy=1.00
# ID=  352, predicted=  7, probability = 0.4943, true=  7, accuracy=1.00
# ID=  353, predicted=  1, probability = 0.8789, true=  6, accuracy=0.00
# ID=  354, predicted=  1, probability = 0.3237, true=  1, accuracy=1.00
# ID=  355, predicted=  1, probability = 0.8005, true=  1, accuracy=1.00
# ID=  356, predicted=  2, probability = 0.7450, true=  2, accuracy=1.00
# ID=  357, predicted=  7, probability = 0.7272, true=  7, accuracy=1.00
# ID=  358, predicted=  2, probability = 0.4744, true=  7, accuracy=0.00
# ID=  359, predicted=  2, probability = 0.7031, true=  7, accuracy=0.00
# ID=  360, predicted=  3, probability = 0.8773, true=  3, accuracy=1.00
# ID=  361, predicted=  7, probability = 0.3806, true=  7, accuracy=1.00
# ID=  362, predicted=  1, probability = 0.5954, true=  2, accuracy=0.00
# ID=  363, predicted=  7, probability = 0.7450, true=  2, accuracy=0.00
# ID=  364, predicted=  7, probability = 0.4329, true=  7, accuracy=1.00
# ID=  365, predicted=  7, probability = 0.5420, true=  7, accuracy=1.00
# ID=  366, predicted=  7, probability = 0.5921, true=  2, accuracy=0.00
# ID=  367, predicted=  7, probability = 0.5603, true=  6, accuracy=0.00
# ID=  368, predicted=  3, probability = 0.6371, true=  2, accuracy=0.00
# ID=  369, predicted=  6, probability = 1.0000, true=  1, accuracy=0.00
# ID=  370, predicted=  3, probability = 0.5612, true=  3, accuracy=1.00
# ID=  371, predicted=  2, probability = 0.7080, true=  2, accuracy=1.00
# ID=  372, predicted=  7, probability = 0.6082, true=  2, accuracy=0.00
# ID=  373, predicted=  7, probability = 0.5924, true=  7, accuracy=1.00
# ID=  374, predicted=  2, probability = 0.8439, true=  2, accuracy=1.00
# ID=  375, predicted=  2, probability = 0.6041, true=  2, accuracy=1.00
# ID=  376, predicted=  3, probability = 0.8627, true=  3, accuracy=1.00
# ID=  377, predicted=  7, probability = 0.8258, true=  7, accuracy=1.00
# ID=  378, predicted=  7, probability = 0.6481, true=  7, accuracy=1.00
# ID=  379, predicted=  2, probability = 0.5484, true=  2, accuracy=1.00
# ID=  380, predicted=  7, probability = 0.4911, true=  1, accuracy=0.00
# ID=  381, predicted=  2, probability = 0.8225, true=  7, accuracy=0.00
# ID=  382, predicted=  7, probability = 0.5705, true=  1, accuracy=0.00
# ID=  383, predicted=  4, probability = 0.6363, true=  4, accuracy=1.00
# ID=  384, predicted=  2, probability = 0.3546, true=  1, accuracy=0.00
# ID=  385, predicted=  2, probability = 0.6898, true=  7, accuracy=0.00
# ID=  386, predicted=  7, probability = 0.4502, true=  5, accuracy=0.00
# ID=  387, predicted=  2, probability = 0.6727, true=  2, accuracy=1.00
# ID=  388, predicted=  1, probability = 0.5319, true=  7, accuracy=0.00
# ID=  389, predicted=  7, probability = 0.4721, true=  1, accuracy=0.00
# ID=  390, predicted=  7, probability = 0.5396, true=  7, accuracy=1.00
# ID=  391, predicted=  7, probability = 0.6755, true=  7, accuracy=1.00
# ID=  392, predicted=  2, probability = 0.6819, true=  2, accuracy=1.00
# ID=  393, predicted=  7, probability = 0.7232, true=  7, accuracy=1.00
# ID=  394, predicted=  7, probability = 0.3296, true=  7, accuracy=1.00
# ID=  395, predicted=  2, probability = 0.5420, true=  2, accuracy=1.00
# ID=  396, predicted=  3, probability = 0.9939, true=  3, accuracy=1.00
# ID=  397, predicted=  2, probability = 0.5243, true=  7, accuracy=0.00
# ID=  398, predicted=  7, probability = 0.3412, true=  2, accuracy=0.00
# ID=  399, predicted=  7, probability = 0.6249, true=  2, accuracy=0.00
# ID=  400, predicted=  7, probability = 0.5641, true=  7, accuracy=1.00
# ID=  401, predicted=  5, probability = 0.5176, true=  1, accuracy=0.00
# ID=  402, predicted=  2, probability = 0.9058, true=  2, accuracy=1.00
# ID=  403, predicted=  7, probability = 0.5408, true=  7, accuracy=1.00
# ID=  404, predicted=  7, probability = 0.5538, true=  2, accuracy=0.00
# ID=  405, predicted=  3, probability = 0.4447, true=  3, accuracy=1.00
# ID=  406, predicted=  2, probability = 0.9132, true= 10, accuracy=0.00
# ID=  407, predicted=  2, probability = 0.6397, true=  2, accuracy=1.00
# ID=  408, predicted=  3, probability = 0.4167, true=  3, accuracy=1.00
# ID=  409, predicted=  2, probability = 0.6976, true=  2, accuracy=1.00
# ID=  410, predicted=  3, probability = 0.9906, true=  3, accuracy=1.00
# ID=  411, predicted=  3, probability = 0.9255, true=  3, accuracy=1.00
# ID=  412, predicted=  7, probability = 0.7358, true=  7, accuracy=1.00
# ID=  413, predicted=  2, probability = 0.6744, true=  7, accuracy=0.00
# ID=  414, predicted=  4, probability = 0.7568, true=  5, accuracy=0.00
# ID=  415, predicted=  3, probability = 0.9677, true=  3, accuracy=1.00
# ID=  416, predicted=  3, probability = 0.7696, true=  5, accuracy=0.00
# ID=  417, predicted=  1, probability = 0.8638, true=  1, accuracy=1.00
# ID=  418, predicted=  2, probability = 0.8211, true=  2, accuracy=1.00
# ID=  419, predicted=  1, probability = 0.8745, true=  1, accuracy=1.00
# ID=  420, predicted=  7, probability = 0.5463, true=  7, accuracy=1.00
# ID=  421, predicted=  7, probability = 0.3714, true=  2, accuracy=0.00
# ID=  422, predicted=  3, probability = 0.9080, true=  3, accuracy=1.00
# ID=  423, predicted=  7, probability = 0.5930, true=  2, accuracy=0.00
# ID=  424, predicted=  7, probability = 0.4906, true=  7, accuracy=1.00
# ID=  425, predicted=  3, probability = 0.9743, true=  3, accuracy=1.00
# ID=  426, predicted=  2, probability = 0.5243, true=  7, accuracy=0.00
# ID=  427, predicted=  2, probability = 0.5043, true=  7, accuracy=0.00
# ID=  428, predicted=  7, probability = 0.5019, true=  7, accuracy=1.00
# ID=  429, predicted=  1, probability = 0.8052, true=  1, accuracy=1.00
# ID=  430, predicted=  1, probability = 0.5380, true=  1, accuracy=1.00
# ID=  431, predicted=  7, probability = 0.5110, true=  7, accuracy=1.00
# ID=  432, predicted=  7, probability = 0.4255, true=  2, accuracy=0.00
# ID=  433, predicted=  1, probability = 0.3713, true=  7, accuracy=0.00
# ID=  434, predicted=  1, probability = 0.8152, true=  1, accuracy=1.00
# ID=  435, predicted=  6, probability = 1.0000, true=  6, accuracy=1.00
# ID=  436, predicted=  3, probability = 0.8951, true=  9, accuracy=0.00
# ID=  437, predicted=  2, probability = 0.7963, true=  2, accuracy=1.00
# ID=  438, predicted=  7, probability = 0.5676, true=  7, accuracy=1.00
# ID=  439, predicted=  3, probability = 0.8051, true=  3, accuracy=1.00
# ID=  440, predicted=  1, probability = 0.5657, true=  3, accuracy=0.00
# ID=  441, predicted=  2, probability = 0.5757, true=  2, accuracy=1.00
# ID=  442, predicted=  5, probability = 0.7207, true=  3, accuracy=0.00
# ID=  443, predicted=  7, probability = 0.5626, true=  2, accuracy=0.00
# ID=  444, predicted=  7, probability = 0.6935, true=  7, accuracy=1.00
# ID=  445, predicted=  7, probability = 0.6643, true=  7, accuracy=1.00
# ID=  446, predicted=  3, probability = 0.8287, true=  3, accuracy=1.00
# ID=  447, predicted=  4, probability = 0.9523, true=  8, accuracy=0.00
# ID=  448, predicted=  7, probability = 0.4354, true=  7, accuracy=1.00
# ID=  449, predicted=  2, probability = 0.5352, true=  7, accuracy=0.00
# ID=  450, predicted=  7, probability = 0.4404, true=  7, accuracy=1.00
# ID=  451, predicted=  7, probability = 0.3238, true=  3, accuracy=0.00
# ID=  452, predicted=  2, probability = 0.6412, true=  2, accuracy=1.00
# ID=  453, predicted=  7, probability = 0.4532, true=  2, accuracy=0.00
# ID=  454, predicted=  2, probability = 0.7821, true=  2, accuracy=1.00
# ID=  455, predicted=  3, probability = 0.9640, true=  3, accuracy=1.00
# ID=  456, predicted=  1, probability = 0.5439, true=  1, accuracy=1.00
# ID=  457, predicted=  7, probability = 0.6002, true=  2, accuracy=0.00
# ID=  458, predicted=  2, probability = 0.4924, true=  2, accuracy=1.00
# ID=  459, predicted=  2, probability = 0.7033, true=  7, accuracy=0.00
# ID=  460, predicted=  4, probability = 0.9796, true=  4, accuracy=1.00
# ID=  461, predicted=  7, probability = 0.7239, true=  7, accuracy=1.00
# ID=  462, predicted=  7, probability = 0.5450, true=  2, accuracy=0.00
# ID=  463, predicted=  2, probability = 0.9847, true=  2, accuracy=1.00
# ID=  464, predicted=  1, probability = 0.8144, true=  1, accuracy=1.00
# ID=  465, predicted=  3, probability = 0.9883, true=  3, accuracy=1.00
# ID=  466, predicted=  2, probability = 0.8320, true=  2, accuracy=1.00
# ID=  467, predicted=  7, probability = 0.5244, true=  7, accuracy=1.00
# ID=  468, predicted=  2, probability = 0.7038, true=  2, accuracy=1.00
# ID=  469, predicted=  7, probability = 0.5944, true=  7, accuracy=1.00
# ID=  470, predicted=  5, probability = 0.8930, true=  1, accuracy=0.00
# ID=  471, predicted=  1, probability = 0.7567, true=  1, accuracy=1.00
# ID=  472, predicted=  5, probability = 0.7704, true=  4, accuracy=0.00
# ID=  473, predicted=  8, probability = 0.9297, true=  8, accuracy=1.00
# ID=  474, predicted=  1, probability = 0.9167, true=  1, accuracy=1.00
# ID=  475, predicted=  7, probability = 0.6586, true=  1, accuracy=0.00
# ID=  476, predicted=  2, probability = 0.7336, true=  1, accuracy=0.00
# ID=  477, predicted=  1, probability = 0.7199, true=  1, accuracy=1.00
# ID=  478, predicted=  5, probability = 0.4035, true=  5, accuracy=1.00
# ID=  479, predicted=  3, probability = 0.9227, true=  3, accuracy=1.00
# ID=  480, predicted=  1, probability = 0.3702, true=  2, accuracy=0.00
# ID=  481, predicted=  1, probability = 0.7532, true=  8, accuracy=0.00
# ID=  482, predicted=  2, probability = 0.4715, true=  2, accuracy=1.00
# ID=  483, predicted=  7, probability = 0.5348, true=  1, accuracy=0.00
# classification accuracy=0.6136
